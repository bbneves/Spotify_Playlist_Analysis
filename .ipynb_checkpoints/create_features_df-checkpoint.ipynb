# %%
import os
import pprint
import pandas as pd
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials
from config import CLIENT_ID, CLIENT_SECRET

# %%
playlist_df = pd.read_csv(f'./Resources/1_60_playlists.csv', index_col=0)
playlist_df.head()
# Out:
#            Playlist   Followers  Songs Genre 1 Genre 2  \
# 0  Today’s Top Hits  31,728,611     50     Pop     R&B
# 1  Today’s Top Hits  31,728,611     50     Pop     R&B
# 2  Today’s Top Hits  31,728,611     50     Pop     R&B
# 3  Today’s Top Hits  31,728,611     50     Pop     R&B
# 4  Today’s Top Hits  31,728,611     50     Pop     R&B
#
#                                        URI  \
# 0  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# 1  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# 2  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# 3  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# 4  spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
#
#                                Song URI  Popularity   Artist Name  \
# 0  spotify:track:0skYUMpS0AcbpjcGsAbRGj          87     BLACKPINK
# 1  spotify:track:0O6u0VJ46W86TxN9wgyqDj          91   Post Malone
# 2  spotify:track:4LRPiXqCikLlN15c3yImP7          96  Harry Styles
# 3  spotify:track:4h9wh7iOZ0GGn8QVp4RAOB          93   OneRepublic
# 4  spotify:track:1PckUlxKqWQs3RlWXVBLw3          91         Lizzo
#
#                                      Song Name
# 0                                   Pink Venom
# 1  I Like You (A Happier Song) (with Doja Cat)
# 2                                    As It Was
# 3                              I Ain't Worried
# 4                              About Damn Time

# %%
playlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4680 entries, 0 to 4679
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Playlist     4680 non-null   object
#  1   Followers    4680 non-null   object
#  2   Songs        4680 non-null   int64
#  3   Genre 1      4680 non-null   object
#  4   Genre 2      4680 non-null   object
#  5   URI          4680 non-null   object
#  6   Song URI     4680 non-null   object
#  7   Popularity   4680 non-null   int64
#  8   Artist Name  4680 non-null   object
#  9   Song Name    4680 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 402.2+ KB

# %%
playlist_df.count()
# Out:
# Playlist       4680
# Followers      4680
# Songs          4680
# Genre 1        4680
# Genre 2        4680
# URI            4680
# Song URI       4680
# Popularity     4680
# Artist Name    4680
# Song Name      4680
# dtype: int64

# %%
playlist_df['Playlist'].value_counts()
# Out:
# Summer Dance Hits            100
# Alternative R&B              100
# Undercurrents                100
# idk.                         100
# vaporwave                    100
# mint                         100
# Retrowave                    100
# Feel Good Indie Rock         100
# Altar                        100
# Blues & Roots Rock           100
# Metropolis                   100
# Acoustic Blues               100
# Get Turnt                    100
# Country Nights               100
# Country Gold                 100
# Lorem                        100
# free refills                 100
# Progressive Metal            100
# My Life Is A Dream           100
# Heavy Metal                  100
# Indie Rock Road Trip         100
# Bedroom Pop                  100
# Rock Hard                    100
# Rockin' Vibes                100
# Adrenaline Workout           100
# Dirty Rock                   100
# Pollen                        98
# Drinkin' Songs                95
# Hyperpop                      95
# Field Party                   90
# Pop Rising                    85
# Funk Outta Here               80
# Sad Bops                      80
# Golden Hour                   80
# Indie Pop                     75
# Blues Roots                   75
# Pumped Pop                    75
# Crying On The Dance Floor     75
# SALT                          70
# Funky Heavy Bluesy            69
# soda                          65
# Just Good Music               60
# Rap Workout                   59
# Walk Like A Bad Ass           55
# Alt Now                       50
# Rock N' Run                   50
# Rock This                     50
# Serotonin                     50
# Today’s Top Hits              50
# Hot Hits USA                  50
# Hard Rock                     50
# Alternative Hip-Hop           50
# Feelin' Myself                50
# RapCaviar                     50
# Genre Glitch                  50
# Workout Twerkout              50
# Are & Be                      50
# In The Name Of The Blues      49
# Name: Playlist, dtype: int64

# %%
# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = CLIENT_ID
os.environ['SPOTIPY_CLIENT_SECRET'] = CLIENT_SECRET

# %%
# instantiate Spotify class
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
track_uris = playlist_df["Song URI"]

# %%
track_uris
# Out:
# 0       spotify:track:0skYUMpS0AcbpjcGsAbRGj
# 1       spotify:track:0O6u0VJ46W86TxN9wgyqDj
# 2       spotify:track:4LRPiXqCikLlN15c3yImP7
# 3       spotify:track:4h9wh7iOZ0GGn8QVp4RAOB
# 4       spotify:track:1PckUlxKqWQs3RlWXVBLw3
#                         ...
# 4675    spotify:track:4G8EhnfKvBQVlOJ4xXCHpQ
# 4676    spotify:track:6EF0xhfKtQNqUPz2mnE5BD
# 4677    spotify:track:7M7AFtWYg73Kvj5cTZUjiZ
# 4678    spotify:track:7JP8lWYrxpA8luKU8IPd3Y
# 4679    spotify:track:5MgL0ccriqgDP1Gq3pwNNO
# Name: Song URI, Length: 4680, dtype: object

# %% [markdown]
# ### audio_features
# Get audio features for one or multiple tracks based upon their Spotify IDs Parameters
# > audio_features(tracks=[])
#
# - tracks - a list of track URIs, URLs or IDs, maximum: 100 ids

# %%
split_tracks = [track_uris[i:i + 100] for i in range(0, len(track_uris), 100)]

# %%
len(track_uris)
# Out:
# 4680

# %%
len(split_tracks)
# Out:
# 47

# %%
split_tracks[0][0]
# Out:
# 'spotify:track:0skYUMpS0AcbpjcGsAbRGj'

# %%
list1 = split_tracks[0:1]

# %%
list1[0]
# Out:
# 0     spotify:track:0skYUMpS0AcbpjcGsAbRGj
# 1     spotify:track:0O6u0VJ46W86TxN9wgyqDj
# 2     spotify:track:4LRPiXqCikLlN15c3yImP7
# 3     spotify:track:4h9wh7iOZ0GGn8QVp4RAOB
# 4     spotify:track:1PckUlxKqWQs3RlWXVBLw3
#                       ...
# 95    spotify:track:4dyx5SzxPPaD8xQIid5Wjj
# 96    spotify:track:0VF7YLIxSQKyNiFL3X6MmN
# 97    spotify:track:6suYoN4gFkanqOBn5yRnJC
# 98    spotify:track:5S5u0EWtlblH00iTNExZ6X
# 99    spotify:track:77G0k1La0c5Dw8bAFANcyp
# Name: Song URI, Length: 100, dtype: object

# %%
list_15 = split_tracks[14:15]

# %%
list_15[0]
# Out:
# 1400    spotify:track:0ePX6rVjeql7Bt1KurTbAG
# 1401    spotify:track:7uvxkcv7FWVh4wE91I8Bi2
# 1402    spotify:track:1NfqGbaWcZLor12cITE5Fv
# 1403    spotify:track:6VRfsebyIwzt9otSvcuV87
# 1404    spotify:track:2Ryp5LkAWyJwRqoFd8N7Kk
#                         ...
# 1495    spotify:track:2LFLXzQe95ViTXZeq1WRdx
# 1496    spotify:track:7jpq3D0zZjvdWpRq80ZQbK
# 1497    spotify:track:0mRbKcvmbbUtfFyfeFHCJa
# 1498    spotify:track:6EelZchgBjDg1oCZfgsTbZ
# 1499    spotify:track:6oxv6Isn0x28fZh43pviCn
# Name: Song URI, Length: 100, dtype: object

# %%
list_16 = split_tracks[15:16]

# %%
list_16[0]
# Out:
# 1500    spotify:track:7huFrzl3tBNxSr8tp6zyDf
# 1501    spotify:track:6inD5TxljZkdnWDF6SvrZB
# 1502    spotify:track:5CM4UuQ9Gnd6K2YyKGPMoK
# 1503    spotify:track:3XgGQ1wjo5khvq2UImjyNF
# 1504    spotify:track:3PJV3HC2LogvCrS6hDs2el
#                         ...
# 1595    spotify:track:57Zhe3iZ0PGDXm5qpeoXIh
# 1596    spotify:track:1447z3NQY5Dg6oik6Zh5rw
# 1597    spotify:track:3TwAePhxn7pwkdHNwpWgvp
# 1598    spotify:track:1nyyEarKbjbGm3iJqvZknV
# 1599    spotify:track:2wynpXzuXf6Cvf2MqHYA9Z
# Name: Song URI, Length: 100, dtype: object

# %%
track_info = sp.audio_features(list_15[0])

# %%
test_df = pd.DataFrame(track_info)
test_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.722   0.889    3    -2.564     0       0.0416       0.06820
# 1          0.824   0.618    5    -5.435     0       0.0656       0.01320
# 2          0.415   0.585    9    -8.958     1       0.0761       0.03840
# 3          0.518   0.792    9    -3.915     1       0.0349       0.00477
# 4          0.661   0.633    5    -8.819     0       0.0520       0.02270
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.904   0.825   11    -5.675     1       0.1230       0.01770
# 96         0.711   0.674   11    -8.186     0       0.1940       0.03500
# 97         0.695   0.690    1    -5.805     0       0.0233       0.03280
# 98         0.791   0.821    8    -8.421     0       0.0901       0.07020
# 99         0.578   0.831    1    -8.214     0       0.1500       0.00452
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000005    0.1240    0.743  139.965  audio_features
# 1           0.000000    0.0872    0.676  120.028  audio_features
# 2           0.000035    0.3280    0.554  160.292  audio_features
# 3           0.000018    0.2960    0.202  122.042  audio_features
# 4           0.000099    0.1040    0.782  104.934  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.006650    0.1240    0.602  123.048  audio_features
# 96          0.897000    0.1330    0.769  160.244  audio_features
# 97          0.697000    0.1130    0.741   92.977  audio_features
# 98          0.553000    0.0764    0.376  121.860  audio_features
# 99          0.804000    0.2930    0.555  171.499  audio_features
#
#                         id                                   uri  \
# 0   0ePX6rVjeql7Bt1KurTbAG  spotify:track:0ePX6rVjeql7Bt1KurTbAG
# 1   7uvxkcv7FWVh4wE91I8Bi2  spotify:track:7uvxkcv7FWVh4wE91I8Bi2
# 2   1NfqGbaWcZLor12cITE5Fv  spotify:track:1NfqGbaWcZLor12cITE5Fv
# 3   6VRfsebyIwzt9otSvcuV87  spotify:track:6VRfsebyIwzt9otSvcuV87
# 4   2Ryp5LkAWyJwRqoFd8N7Kk  spotify:track:2Ryp5LkAWyJwRqoFd8N7Kk
# ..                     ...                                   ...
# 95  2LFLXzQe95ViTXZeq1WRdx  spotify:track:2LFLXzQe95ViTXZeq1WRdx
# 96  7jpq3D0zZjvdWpRq80ZQbK  spotify:track:7jpq3D0zZjvdWpRq80ZQbK
# 97  0mRbKcvmbbUtfFyfeFHCJa  spotify:track:0mRbKcvmbbUtfFyfeFHCJa
# 98  6EelZchgBjDg1oCZfgsTbZ  spotify:track:6EelZchgBjDg1oCZfgsTbZ
# 99  6oxv6Isn0x28fZh43pviCn  spotify:track:6oxv6Isn0x28fZh43pviCn
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/0ePX6rVjeql7...
# 1   https://api.spotify.com/v1/tracks/7uvxkcv7FWVh...
# 2   https://api.spotify.com/v1/tracks/1NfqGbaWcZLo...
# 3   https://api.spotify.com/v1/tracks/6VRfsebyIwzt...
# 4   https://api.spotify.com/v1/tracks/2Ryp5LkAWyJw...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/2LFLXzQe95Vi...
# 96  https://api.spotify.com/v1/tracks/7jpq3D0zZjvd...
# 97  https://api.spotify.com/v1/tracks/0mRbKcvmbbUt...
# 98  https://api.spotify.com/v1/tracks/6EelZchgBjDg...
# 99  https://api.spotify.com/v1/tracks/6oxv6Isn0x28...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/0ePX...       177397
# 1   https://api.spotify.com/v1/audio-analysis/7uvx...       243236
# 2   https://api.spotify.com/v1/audio-analysis/1Nfq...       164349
# 3   https://api.spotify.com/v1/audio-analysis/6VRf...       215814
# 4   https://api.spotify.com/v1/audio-analysis/2Ryp...       148571
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/2LFL...       203550
# 96  https://api.spotify.com/v1/audio-analysis/7jpq...       173480
# 97  https://api.spotify.com/v1/audio-analysis/0mRb...       293427
# 98  https://api.spotify.com/v1/audio-analysis/6Eel...       362627
# 99  https://api.spotify.com/v1/audio-analysis/6oxv...       186486
#
#     time_signature
# 0                4
# 1                4
# 2                3
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [100 rows x 18 columns]

# %%
test_df[35:45]
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 35         0.787   0.761    0    -8.415     1       0.0372       0.18600
# 36         0.625   0.592   11    -8.034     0       0.0363       0.09710
# 37         0.560   0.647    1    -8.336     1       0.1740       0.62800
# 38         0.730   0.645    2    -6.506     0       0.3480       0.58700
# 39         0.853   0.423    1    -9.670     0       0.2430       0.14100
# 40         0.617   0.709    7    -7.143     1       0.2250       0.00707
# 41         0.806   0.277    9   -14.927     0       0.0439       0.76500
# 42         0.632   0.765    4    -6.451     1       0.0814       0.09400
# 43         0.852   0.930    1    -7.020     1       0.2090       0.01270
# 44         0.690   0.532    1   -10.207     1       0.0822       0.01210
#
#     instrumentalness  liveness  valence    tempo            type  \
# 35          0.535000    0.2910    0.674  131.947  audio_features
# 36          0.073000    0.1190    0.217   88.040  audio_features
# 37          0.000002    0.1020    0.224  120.321  audio_features
# 38          0.000000    0.0937    0.772  128.519  audio_features
# 39          0.020800    0.0990    0.416   75.574  audio_features
# 40          0.000020    0.2740    0.328  100.304  audio_features
# 41          0.874000    0.1200    0.558  141.903  audio_features
# 42          0.002780    0.0865    0.705   78.842  audio_features
# 43          0.494000    0.0573    0.236  129.028  audio_features
# 44          0.000000    0.2010    0.304  143.990  audio_features
#
#                         id                                   uri  \
# 35  36ZL5lijTM6ohAOr2i5lnv  spotify:track:36ZL5lijTM6ohAOr2i5lnv
# 36  3xfz3yzwXhSQCSvJXoM7fY  spotify:track:3xfz3yzwXhSQCSvJXoM7fY
# 37  5XCRe3sFlMuVfQAvv3JBwF  spotify:track:5XCRe3sFlMuVfQAvv3JBwF
# 38  0z3YYobsavHguLTgqg5GC1  spotify:track:0z3YYobsavHguLTgqg5GC1
# 39  2rKg3k5vb5514zEA53JwMt  spotify:track:2rKg3k5vb5514zEA53JwMt
# 40  2QZb1ps0j6TQAGIRbpYboE  spotify:track:2QZb1ps0j6TQAGIRbpYboE
# 41  7lKN7pik3CelVWHWGp6DfB  spotify:track:7lKN7pik3CelVWHWGp6DfB
# 42  0UYbhQk9tUzDeqjcsfDFRF  spotify:track:0UYbhQk9tUzDeqjcsfDFRF
# 43  55meeb1WffJW16DfMnWVi0  spotify:track:55meeb1WffJW16DfMnWVi0
# 44  0jF9AZAaMv49jsy3InMUjQ  spotify:track:0jF9AZAaMv49jsy3InMUjQ
#
#                                            track_href  \
# 35  https://api.spotify.com/v1/tracks/36ZL5lijTM6o...
# 36  https://api.spotify.com/v1/tracks/3xfz3yzwXhSQ...
# 37  https://api.spotify.com/v1/tracks/5XCRe3sFlMuV...
# 38  https://api.spotify.com/v1/tracks/0z3YYobsavHg...
# 39  https://api.spotify.com/v1/tracks/2rKg3k5vb551...
# 40  https://api.spotify.com/v1/tracks/2QZb1ps0j6TQ...
# 41  https://api.spotify.com/v1/tracks/7lKN7pik3Cel...
# 42  https://api.spotify.com/v1/tracks/0UYbhQk9tUzD...
# 43  https://api.spotify.com/v1/tracks/55meeb1WffJW...
# 44  https://api.spotify.com/v1/tracks/0jF9AZAaMv49...
#
#                                          analysis_url  duration_ms  \
# 35  https://api.spotify.com/v1/audio-analysis/36ZL...       149524
# 36  https://api.spotify.com/v1/audio-analysis/3xfz...       263360
# 37  https://api.spotify.com/v1/audio-analysis/5XCR...       233078
# 38  https://api.spotify.com/v1/audio-analysis/0z3Y...       176931
# 39  https://api.spotify.com/v1/audio-analysis/2rKg...       143013
# 40  https://api.spotify.com/v1/audio-analysis/2QZb...       232122
# 41  https://api.spotify.com/v1/audio-analysis/7lKN...       247616
# 42  https://api.spotify.com/v1/audio-analysis/0UYb...       150380
# 43  https://api.spotify.com/v1/audio-analysis/55me...       271642
# 44  https://api.spotify.com/v1/audio-analysis/0jF9...       180000
#
#     time_signature
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4

# %%
# create empty list
track_list = []

# loop amount
n = 47

# loop n number of times
for i in range(0, n):
    
    # sleep for 30 seconds between each set of 100 tracks to avoid API rate limit
    time.sleep(30)
    
    # pull audio features
    tracks = sp.audio_features(split_tracks[i])
    
    # add audio features to list
    track_list = track_list + tracks
    
    # watch the track list grow
    print(len(track_list))
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4680

# %%
# remove None values
track_list = [i for i in track_list if i is not None]

# %%
# convert the complete list to a dataframe    
track_df = pd.DataFrame.from_records(track_list)

# %%
len(track_list)
# Out:
# 4676

# %%
track_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4676 entries, 0 to 4675
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      4676 non-null   float64
#  1   energy            4676 non-null   float64
#  2   key               4676 non-null   int64
#  3   loudness          4676 non-null   float64
#  4   mode              4676 non-null   int64
#  5   speechiness       4676 non-null   float64
#  6   acousticness      4676 non-null   float64
#  7   instrumentalness  4676 non-null   float64
#  8   liveness          4676 non-null   float64
#  9   valence           4676 non-null   float64
#  10  tempo             4676 non-null   float64
#  11  type              4676 non-null   object
#  12  id                4676 non-null   object
#  13  uri               4676 non-null   object
#  14  track_href        4676 non-null   object
#  15  analysis_url      4676 non-null   object
#  16  duration_ms       4676 non-null   int64
#  17  time_signature    4676 non-null   int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 657.7+ KB

# %%
# view one track
track_list[0]
# Out:
# {'danceability': 0.798,
#  'energy': 0.697,
#  'key': 0,
#  'loudness': -7.139,
#  'mode': 1,
#  'speechiness': 0.0891,
#  'acousticness': 0.0202,
#  'instrumentalness': 0,
#  'liveness': 0.259,
#  'valence': 0.745,
#  'tempo': 90.031,
#  'type': 'audio_features',
#  'id': '0skYUMpS0AcbpjcGsAbRGj',
#  'uri': 'spotify:track:0skYUMpS0AcbpjcGsAbRGj',
#  'track_href': 'https://api.spotify.com/v1/tracks/0skYUMpS0AcbpjcGsAbRGj',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0skYUMpS0AcbpjcGsAbRGj',
#  'duration_ms': 186964,
#  'time_signature': 4}

# %%
type(track_list)
# Out:
# list

# %%
type(track_list[0])
# Out:
# dict

# %%
type(tracks)
# Out:
# list

# %%
type(track_df)
# Out:
# pandas.core.frame.DataFrame

# %%
track_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.798   0.697    0    -7.139     1       0.0891       0.02020
# 1            0.733   0.670    5    -6.009     1       0.0751       0.12100
# 2            0.520   0.731    6    -5.338     0       0.0557       0.34200
# 3            0.704   0.797    0    -5.927     1       0.0475       0.08260
# 4            0.836   0.743   10    -6.305     0       0.0656       0.09950
# ...            ...     ...  ...       ...   ...          ...           ...
# 2492         0.662   0.775    7    -6.742     1       0.0441       0.00204
# 2493         0.622   0.673    0    -5.914     1       0.0552       0.02890
# 2494         0.688   0.826    8    -7.617     1       0.0573       0.15600
# 2495         0.633   0.720    2   -10.156     1       0.0470       0.05560
# 2496         0.707   0.415    0    -9.874     1       0.0318       0.00462
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.2590   0.7450   90.031  audio_features
# 1             0.000000    0.1210   0.4720  100.964  audio_features
# 2             0.001010    0.3110   0.6620  173.930  audio_features
# 3             0.000745    0.0546   0.8250  139.994  audio_features
# 4             0.000000    0.3350   0.7220  108.966  audio_features
# ...                ...       ...      ...      ...             ...
# 2492          0.958000    0.0893   0.5940  128.045  audio_features
# 2493          0.029200    0.1280   0.0763  173.981  audio_features
# 2494          0.914000    0.1070   0.7630  142.016  audio_features
# 2495          0.849000    0.1000   0.1600  124.002  audio_features
# 2496          0.090500    0.1110   0.2140  130.049  audio_features
#
#                           id                                   uri  \
# 0     0skYUMpS0AcbpjcGsAbRGj  spotify:track:0skYUMpS0AcbpjcGsAbRGj
# 1     0O6u0VJ46W86TxN9wgyqDj  spotify:track:0O6u0VJ46W86TxN9wgyqDj
# 2     4LRPiXqCikLlN15c3yImP7  spotify:track:4LRPiXqCikLlN15c3yImP7
# 3     4h9wh7iOZ0GGn8QVp4RAOB  spotify:track:4h9wh7iOZ0GGn8QVp4RAOB
# 4     1PckUlxKqWQs3RlWXVBLw3  spotify:track:1PckUlxKqWQs3RlWXVBLw3
# ...                      ...                                   ...
# 2492  5FHLW4748Qp01kvyPjbODM  spotify:track:5FHLW4748Qp01kvyPjbODM
# 2493  43XXw4DgEq4FLeLheuED0X  spotify:track:43XXw4DgEq4FLeLheuED0X
# 2494  45rqRN1h6iNDMIAb0idSjQ  spotify:track:45rqRN1h6iNDMIAb0idSjQ
# 2495  0Vvp9sJydb4zJsanPA77By  spotify:track:0Vvp9sJydb4zJsanPA77By
# 2496  7pLOaCyA4SUW6ERrgkYOUV  spotify:track:7pLOaCyA4SUW6ERrgkYOUV
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0skYUMpS0Acb...
# 1     https://api.spotify.com/v1/tracks/0O6u0VJ46W86...
# 2     https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 3     https://api.spotify.com/v1/tracks/4h9wh7iOZ0GG...
# 4     https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
# ...                                                 ...
# 2492  https://api.spotify.com/v1/tracks/5FHLW4748Qp0...
# 2493  https://api.spotify.com/v1/tracks/43XXw4DgEq4F...
# 2494  https://api.spotify.com/v1/tracks/45rqRN1h6iND...
# 2495  https://api.spotify.com/v1/tracks/0Vvp9sJydb4z...
# 2496  https://api.spotify.com/v1/tracks/7pLOaCyA4SUW...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0skY...       186964
# 1     https://api.spotify.com/v1/audio-analysis/0O6u...       192841
# 2     https://api.spotify.com/v1/audio-analysis/4LRP...       167303
# 3     https://api.spotify.com/v1/audio-analysis/4h9w...       148486
# 4     https://api.spotify.com/v1/audio-analysis/1Pck...       191822
# ...                                                 ...          ...
# 2492  https://api.spotify.com/v1/audio-analysis/5FHL...       226500
# 2493  https://api.spotify.com/v1/audio-analysis/43XX...       226207
# 2494  https://api.spotify.com/v1/audio-analysis/45rq...       175399
# 2495  https://api.spotify.com/v1/audio-analysis/0Vvp...       329072
# 2496  https://api.spotify.com/v1/audio-analysis/7pLO...       257424
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2492               4
# 2493               4
# 2494               4
# 2495               5
# 2496               4
#
# [2497 rows x 18 columns]

# %%
track_df.to_csv('Resources/features.csv')
