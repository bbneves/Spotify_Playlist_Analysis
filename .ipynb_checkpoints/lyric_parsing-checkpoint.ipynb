# %%
# !pip install lyricsgenius
# Out:
# ...
#      ---------------------------------------- 59.4/59.4 kB 3.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from lyricsgenius import Genius

# %%
token = GENIUS_ACCESS_TOKEN

genius = Genius(token)
genius.search_artist('Mogwai')
artist.save_lyrics()
# Out:
# Searching for songs by Mogwai...
#
# Song 1: "Take Me Somewhere Nice"
# Song 2: "Cody"
# Song 3: "Party in the Dark"
# Song 4: "Punk Rock"
# Song 5: "Ritchie Sacramento"
# Song 6: "R U Still in 2 It"
# Song 7: "Repelish"
# Song 8: "Yes! I Am a Long Way from Home"
# Song 9: "Travel Is Dangerous"
# Song 10: "What Are They Doing in Heaven Today?"
# Song 11: "Kids Will Be Skeletons"
# Song 12: "We’re Not Done (End Title)"
# Song 13: "Tracy"
# Song 14: "Dial: Revenge"
# Song 15: "Acid Food"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Mogwai-coolverine-lyrics
# Song 16: "Coolverine"
# Song 17: "George Square Thatcher Death Party"
# Couldn't find the lyrics section. Please report this if the song has lyrics.
# Song URL: https://genius.com/Mogwai-i-know-you-are-but-what-am-i-lyrics
# Song 18: "I Know You Are But What Am I?"
# Song 19: "To the Bin My Friend, Tonight We Vacate Earth"
# Song 20: "Now You’re Taken"
# ...

# %%
happy = genius.search_songs(search_term = "Happy", per_page = 50)
pp.pprint(happy)
# Out:
# {'hits': [{'highlights': [],
#            'index': 'song',
#            'result': {'annotation_count': 7,
#                       'api_path': '/songs/154031',
#                       'artist_names': 'Pharrell Williams',
#                       'featured_artists': [],
#                       'full_title': 'Happy by\xa0Pharrell\xa0Williams',
#                       'header_image_thumbnail_url': 'https://images.genius.com/0712acd53d97c0961659f8228847da34.300x300x1.jpg',
#                       'header_image_url': 'https://images.genius.com/0712acd53d97c0961659f8228847da34.1000x1000x1.jpg',
#                       'id': 154031,
#                       'lyrics_owner_id': 152635,
#                       'lyrics_state': 'complete',
#                       'path': '/Pharrell-williams-happy-lyrics',
#                       'primary_artist': {'api_path': '/artists/110',
# ...

# %%
import pprint

pp = pprint.PrettyPrinter(compact=True)

song = genius.song(154031)
pp.pprint(song)
# Out:
# {'song': {'album': {'api_path': '/albums/84179',
#                     'artist': {'api_path': '/artists/110',
#                                'header_image_url': 'https://images.genius.com/6bb3ce5bd62c7acfc3a66798c4bbeb26.640x427x1.jpg',
#                                'id': 110,
#                                'image_url': 'https://images.genius.com/aa964e94a21e7b893801ed3a2bd389b8.1000x1000x1.jpg',
#                                'iq': 686,
#                                'is_meme_verified': True,
#                                'is_verified': True,
#                                'name': 'Pharrell Williams',
#                                'url': 'https://genius.com/artists/Pharrell-williams'},
#                     'cover_art_url': 'https://images.genius.com/4c01c628ba5147dcc6967aabb1e54da0.994x994x1.png',
#                     'full_title': 'G I R L by Pharrell Williams',
#                     'id': 84179,
#                     'name': 'G I R L',
# ...

# %%
import pandas as pd
from config import GENIUS_ACCESS_TOKEN
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
playlist_df = pd.read_csv(f'./Resources/playlist_df.csv')

# %%
playlist_df
# Out:
#     Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0            0         0.520   0.731    6    -5.338     0       0.0557
# 1            1         0.733   0.670    5    -6.009     1       0.0751
# 2            2         0.686   0.507    1    -7.097     1       0.0357
# 3            3         0.836   0.743   10    -6.305     0       0.0656
# 4            4         0.704   0.797    0    -5.927     1       0.0475
# 5            5         0.798   0.697    0    -7.139     1       0.0891
# 6            6         0.625   0.533   10   -11.903     0       0.0596
# 7            7         0.621   0.782    2    -5.548     1       0.0440
# 8            8         0.801   0.601    8    -7.574     0       0.2550
# 9            9         0.950   0.891    2    -2.653     1       0.2410
# 10          10         0.881   0.592    2    -4.898     1       0.0324
# 11          11         0.714   0.728   10    -4.595     1       0.0468
# ...
