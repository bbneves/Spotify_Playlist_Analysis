# %% [markdown]
# ### utilizing Spotipy library
# https://spotipy.readthedocs.io/en/master/

# %%
from config import CLIENT_ID, CLIENT_SECRET
import os
import pprint
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# ## sensitive info should be saved in your own config file
# at least for now.

# %%
# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = CLIENT_ID
os.environ['SPOTIPY_CLIENT_SECRET'] = CLIENT_SECRET
# os.environ['SPOTIPY_REDIRECT_URI'] = REDIRECT_URI

# %%
# instantiate Spotify class
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %% [markdown]
# ## test playlist (only has 36 songs)
# https://open.spotify.com/playlist/2kDhFUoUK822iKJhKfyn4U?si=ed745160d4be44dd

# %% [markdown]
# ### add the URI
# assuming we can eventually pass in a list of playlists

# %%
#playlist = 'spotify:playlist:2kDhFUoUK822iKJhKfyn4U'

# %% [markdown]
# ### playlist_tracks
# Get full details of the tracks of a playlist.
# > playlist_tracks(playlist_id, fields=None, limit=100, offset=0, market=None, additional_types=('track', ))
#
# Parameters:<br>
# - playlist_id - the playlist ID, URI or URL
# - fields - which fields to return
# - limit - the maximum number of tracks to return
# - offset - the index of the first track to return
# - market - an ISO 3166-1 alpha-2 country code.
# - additional_types - list of item types to return.
#   - valid types are: track and episode

# %%
track_list = sp.playlist_tracks(playlist)

# %% [markdown]
# ### split to extract just the track info

# %%
playlist_URI = playlist.split("/")[-1].split("?")[0]

# %%
type(playlist_URI)
# Out:
# str

# %% [markdown]
# ### create list of tracks

# %%
song_info_df = pd.read_csv(f'./song_info.csv')
track_uris = song_info_df['Song URI']

# %% [markdown]
# ### view track URI's

# %%
track_uris
# Out:
# ['spotify:track:3wOX9DeKWek6OtwcxNnj3x',
#  'spotify:track:4i39VKIzzOgVQS1OPoXvFG',
#  'spotify:track:36zJ1xpwNPWH7z42WOmrl7',
#  'spotify:track:0OF6WSdeVmYEGBZlxvwvLq',
#  'spotify:track:3BWB9Yc0pU1DfqpcKtenJF',
#  'spotify:track:6RPuORHGAq1Z4TKW84nlfh',
#  'spotify:track:2AHejGSGKvO4qu4f26uyEa',
#  'spotify:track:2hN5qPiwQuQlkBQbQ0klaj',
#  'spotify:track:0qpF1m96FRwUUIModl6axE',
#  'spotify:track:3plbKUus8Ox5de75VAKc2h',
#  'spotify:track:4Wt0oJhNlzjyMHhCF3MN7B',
#  'spotify:track:5IEIWiTaLcLhhZduWbEB2a',
#  'spotify:track:1xYYHZ32U32ZYZfFVaujtx',
#  'spotify:track:5umCCdpja8kE1TdqGsVd74',
#  'spotify:track:6kKYRXeuP8gy5M85VCkzLk',
#  'spotify:track:2MwDr9z9cDBiCQkaqYPnWA',
#  'spotify:track:06X1J1lPc0boVEpxG6UOCB',
#  'spotify:track:4p0Yp2fnqydGVEgIE2p60X',
#  'spotify:track:32z2kqCprd70fr5FbxOkfG',
#  'spotify:track:3fBhtdB0pAFJiDTrniqMlV',
#  'spotify:track:3an4AA3vBuzfdyyQF4nsvF',
#  'spotify:track:5NdxiycRi3nP2v7RJoAJIT',
#  'spotify:track:3edkLXdSJzmaqrFVVU1S4p',
#  'spotify:track:4VR212R0dETpbPf4UgOAr9',
#  'spotify:track:5MgSCSEn260529OpGIdeyh',
#  'spotify:track:1XrXFGSiogBItHsrQtRXoE',
#  'spotify:track:05iEquGKfKdtdiWbfRkFEa',
#  'spotify:track:2kL584Ddb8dVjAbga456kZ',
#  'spotify:track:4SdTaBGTR2pQ33vGnAMDCB',
#  'spotify:track:0SbxubxBn2LUvmTKwQAdqT',
#  'spotify:track:5QzKkvtKG3ksglJPylHUqm',
#  'spotify:track:25s1qqeuHILtIlg0mTplBt',
#  'spotify:track:0mA3nM1PFPYttlAYBcuIEB',
#  'spotify:track:1jNXjWbyY3OHoY7vY8HT68',
#  'spotify:track:5uOecHLyk0bHjuz9TVvuDD',
#  'spotify:track:3OetGGu1atx3ZoJ80s5ft2']

# %% [markdown]
# ### convert to DataFrame
# this may not be needed at this time with this data but good practice nonetheless

# %%
track_df = pd.DataFrame(track_uris)

# %% [markdown]
# ### view the DataFrame

# %%
track_df
# Out:
#                                        0
# 0   spotify:track:3wOX9DeKWek6OtwcxNnj3x
# 1   spotify:track:4i39VKIzzOgVQS1OPoXvFG
# 2   spotify:track:36zJ1xpwNPWH7z42WOmrl7
# 3   spotify:track:0OF6WSdeVmYEGBZlxvwvLq
# 4   spotify:track:3BWB9Yc0pU1DfqpcKtenJF
# 5   spotify:track:6RPuORHGAq1Z4TKW84nlfh
# 6   spotify:track:2AHejGSGKvO4qu4f26uyEa
# 7   spotify:track:2hN5qPiwQuQlkBQbQ0klaj
# 8   spotify:track:0qpF1m96FRwUUIModl6axE
# 9   spotify:track:3plbKUus8Ox5de75VAKc2h
# 10  spotify:track:4Wt0oJhNlzjyMHhCF3MN7B
# 11  spotify:track:5IEIWiTaLcLhhZduWbEB2a
# 12  spotify:track:1xYYHZ32U32ZYZfFVaujtx
# 13  spotify:track:5umCCdpja8kE1TdqGsVd74
# 14  spotify:track:6kKYRXeuP8gy5M85VCkzLk
# 15  spotify:track:2MwDr9z9cDBiCQkaqYPnWA
# 16  spotify:track:06X1J1lPc0boVEpxG6UOCB
# 17  spotify:track:4p0Yp2fnqydGVEgIE2p60X
# 18  spotify:track:32z2kqCprd70fr5FbxOkfG
# 19  spotify:track:3fBhtdB0pAFJiDTrniqMlV
# 20  spotify:track:3an4AA3vBuzfdyyQF4nsvF
# 21  spotify:track:5NdxiycRi3nP2v7RJoAJIT
# 22  spotify:track:3edkLXdSJzmaqrFVVU1S4p
# 23  spotify:track:4VR212R0dETpbPf4UgOAr9
# 24  spotify:track:5MgSCSEn260529OpGIdeyh
# 25  spotify:track:1XrXFGSiogBItHsrQtRXoE
# 26  spotify:track:05iEquGKfKdtdiWbfRkFEa
# 27  spotify:track:2kL584Ddb8dVjAbga456kZ
# 28  spotify:track:4SdTaBGTR2pQ33vGnAMDCB
# 29  spotify:track:0SbxubxBn2LUvmTKwQAdqT
# 30  spotify:track:5QzKkvtKG3ksglJPylHUqm
# 31  spotify:track:25s1qqeuHILtIlg0mTplBt
# 32  spotify:track:0mA3nM1PFPYttlAYBcuIEB
# 33  spotify:track:1jNXjWbyY3OHoY7vY8HT68
# 34  spotify:track:5uOecHLyk0bHjuz9TVvuDD
# 35  spotify:track:3OetGGu1atx3ZoJ80s5ft2

# %% [markdown]
# ### PrettyPrinter
# Construct a PrettyPrinter instance. This constructor understands several keyword parameters.
# > pprint.PrettyPrinter(indent=1, width=80, depth=None, stream=None, *, compact=False, sort_dicts=True, underscore_numbers=False)
#
# - stream (default sys.stdout) is a file-like object to which the output will be written by calling its write() method.
#
# Other values configure the manner in which nesting of complex data structures is displayed.
#
# - indent (default 1) specifies the amount of indentation added for each nesting level.
#
# - depth controls the number of nesting levels which may be printed; if the data structure being printed is too deep, the next contained level is replaced by .... By default, there is no constraint on the depth of the objects being formatted.
#
# - width (default 80) specifies the desired maximum number of characters per line in the output. If a structure cannot be formatted within the width constraint, a best effort will be made.
#
# - compact impacts the way that long sequences (lists, tuples, sets, etc) are formatted. If compact is false (the default) then each item of a sequence will be formatted on a separate line. If compact is true, as many items as will fit within the width will be formatted on each output line.
#
# - If sort_dicts is true (the default), dictionaries will be formatted with their keys sorted, otherwise they will display in insertion order.
#
# - If underscore_numbers is true, integers will be formatted with the _ character for a thousands separator, otherwise underscores are not displayed (the default).

# %%
pp = pprint.PrettyPrinter(compact=True)

# %%
# track_1 = list(track_list.items())[:2]

# %%
pp.pprint(track_list)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2kDhFUoUK822iKJhKfyn4U/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'compilation',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                              'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                              'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                              'name': 'Various Artists',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4rbWJkt4gXZI2UYvpNR0mD'},
#                                 'href': 'https://api.spotify.com/v1/albums/4rbWJkt4gXZI2UYvpNR0mD',
#                                 'id': '4rbWJkt4gXZI2UYvpNR0mD',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ee1ca4ec002d7b2f7835636c',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ee1ca4ec002d7b2f7835636c',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ee1ca4ec002d7b2f7835636c',
#                                             'width': 64}],
#                                 'name': 'Beautiful Boy (Original Motion '
#                                         'Picture Soundtrack)',
#                                 'release_date': '2018-10-12',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4rbWJkt4gXZI2UYvpNR0mD'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/34UhPkLbtFKRq3nmfFgejG'},
#                                    'href': 'https://api.spotify.com/v1/artists/34UhPkLbtFKRq3nmfFgejG',
#                                    'id': '34UhPkLbtFKRq3nmfFgejG',
#                                    'name': 'Mogwai',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:34UhPkLbtFKRq3nmfFgejG'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 357817,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBGDZ9700008'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3wOX9DeKWek6OtwcxNnj3x'},
#                       'href': 'https://api.spotify.com/v1/tracks/3wOX9DeKWek6OtwcxNnj3x',
#                       'id': '3wOX9DeKWek6OtwcxNnj3x',
#                       'is_local': False,
#                       'name': 'Helicon 1',
#                       'popularity': 28,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/3dfb5ed9fd6273cbdc17f67efc03da5571273857?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:3wOX9DeKWek6OtwcxNnj3x'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MT9A89Dq8xRJ9hMvvPiJw'},
#                                              'href': 'https://api.spotify.com/v1/artists/4MT9A89Dq8xRJ9hMvvPiJw',
#                                              'id': '4MT9A89Dq8xRJ9hMvvPiJw',
#                                              'name': 'Red Sparowes',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:4MT9A89Dq8xRJ9hMvvPiJw'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'KE', 'KG', 'KH', 'KI',
#                                                       'KM', 'KN', 'KR', 'KW',
#                                                       'KZ', 'LA', 'LB', 'LC',
#                                                       'LI', 'LK', 'LR', 'LS',
#                                                       'LT', 'LU', 'LV', 'LY',
#                                                       'MA', 'MC', 'MD', 'ME',
#                                                       'MG', 'MH', 'MK', 'ML',
#                                                       'MN', 'MO', 'MR', 'MT',
#                                                       'MU', 'MV', 'MW', 'MX',
#                                                       'MY', 'MZ', 'NA', 'NE',
#                                                       'NG', 'NI', 'NL', 'NO',
#                                                       'NP', 'NR', 'NZ', 'OM',
#                                                       'PA', 'PE', 'PG', 'PH',
#                                                       'PK', 'PL', 'PS', 'PT',
#                                                       'PW', 'PY', 'QA', 'RO',
#                                                       'RS', 'RW', 'SA', 'SB',
#                                                       'SC', 'SE', 'SG', 'SI',
#                                                       'SK', 'SL', 'SM', 'SN',
#                                                       'SR', 'ST', 'SV', 'SZ',
#                                                       'TD', 'TG', 'TH', 'TJ',
#                                                       'TL', 'TN', 'TO', 'TR',
#                                                       'TT', 'TV', 'TW', 'TZ',
#                                                       'UA', 'UG', 'US', 'UY',
#                                                       'UZ', 'VC', 'VE', 'VN',
#                                                       'VU', 'WS', 'XK', 'ZA',
#                                                       'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1mLisF7qgSwVDrQ4gklpcR'},
#                                 'href': 'https://api.spotify.com/v1/albums/1mLisF7qgSwVDrQ4gklpcR',
#                                 'id': '1mLisF7qgSwVDrQ4gklpcR',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273357b340a53240da42cf8e8da',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02357b340a53240da42cf8e8da',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851357b340a53240da42cf8e8da',
#                                             'width': 64}],
#                                 'name': 'The Fear Is Excruciating, But Therein '
#                                         'Lies The Answer',
#                                 'release_date': '2010-04-06',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1mLisF7qgSwVDrQ4gklpcR'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4MT9A89Dq8xRJ9hMvvPiJw'},
#                                    'href': 'https://api.spotify.com/v1/artists/4MT9A89Dq8xRJ9hMvvPiJw',
#                                    'id': '4MT9A89Dq8xRJ9hMvvPiJw',
#                                    'name': 'Red Sparowes',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:4MT9A89Dq8xRJ9hMvvPiJw'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'KE', 'KG', 'KH', 'KI',
#                                             'KM', 'KN', 'KR', 'KW', 'KZ', 'LA',
#                                             'LB', 'LC', 'LI', 'LK', 'LR', 'LS',
#                                             'LT', 'LU', 'LV', 'LY', 'MA', 'MC',
#                                             'MD', 'ME', 'MG', 'MH', 'MK', 'ML',
#                                             'MN', 'MO', 'MR', 'MT', 'MU', 'MV',
#                                             'MW', 'MX', 'MY', 'MZ', 'NA', 'NE',
#                                             'NG', 'NI', 'NL', 'NO', 'NP', 'NR',
#                                             'NZ', 'OM', 'PA', 'PE', 'PG', 'PH',
#                                             'PK', 'PL', 'PS', 'PT', 'PW', 'PY',
#                                             'QA', 'RO', 'RS', 'RW', 'SA', 'SB',
#                                             'SC', 'SE', 'SG', 'SI', 'SK', 'SL',
#                                             'SM', 'SN', 'SR', 'ST', 'SV', 'SZ',
#                                             'TD', 'TG', 'TH', 'TJ', 'TL', 'TN',
#                                             'TO', 'TR', 'TT', 'TV', 'TW', 'TZ',
#                                             'UA', 'UG', 'US', 'UY', 'UZ', 'VC',
#                                             'VE', 'VN', 'VU', 'WS', 'XK', 'ZA',
#                                             'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 331866,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USQY51001556'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4i39VKIzzOgVQS1OPoXvFG'},
#                       'href': 'https://api.spotify.com/v1/tracks/4i39VKIzzOgVQS1OPoXvFG',
#                       'id': '4i39VKIzzOgVQS1OPoXvFG',
#                       'is_local': False,
#                       'name': 'A Mutiny',
#                       'popularity': 19,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e87316609b7517be8144934367fce5916fb38801?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:4i39VKIzzOgVQS1OPoXvFG'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3puKPIXi7bUDnPuJZOlJxL'},
#                                              'href': 'https://api.spotify.com/v1/artists/3puKPIXi7bUDnPuJZOlJxL',
#                                              'id': '3puKPIXi7bUDnPuJZOlJxL',
#                                              'name': 'The Six Parts Seven',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3puKPIXi7bUDnPuJZOlJxL'}],
#                                 'available_markets': [],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5x8JhqPRkOtegH8pSgC6ay'},
#                                 'href': 'https://api.spotify.com/v1/albums/5x8JhqPRkOtegH8pSgC6ay',
#                                 'id': '5x8JhqPRkOtegH8pSgC6ay',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2737098c4efa876529949e9b8b5',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e027098c4efa876529949e9b8b5',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048517098c4efa876529949e9b8b5',
#                                             'width': 64}],
#                                 'name': 'Lost Notes From Forgotten Songs',
#                                 'release_date': '2004-05-10',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 9,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5x8JhqPRkOtegH8pSgC6ay'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3puKPIXi7bUDnPuJZOlJxL'},
#                                    'href': 'https://api.spotify.com/v1/artists/3puKPIXi7bUDnPuJZOlJxL',
#                                    'id': '3puKPIXi7bUDnPuJZOlJxL',
#                                    'name': 'The Six Parts Seven',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3puKPIXi7bUDnPuJZOlJxL'}],
#                       'available_markets': [],
#                       'disc_number': 1,
#                       'duration_ms': 147960,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'US33X0403001'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/36zJ1xpwNPWH7z42WOmrl7'},
#                       'href': 'https://api.spotify.com/v1/tracks/36zJ1xpwNPWH7z42WOmrl7',
#                       'id': '36zJ1xpwNPWH7z42WOmrl7',
#                       'is_local': False,
#                       'name': 'Sleeping Diagonally',
#                       'popularity': 0,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:36zJ1xpwNPWH7z42WOmrl7'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r4OqYJL7JrtZlffx7FJlb'},
#                                              'href': 'https://api.spotify.com/v1/artists/5r4OqYJL7JrtZlffx7FJlb',
#                                              'id': '5r4OqYJL7JrtZlffx7FJlb',
#                                              'name': 'The American Dollar',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5r4OqYJL7JrtZlffx7FJlb'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7A6VoC5v3dHcINkZudtJaD'},
#                                 'href': 'https://api.spotify.com/v1/albums/7A6VoC5v3dHcINkZudtJaD',
#                                 'id': '7A6VoC5v3dHcINkZudtJaD',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a99596376a34b47fa2f245f5',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a99596376a34b47fa2f245f5',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a99596376a34b47fa2f245f5',
#                                             'width': 64}],
#                                 'name': 'Ambient One',
#                                 'release_date': '2009-07-15',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7A6VoC5v3dHcINkZudtJaD'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5r4OqYJL7JrtZlffx7FJlb'},
#                                    'href': 'https://api.spotify.com/v1/artists/5r4OqYJL7JrtZlffx7FJlb',
#                                    'id': '5r4OqYJL7JrtZlffx7FJlb',
#                                    'name': 'The American Dollar',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5r4OqYJL7JrtZlffx7FJlb'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 248125,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'US-TC9-09-78721'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0OF6WSdeVmYEGBZlxvwvLq'},
#                       'href': 'https://api.spotify.com/v1/tracks/0OF6WSdeVmYEGBZlxvwvLq',
#                       'id': '0OF6WSdeVmYEGBZlxvwvLq',
#                       'is_local': False,
#                       'name': 'Anything You Synthesize - Ambient',
#                       'popularity': 52,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/f648b4b140f922ff1e384760837024829fee91df?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 10,
#                       'type': 'track',
#                       'uri': 'spotify:track:0OF6WSdeVmYEGBZlxvwvLq'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3cgIU3hh7Y4pUsPgHB8aYT'},
#                                              'href': 'https://api.spotify.com/v1/artists/3cgIU3hh7Y4pUsPgHB8aYT',
#                                              'id': '3cgIU3hh7Y4pUsPgHB8aYT',
#                                              'name': 'Toundra',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3cgIU3hh7Y4pUsPgHB8aYT'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0BZ6vnrROx7OJMLGNFuEtW'},
#                                 'href': 'https://api.spotify.com/v1/albums/0BZ6vnrROx7OJMLGNFuEtW',
#                                 'id': '0BZ6vnrROx7OJMLGNFuEtW',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27357d003b07e274956118c66cf',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0257d003b07e274956118c66cf',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485157d003b07e274956118c66cf',
#                                             'width': 64}],
#                                 'name': 'Vortex',
#                                 'release_date': '2018-04-27',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0BZ6vnrROx7OJMLGNFuEtW'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3cgIU3hh7Y4pUsPgHB8aYT'},
#                                    'href': 'https://api.spotify.com/v1/artists/3cgIU3hh7Y4pUsPgHB8aYT',
#                                    'id': '3cgIU3hh7Y4pUsPgHB8aYT',
#                                    'name': 'Toundra',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3cgIU3hh7Y4pUsPgHB8aYT'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 494693,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBDHC1800403'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3BWB9Yc0pU1DfqpcKtenJF'},
#                       'href': 'https://api.spotify.com/v1/tracks/3BWB9Yc0pU1DfqpcKtenJF',
#                       'id': '3BWB9Yc0pU1DfqpcKtenJF',
#                       'is_local': False,
#                       'name': 'Tuareg',
#                       'popularity': 17,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/2a7aaaf983275d47530f58de77d2f4731aa3e5f6?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:3BWB9Yc0pU1DfqpcKtenJF'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02uPe16VFxPaiueQsPEDkE'},
#                                              'href': 'https://api.spotify.com/v1/artists/02uPe16VFxPaiueQsPEDkE',
#                                              'id': '02uPe16VFxPaiueQsPEDkE',
#                                              'name': 'The Album Leaf',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:02uPe16VFxPaiueQsPEDkE'}],
#                                 'available_markets': [],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0yoDsVdGWHwUthIDLHsN83'},
#                                 'href': 'https://api.spotify.com/v1/albums/0yoDsVdGWHwUthIDLHsN83',
#                                 'id': '0yoDsVdGWHwUthIDLHsN83',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 64}],
#                                 'name': 'A Chorus of Storytellers',
#                                 'release_date': '2010-02-02',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0yoDsVdGWHwUthIDLHsN83'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02uPe16VFxPaiueQsPEDkE'},
#                                    'href': 'https://api.spotify.com/v1/artists/02uPe16VFxPaiueQsPEDkE',
#                                    'id': '02uPe16VFxPaiueQsPEDkE',
#                                    'name': 'The Album Leaf',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:02uPe16VFxPaiueQsPEDkE'}],
#                       'available_markets': [],
#                       'disc_number': 1,
#                       'duration_ms': 296680,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSUB0980505'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6RPuORHGAq1Z4TKW84nlfh'},
#                       'href': 'https://api.spotify.com/v1/tracks/6RPuORHGAq1Z4TKW84nlfh',
#                       'id': '6RPuORHGAq1Z4TKW84nlfh',
#                       'is_local': False,
#                       'name': 'Falling from the Sun',
#                       'popularity': 0,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:6RPuORHGAq1Z4TKW84nlfh'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
# ...
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 340278,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'UKJSB1800038'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1jNXjWbyY3OHoY7vY8HT68'},
#                       'href': 'https://api.spotify.com/v1/tracks/1jNXjWbyY3OHoY7vY8HT68',
#                       'id': '1jNXjWbyY3OHoY7vY8HT68',
#                       'is_local': False,
#                       'name': 'Penarth',
#                       'popularity': 3,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/6c7470f270983dc1f7e7c07855ad64d8b5e6b71a?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 4,
#                       'type': 'track',
#                       'uri': 'spotify:track:1jNXjWbyY3OHoY7vY8HT68'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02uPe16VFxPaiueQsPEDkE'},
#                                              'href': 'https://api.spotify.com/v1/artists/02uPe16VFxPaiueQsPEDkE',
#                                              'id': '02uPe16VFxPaiueQsPEDkE',
#                                              'name': 'The Album Leaf',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:02uPe16VFxPaiueQsPEDkE'}],
#                                 'available_markets': [],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0yoDsVdGWHwUthIDLHsN83'},
#                                 'href': 'https://api.spotify.com/v1/albums/0yoDsVdGWHwUthIDLHsN83',
#                                 'id': '0yoDsVdGWHwUthIDLHsN83',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a8f20b39e91c2ecc8fe9e1f1',
#                                             'width': 64}],
#                                 'name': 'A Chorus of Storytellers',
#                                 'release_date': '2010-02-02',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0yoDsVdGWHwUthIDLHsN83'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02uPe16VFxPaiueQsPEDkE'},
#                                    'href': 'https://api.spotify.com/v1/artists/02uPe16VFxPaiueQsPEDkE',
#                                    'id': '02uPe16VFxPaiueQsPEDkE',
#                                    'name': 'The Album Leaf',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:02uPe16VFxPaiueQsPEDkE'}],
#                       'available_markets': [],
#                       'disc_number': 1,
#                       'duration_ms': 175213,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSUB0980501'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5uOecHLyk0bHjuz9TVvuDD'},
#                       'href': 'https://api.spotify.com/v1/tracks/5uOecHLyk0bHjuz9TVvuDD',
#                       'id': '5uOecHLyk0bHjuz9TVvuDD',
#                       'is_local': False,
#                       'name': 'Perro',
#                       'popularity': 0,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:5uOecHLyk0bHjuz9TVvuDD'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-10-01T11:55:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/frankiebucalo'},
#                          'href': 'https://api.spotify.com/v1/users/frankiebucalo',
#                          'id': 'frankiebucalo',
#                          'type': 'user',
#                          'uri': 'spotify:user:frankiebucalo'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19iNYCVHcMwJMS3NZqhZ59'},
#                                              'href': 'https://api.spotify.com/v1/artists/19iNYCVHcMwJMS3NZqhZ59',
#                                              'id': '19iNYCVHcMwJMS3NZqhZ59',
#                                              'name': 'Oh Hiroshima',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:19iNYCVHcMwJMS3NZqhZ59'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2lAFeBriKxg2zCxO4PYZWY'},
#                                 'href': 'https://api.spotify.com/v1/albums/2lAFeBriKxg2zCxO4PYZWY',
#                                 'id': '2lAFeBriKxg2zCxO4PYZWY',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734c11e65c32bc23a6910aca37',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024c11e65c32bc23a6910aca37',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514c11e65c32bc23a6910aca37',
#                                             'width': 64}],
#                                 'name': 'In Silence We Yearn',
#                                 'release_date': '2015-11-06',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 6,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2lAFeBriKxg2zCxO4PYZWY'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19iNYCVHcMwJMS3NZqhZ59'},
#                                    'href': 'https://api.spotify.com/v1/artists/19iNYCVHcMwJMS3NZqhZ59',
#                                    'id': '19iNYCVHcMwJMS3NZqhZ59',
#                                    'name': 'Oh Hiroshima',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:19iNYCVHcMwJMS3NZqhZ59'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 308368,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'SEYOK1535196'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3OetGGu1atx3ZoJ80s5ft2'},
#                       'href': 'https://api.spotify.com/v1/tracks/3OetGGu1atx3ZoJ80s5ft2',
#                       'id': '3OetGGu1atx3ZoJ80s5ft2',
#                       'is_local': False,
#                       'name': 'Aria',
#                       'popularity': 28,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/0c16f43b95e4e87355c59ab0ca4e7438ecb33dc6?cid=ffd52a957ee14a529c88924db3d395db',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:3OetGGu1atx3ZoJ80s5ft2'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 36}

# %% [markdown]
# ### audio_features
# Get audio features for one or multiple tracks based upon their Spotify IDs Parameters
# > audio_features(tracks=[])
#
# - tracks - a list of track URIs, URLs or IDs, maximum: 100 ids

# %%
song_data = []

# Create counters.
record_count = 1
set_count = 1

for i in range len(track_uris):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)
    
    print(f'Processing song {i} of {len(track_uris)}')

    record_count += 1

    try:
        track_info = sp.audio_features(track_uris)

    except:
        print("Audio features not found. Skipping...")
        pass

# %%
track_info
# Out:
# [{'danceability': 0.242,
#   'energy': 0.394,
#   'key': 2,
#   'loudness': -13.306,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.0708,
#   'instrumentalness': 0.791,
#   'liveness': 0.0805,
#   'valence': 0.0458,
#   'tempo': 118.848,
#   'type': 'audio_features',
#   'id': '3wOX9DeKWek6OtwcxNnj3x',
#   'uri': 'spotify:track:3wOX9DeKWek6OtwcxNnj3x',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wOX9DeKWek6OtwcxNnj3x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wOX9DeKWek6OtwcxNnj3x',
#   'duration_ms': 357817,
#   'time_signature': 3},
#  {'danceability': 0.247,
#   'energy': 0.526,
#   'key': 2,
#   'loudness': -7.984,
#   'mode': 0,
#   'speechiness': 0.032,
#   'acousticness': 0.2,
#   'instrumentalness': 0.878,
#   'liveness': 0.108,
#   'valence': 0.13,
#   'tempo': 135.448,
#   'type': 'audio_features',
#   'id': '4i39VKIzzOgVQS1OPoXvFG',
#   'uri': 'spotify:track:4i39VKIzzOgVQS1OPoXvFG',
#   'track_href': 'https://api.spotify.com/v1/tracks/4i39VKIzzOgVQS1OPoXvFG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4i39VKIzzOgVQS1OPoXvFG',
#   'duration_ms': 331867,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.542,
#   'key': 0,
#   'loudness': -4.796,
#   'mode': 1,
#   'speechiness': 0.0459,
#   'acousticness': 0.89,
#   'instrumentalness': 0.891,
#   'liveness': 0.127,
#   'valence': 0.543,
#   'tempo': 182.803,
#   'type': 'audio_features',
#   'id': '36zJ1xpwNPWH7z42WOmrl7',
#   'uri': 'spotify:track:36zJ1xpwNPWH7z42WOmrl7',
#   'track_href': 'https://api.spotify.com/v1/tracks/36zJ1xpwNPWH7z42WOmrl7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/36zJ1xpwNPWH7z42WOmrl7',
#   'duration_ms': 147960,
#   'time_signature': 4},
#  {'danceability': 0.496,
#   'energy': 0.0936,
#   'key': 1,
#   'loudness': -22.248,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.43,
#   'instrumentalness': 0.94,
#   'liveness': 0.0997,
#   'valence': 0.0308,
#   'tempo': 120.116,
#   'type': 'audio_features',
#   'id': '0OF6WSdeVmYEGBZlxvwvLq',
#   'uri': 'spotify:track:0OF6WSdeVmYEGBZlxvwvLq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0OF6WSdeVmYEGBZlxvwvLq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0OF6WSdeVmYEGBZlxvwvLq',
#   'duration_ms': 248125,
#   'time_signature': 4},
#  {'danceability': 0.174,
#   'energy': 0.913,
#   'key': 2,
#   'loudness': -6.861,
#   'mode': 0,
#   'speechiness': 0.0487,
#   'acousticness': 1.97e-05,
#   'instrumentalness': 0.754,
#   'liveness': 0.099,
#   'valence': 0.0719,
#   'tempo': 155.947,
#   'type': 'audio_features',
#   'id': '3BWB9Yc0pU1DfqpcKtenJF',
#   'uri': 'spotify:track:3BWB9Yc0pU1DfqpcKtenJF',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BWB9Yc0pU1DfqpcKtenJF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BWB9Yc0pU1DfqpcKtenJF',
#   'duration_ms': 494693,
#   'time_signature': 4},
#  {'danceability': 0.462,
#   'energy': 0.53,
#   'key': 2,
#   'loudness': -7.732,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.0872,
#   'instrumentalness': 0.207,
#   'liveness': 0.105,
#   'valence': 0.329,
#   'tempo': 169.908,
#   'type': 'audio_features',
#   'id': '6RPuORHGAq1Z4TKW84nlfh',
#   'uri': 'spotify:track:6RPuORHGAq1Z4TKW84nlfh',
#   'track_href': 'https://api.spotify.com/v1/tracks/6RPuORHGAq1Z4TKW84nlfh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6RPuORHGAq1Z4TKW84nlfh',
#   'duration_ms': 296680,
#   'time_signature': 4},
#  {'danceability': 0.211,
#   'energy': 0.644,
#   'key': 6,
#   'loudness': -8.299,
#   'mode': 0,
#   'speechiness': 0.0402,
#   'acousticness': 0.0499,
#   'instrumentalness': 0.795,
#   'liveness': 0.11,
#   'valence': 0.0455,
#   'tempo': 136.123,
#   'type': 'audio_features',
#   'id': '2AHejGSGKvO4qu4f26uyEa',
#   'uri': 'spotify:track:2AHejGSGKvO4qu4f26uyEa',
#   'track_href': 'https://api.spotify.com/v1/tracks/2AHejGSGKvO4qu4f26uyEa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2AHejGSGKvO4qu4f26uyEa',
#   'duration_ms': 383933,
#   'time_signature': 4},
#  {'danceability': 0.378,
#   'energy': 0.519,
#   'key': 9,
#   'loudness': -9.157,
#   'mode': 0,
#   'speechiness': 0.0289,
#   'acousticness': 0.00104,
#   'instrumentalness': 0.862,
#   'liveness': 0.106,
#   'valence': 0.0385,
#   'tempo': 129.279,
#   'type': 'audio_features',
#   'id': '2hN5qPiwQuQlkBQbQ0klaj',
#   'uri': 'spotify:track:2hN5qPiwQuQlkBQbQ0klaj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2hN5qPiwQuQlkBQbQ0klaj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2hN5qPiwQuQlkBQbQ0klaj',
#   'duration_ms': 562360,
#   'time_signature': 4},
#  {'danceability': 0.223,
#   'energy': 0.0115,
#   'key': 0,
#   'loudness': -29.858,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.994,
#   'instrumentalness': 0.876,
#   'liveness': 0.2,
#   'valence': 0.0414,
#   'tempo': 73.387,
#   'type': 'audio_features',
#   'id': '0qpF1m96FRwUUIModl6axE',
#   'uri': 'spotify:track:0qpF1m96FRwUUIModl6axE',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qpF1m96FRwUUIModl6axE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qpF1m96FRwUUIModl6axE',
#   'duration_ms': 104960,
#   'time_signature': 3},
#  {'danceability': 0.161,
#   'energy': 0.794,
#   'key': 7,
#   'loudness': -7.836,
#   'mode': 1,
#   'speechiness': 0.0474,
#   'acousticness': 7.86e-05,
#   'instrumentalness': 0.639,
#   'liveness': 0.111,
#   'valence': 0.28,
#   'tempo': 104.855,
#   'type': 'audio_features',
#   'id': '3plbKUus8Ox5de75VAKc2h',
#   'uri': 'spotify:track:3plbKUus8Ox5de75VAKc2h',
#   'track_href': 'https://api.spotify.com/v1/tracks/3plbKUus8Ox5de75VAKc2h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3plbKUus8Ox5de75VAKc2h',
#   'duration_ms': 487600,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.648,
#   'key': 5,
#   'loudness': -7.107,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.0466,
#   'instrumentalness': 0.779,
#   'liveness': 0.23,
#   'valence': 0.342,
#   'tempo': 139.987,
#   'type': 'audio_features',
#   'id': '4Wt0oJhNlzjyMHhCF3MN7B',
#   'uri': 'spotify:track:4Wt0oJhNlzjyMHhCF3MN7B',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Wt0oJhNlzjyMHhCF3MN7B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Wt0oJhNlzjyMHhCF3MN7B',
#   'duration_ms': 359307,
#   'time_signature': 4},
#  {'danceability': 0.4,
#   'energy': 0.66,
#   'key': 1,
#   'loudness': -8.785,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.163,
#   'instrumentalness': 0.963,
#   'liveness': 0.109,
#   'valence': 0.0841,
#   'tempo': 162.007,
#   'type': 'audio_features',
#   'id': '5IEIWiTaLcLhhZduWbEB2a',
#   'uri': 'spotify:track:5IEIWiTaLcLhhZduWbEB2a',
#   'track_href': 'https://api.spotify.com/v1/tracks/5IEIWiTaLcLhhZduWbEB2a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IEIWiTaLcLhhZduWbEB2a',
#   'duration_ms': 393413,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.848,
#   'key': 2,
#   'loudness': -9.093,
#   'mode': 0,
#   'speechiness': 0.0482,
#   'acousticness': 0.00243,
#   'instrumentalness': 0.885,
#   'liveness': 0.207,
#   'valence': 0.125,
#   'tempo': 125.02,
#   'type': 'audio_features',
#   'id': '1xYYHZ32U32ZYZfFVaujtx',
#   'uri': 'spotify:track:1xYYHZ32U32ZYZfFVaujtx',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xYYHZ32U32ZYZfFVaujtx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xYYHZ32U32ZYZfFVaujtx',
#   'duration_ms': 396107,
#   'time_signature': 4},
#  {'danceability': 0.271,
#   'energy': 0.826,
#   'key': 11,
#   'loudness': -7.192,
#   'mode': 0,
#   'speechiness': 0.0404,
#   'acousticness': 6.6e-05,
#   'instrumentalness': 0.782,
#   'liveness': 0.139,
#   'valence': 0.115,
#   'tempo': 112.022,
#   'type': 'audio_features',
#   'id': '5umCCdpja8kE1TdqGsVd74',
#   'uri': 'spotify:track:5umCCdpja8kE1TdqGsVd74',
#   'track_href': 'https://api.spotify.com/v1/tracks/5umCCdpja8kE1TdqGsVd74',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5umCCdpja8kE1TdqGsVd74',
#   'duration_ms': 479275,
#   'time_signature': 4},
#  {'danceability': 0.184,
#   'energy': 0.584,
#   'key': 2,
#   'loudness': -9.978,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.729,
#   'instrumentalness': 0.905,
#   'liveness': 0.106,
#   'valence': 0.0813,
#   'tempo': 105.94,
#   'type': 'audio_features',
#   'id': '6kKYRXeuP8gy5M85VCkzLk',
#   'uri': 'spotify:track:6kKYRXeuP8gy5M85VCkzLk',
#   'track_href': 'https://api.spotify.com/v1/tracks/6kKYRXeuP8gy5M85VCkzLk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kKYRXeuP8gy5M85VCkzLk',
#   'duration_ms': 428361,
#   'time_signature': 3},
#  {'danceability': 0.274,
#   'energy': 0.571,
#   'key': 4,
#   'loudness': -8.932,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 0.00428,
#   'instrumentalness': 0.848,
#   'liveness': 0.102,
#   'valence': 0.162,
#   'tempo': 118.107,
#   'type': 'audio_features',
#   'id': '2MwDr9z9cDBiCQkaqYPnWA',
#   'uri': 'spotify:track:2MwDr9z9cDBiCQkaqYPnWA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MwDr9z9cDBiCQkaqYPnWA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MwDr9z9cDBiCQkaqYPnWA',
#   'duration_ms': 282036,
#   'time_signature': 4},
#  {'danceability': 0.112,
#   'energy': 0.0657,
#   'key': 2,
#   'loudness': -19.837,
#   'mode': 1,
#   'speechiness': 0.0495,
#   'acousticness': 0.947,
#   'instrumentalness': 0.931,
#   'liveness': 0.112,
#   'valence': 0.0354,
#   'tempo': 56.75,
#   'type': 'audio_features',
#   'id': '06X1J1lPc0boVEpxG6UOCB',
#   'uri': 'spotify:track:06X1J1lPc0boVEpxG6UOCB',
#   'track_href': 'https://api.spotify.com/v1/tracks/06X1J1lPc0boVEpxG6UOCB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06X1J1lPc0boVEpxG6UOCB',
#   'duration_ms': 161027,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.598,
#   'key': 2,
#   'loudness': -9.179,
#   'mode': 1,
#   'speechiness': 0.0267,
#   'acousticness': 0.0218,
#   'instrumentalness': 0.843,
#   'liveness': 0.102,
#   'valence': 0.666,
#   'tempo': 90.825,
#   'type': 'audio_features',
#   'id': '4p0Yp2fnqydGVEgIE2p60X',
#   'uri': 'spotify:track:4p0Yp2fnqydGVEgIE2p60X',
#   'track_href': 'https://api.spotify.com/v1/tracks/4p0Yp2fnqydGVEgIE2p60X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4p0Yp2fnqydGVEgIE2p60X',
#   'duration_ms': 312000,
#   'time_signature': 4},
#  {'danceability': 0.297,
#   'energy': 0.776,
#   'key': 2,
#   'loudness': -7.074,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.236,
#   'instrumentalness': 0.879,
#   'liveness': 0.11,
#   'valence': 0.133,
#   'tempo': 120.877,
#   'type': 'audio_features',
#   'id': '32z2kqCprd70fr5FbxOkfG',
#   'uri': 'spotify:track:32z2kqCprd70fr5FbxOkfG',
#   'track_href': 'https://api.spotify.com/v1/tracks/32z2kqCprd70fr5FbxOkfG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/32z2kqCprd70fr5FbxOkfG',
#   'duration_ms': 386533,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.616,
#   'key': 2,
#   'loudness': -7.83,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.00701,
#   'instrumentalness': 0.873,
#   'liveness': 0.103,
#   'valence': 0.123,
#   'tempo': 125.009,
#   'type': 'audio_features',
#   'id': '3fBhtdB0pAFJiDTrniqMlV',
#   'uri': 'spotify:track:3fBhtdB0pAFJiDTrniqMlV',
#   'track_href': 'https://api.spotify.com/v1/tracks/3fBhtdB0pAFJiDTrniqMlV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fBhtdB0pAFJiDTrniqMlV',
#   'duration_ms': 383707,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.617,
#   'key': 8,
#   'loudness': -8.194,
#   'mode': 0,
#   'speechiness': 0.0335,
#   'acousticness': 0.0011,
#   'instrumentalness': 0.838,
#   'liveness': 0.102,
#   'valence': 0.0369,
#   'tempo': 124.956,
#   'type': 'audio_features',
#   'id': '3an4AA3vBuzfdyyQF4nsvF',
#   'uri': 'spotify:track:3an4AA3vBuzfdyyQF4nsvF',
#   'track_href': 'https://api.spotify.com/v1/tracks/3an4AA3vBuzfdyyQF4nsvF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3an4AA3vBuzfdyyQF4nsvF',
#   'duration_ms': 267200,
#   'time_signature': 4},
#  {'danceability': 0.279,
#   'energy': 0.472,
#   'key': 4,
#   'loudness': -16.42,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.103,
#   'instrumentalness': 0.874,
#   'liveness': 0.063,
#   'valence': 0.135,
#   'tempo': 115.13,
#   'type': 'audio_features',
#   'id': '5NdxiycRi3nP2v7RJoAJIT',
#   'uri': 'spotify:track:5NdxiycRi3nP2v7RJoAJIT',
#   'track_href': 'https://api.spotify.com/v1/tracks/5NdxiycRi3nP2v7RJoAJIT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NdxiycRi3nP2v7RJoAJIT',
#   'duration_ms': 496573,
#   'time_signature': 3},
#  {'danceability': 0.243,
#   'energy': 0.821,
#   'key': 11,
#   'loudness': -7.223,
#   'mode': 0,
#   'speechiness': 0.0549,
#   'acousticness': 0.00014,
#   'instrumentalness': 0.685,
#   'liveness': 0.122,
#   'valence': 0.138,
#   'tempo': 164.04,
#   'type': 'audio_features',
#   'id': '3edkLXdSJzmaqrFVVU1S4p',
#   'uri': 'spotify:track:3edkLXdSJzmaqrFVVU1S4p',
#   'track_href': 'https://api.spotify.com/v1/tracks/3edkLXdSJzmaqrFVVU1S4p',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3edkLXdSJzmaqrFVVU1S4p',
#   'duration_ms': 392733,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.318,
#   'key': 0,
#   'loudness': -16.671,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.0333,
#   'instrumentalness': 0.781,
#   'liveness': 0.222,
#   'valence': 0.215,
#   'tempo': 129.983,
#   'type': 'audio_features',
#   'id': '4VR212R0dETpbPf4UgOAr9',
#   'uri': 'spotify:track:4VR212R0dETpbPf4UgOAr9',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VR212R0dETpbPf4UgOAr9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VR212R0dETpbPf4UgOAr9',
#   'duration_ms': 358812,
#   'time_signature': 4},
#  {'danceability': 0.453,
#   'energy': 0.388,
#   'key': 8,
#   'loudness': -10.464,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.702,
#   'instrumentalness': 0.881,
#   'liveness': 0.111,
#   'valence': 0.0381,
#   'tempo': 106.129,
#   'type': 'audio_features',
#   'id': '5MgSCSEn260529OpGIdeyh',
#   'uri': 'spotify:track:5MgSCSEn260529OpGIdeyh',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MgSCSEn260529OpGIdeyh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MgSCSEn260529OpGIdeyh',
#   'duration_ms': 410213,
#   'time_signature': 4},
#  {'danceability': 0.199,
#   'energy': 0.227,
#   'key': 0,
#   'loudness': -17.137,
#   'mode': 1,
#   'speechiness': 0.031,
#   'acousticness': 0.916,
#   'instrumentalness': 0.939,
#   'liveness': 0.122,
#   'valence': 0.072,
#   'tempo': 100.759,
#   'type': 'audio_features',
#   'id': '1XrXFGSiogBItHsrQtRXoE',
#   'uri': 'spotify:track:1XrXFGSiogBItHsrQtRXoE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1XrXFGSiogBItHsrQtRXoE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1XrXFGSiogBItHsrQtRXoE',
#   'duration_ms': 311556,
#   'time_signature': 3},
#  {'danceability': 0.271,
#   'energy': 0.25,
#   'key': 4,
#   'loudness': -9.95,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.0849,
#   'instrumentalness': 0.94,
#   'liveness': 0.0966,
#   'valence': 0.0311,
#   'tempo': 110.805,
#   'type': 'audio_features',
#   'id': '05iEquGKfKdtdiWbfRkFEa',
#   'uri': 'spotify:track:05iEquGKfKdtdiWbfRkFEa',
#   'track_href': 'https://api.spotify.com/v1/tracks/05iEquGKfKdtdiWbfRkFEa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05iEquGKfKdtdiWbfRkFEa',
#   'duration_ms': 109213,
#   'time_signature': 4},
#  {'danceability': 0.454,
#   'energy': 0.567,
#   'key': 2,
#   'loudness': -8.473,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.00878,
#   'instrumentalness': 0.843,
#   'liveness': 0.12,
#   'valence': 0.135,
#   'tempo': 114.91,
#   'type': 'audio_features',
#   'id': '2kL584Ddb8dVjAbga456kZ',
#   'uri': 'spotify:track:2kL584Ddb8dVjAbga456kZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2kL584Ddb8dVjAbga456kZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kL584Ddb8dVjAbga456kZ',
#   'duration_ms': 516255,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.812,
#   'key': 11,
#   'loudness': -8.427,
#   'mode': 1,
#   'speechiness': 0.0677,
#   'acousticness': 0.84,
#   'instrumentalness': 0.894,
#   'liveness': 0.221,
#   'valence': 0.29,
#   'tempo': 135.856,
#   'type': 'audio_features',
#   'id': '4SdTaBGTR2pQ33vGnAMDCB',
#   'uri': 'spotify:track:4SdTaBGTR2pQ33vGnAMDCB',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SdTaBGTR2pQ33vGnAMDCB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SdTaBGTR2pQ33vGnAMDCB',
#   'duration_ms': 273804,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.716,
#   'key': 4,
#   'loudness': -8.528,
#   'mode': 0,
#   'speechiness': 0.0307,
#   'acousticness': 0.00285,
#   'instrumentalness': 0.715,
#   'liveness': 0.0898,
#   'valence': 0.437,
#   'tempo': 127.001,
#   'type': 'audio_features',
#   'id': '0SbxubxBn2LUvmTKwQAdqT',
#   'uri': 'spotify:track:0SbxubxBn2LUvmTKwQAdqT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SbxubxBn2LUvmTKwQAdqT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SbxubxBn2LUvmTKwQAdqT',
#   'duration_ms': 272800,
#   'time_signature': 4},
#  {'danceability': 0.422,
#   'energy': 0.481,
#   'key': 9,
#   'loudness': -10.78,
#   'mode': 0,
#   'speechiness': 0.0351,
#   'acousticness': 0.215,
#   'instrumentalness': 0.873,
#   'liveness': 0.164,
#   'valence': 0.0563,
#   'tempo': 114.942,
#   'type': 'audio_features',
#   'id': '5QzKkvtKG3ksglJPylHUqm',
#   'uri': 'spotify:track:5QzKkvtKG3ksglJPylHUqm',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QzKkvtKG3ksglJPylHUqm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QzKkvtKG3ksglJPylHUqm',
#   'duration_ms': 346644,
#   'time_signature': 3},
#  {'danceability': 0.442,
#   'energy': 0.939,
#   'key': 2,
#   'loudness': -5.367,
#   'mode': 0,
#   'speechiness': 0.0702,
#   'acousticness': 0.00014,
#   'instrumentalness': 0.782,
#   'liveness': 0.217,
#   'valence': 0.21,
#   'tempo': 119.553,
#   'type': 'audio_features',
#   'id': '25s1qqeuHILtIlg0mTplBt',
#   'uri': 'spotify:track:25s1qqeuHILtIlg0mTplBt',
#   'track_href': 'https://api.spotify.com/v1/tracks/25s1qqeuHILtIlg0mTplBt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25s1qqeuHILtIlg0mTplBt',
#   'duration_ms': 329280,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.314,
#   'key': 11,
#   'loudness': -10.664,
#   'mode': 0,
#   'speechiness': 0.0329,
#   'acousticness': 0.812,
#   'instrumentalness': 0.898,
#   'liveness': 0.112,
#   'valence': 0.196,
#   'tempo': 85.176,
#   'type': 'audio_features',
#   'id': '0mA3nM1PFPYttlAYBcuIEB',
#   'uri': 'spotify:track:0mA3nM1PFPYttlAYBcuIEB',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mA3nM1PFPYttlAYBcuIEB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mA3nM1PFPYttlAYBcuIEB',
#   'duration_ms': 237173,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.404,
#   'key': 2,
#   'loudness': -15.41,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.235,
#   'instrumentalness': 0.926,
#   'liveness': 0.172,
#   'valence': 0.421,
#   'tempo': 107.1,
#   'type': 'audio_features',
#   'id': '1jNXjWbyY3OHoY7vY8HT68',
#   'uri': 'spotify:track:1jNXjWbyY3OHoY7vY8HT68',
#   'track_href': 'https://api.spotify.com/v1/tracks/1jNXjWbyY3OHoY7vY8HT68',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jNXjWbyY3OHoY7vY8HT68',
#   'duration_ms': 340279,
#   'time_signature': 4},
#  {'danceability': 0.128,
#   'energy': 0.361,
#   'key': 9,
#   'loudness': -16.784,
#   'mode': 0,
#   'speechiness': 0.0639,
#   'acousticness': 0.748,
#   'instrumentalness': 0.893,
#   'liveness': 0.651,
#   'valence': 0.219,
#   'tempo': 179.9,
#   'type': 'audio_features',
#   'id': '5uOecHLyk0bHjuz9TVvuDD',
#   'uri': 'spotify:track:5uOecHLyk0bHjuz9TVvuDD',
#   'track_href': 'https://api.spotify.com/v1/tracks/5uOecHLyk0bHjuz9TVvuDD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uOecHLyk0bHjuz9TVvuDD',
#   'duration_ms': 175213,
#   'time_signature': 3},
#  {'danceability': 0.443,
#   'energy': 0.341,
#   'key': 5,
#   'loudness': -8.772,
#   'mode': 1,
#   'speechiness': 0.0287,
#   'acousticness': 0.000513,
#   'instrumentalness': 0.843,
#   'liveness': 0.182,
#   'valence': 0.115,
#   'tempo': 99.958,
#   'type': 'audio_features',
#   'id': '3OetGGu1atx3ZoJ80s5ft2',
#   'uri': 'spotify:track:3OetGGu1atx3ZoJ80s5ft2',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OetGGu1atx3ZoJ80s5ft2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OetGGu1atx3ZoJ80s5ft2',
#   'duration_ms': 308368,
#   'time_signature': 3}]

# %% [markdown]
# ### confirm how many tracks in list

# %%
len(playlist_info)
# Out:
# 36

# %% [markdown]
# ### convert to DataFrame

# %%
playlist_df = pd.DataFrame(playlist_info)

# %%
playlist_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.242  0.3940    2   -13.306     1       0.0393      0.070800
# 1          0.247  0.5260    2    -7.984     0       0.0320      0.200000
# 2          0.587  0.5420    0    -4.796     1       0.0459      0.890000
# 3          0.496  0.0936    1   -22.248     0       0.0359      0.430000
# 4          0.174  0.9130    2    -6.861     0       0.0487      0.000020
# 5          0.462  0.5300    2    -7.732     1       0.0290      0.087200
# 6          0.211  0.6440    6    -8.299     0       0.0402      0.049900
# 7          0.378  0.5190    9    -9.157     0       0.0289      0.001040
# 8          0.223  0.0115    0   -29.858     1       0.0414      0.994000
# 9          0.161  0.7940    7    -7.836     1       0.0474      0.000079
# 10         0.596  0.6480    5    -7.107     1       0.0306      0.046600
# 11         0.400  0.6600    1    -8.785     1       0.0277      0.163000
# 12         0.596  0.8480    2    -9.093     0       0.0482      0.002430
# 13         0.271  0.8260   11    -7.192     0       0.0404      0.000066
# 14         0.184  0.5840    2    -9.978     1       0.0398      0.729000
# 15         0.274  0.5710    4    -8.932     0       0.0347      0.004280
# 16         0.112  0.0657    2   -19.837     1       0.0495      0.947000
# 17         0.653  0.5980    2    -9.179     1       0.0267      0.021800
# 18         0.297  0.7760    2    -7.074     1       0.0572      0.236000
# 19         0.580  0.6160    2    -7.830     1       0.0356      0.007010
# 20         0.481  0.6170    8    -8.194     0       0.0335      0.001100
# 21         0.279  0.4720    4   -16.420     1       0.0295      0.103000
# 22         0.243  0.8210   11    -7.223     0       0.0549      0.000140
# 23         0.595  0.3180    0   -16.671     1       0.0281      0.033300
# 24         0.453  0.3880    8   -10.464     1       0.0303      0.702000
# 25         0.199  0.2270    0   -17.137     1       0.0310      0.916000
# 26         0.271  0.2500    4    -9.950     1       0.0362      0.084900
# 27         0.454  0.5670    2    -8.473     1       0.0304      0.008780
# 28         0.441  0.8120   11    -8.427     1       0.0677      0.840000
# 29         0.523  0.7160    4    -8.528     0       0.0307      0.002850
# 30         0.422  0.4810    9   -10.780     0       0.0351      0.215000
# 31         0.442  0.9390    2    -5.367     0       0.0702      0.000140
# 32         0.609  0.3140   11   -10.664     0       0.0329      0.812000
# 33         0.629  0.4040    2   -15.410     0       0.0313      0.235000
# 34         0.128  0.3610    9   -16.784     0       0.0639      0.748000
# 35         0.443  0.3410    5    -8.772     1       0.0287      0.000513
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0              0.791    0.0805   0.0458  118.848  audio_features
# 1              0.878    0.1080   0.1300  135.448  audio_features
# 2              0.891    0.1270   0.5430  182.803  audio_features
# 3              0.940    0.0997   0.0308  120.116  audio_features
# 4              0.754    0.0990   0.0719  155.947  audio_features
# 5              0.207    0.1050   0.3290  169.908  audio_features
# 6              0.795    0.1100   0.0455  136.123  audio_features
# 7              0.862    0.1060   0.0385  129.279  audio_features
# 8              0.876    0.2000   0.0414   73.387  audio_features
# 9              0.639    0.1110   0.2800  104.855  audio_features
# 10             0.779    0.2300   0.3420  139.987  audio_features
# 11             0.963    0.1090   0.0841  162.007  audio_features
# 12             0.885    0.2070   0.1250  125.020  audio_features
# 13             0.782    0.1390   0.1150  112.022  audio_features
# 14             0.905    0.1060   0.0813  105.940  audio_features
# 15             0.848    0.1020   0.1620  118.107  audio_features
# 16             0.931    0.1120   0.0354   56.750  audio_features
# 17             0.843    0.1020   0.6660   90.825  audio_features
# 18             0.879    0.1100   0.1330  120.877  audio_features
# 19             0.873    0.1030   0.1230  125.009  audio_features
# 20             0.838    0.1020   0.0369  124.956  audio_features
# 21             0.874    0.0630   0.1350  115.130  audio_features
# 22             0.685    0.1220   0.1380  164.040  audio_features
# 23             0.781    0.2220   0.2150  129.983  audio_features
# 24             0.881    0.1110   0.0381  106.129  audio_features
# 25             0.939    0.1220   0.0720  100.759  audio_features
# 26             0.940    0.0966   0.0311  110.805  audio_features
# 27             0.843    0.1200   0.1350  114.910  audio_features
# 28             0.894    0.2210   0.2900  135.856  audio_features
# 29             0.715    0.0898   0.4370  127.001  audio_features
# 30             0.873    0.1640   0.0563  114.942  audio_features
# 31             0.782    0.2170   0.2100  119.553  audio_features
# 32             0.898    0.1120   0.1960   85.176  audio_features
# 33             0.926    0.1720   0.4210  107.100  audio_features
# 34             0.893    0.6510   0.2190  179.900  audio_features
# 35             0.843    0.1820   0.1150   99.958  audio_features
#
#                         id                                   uri  \
# 0   3wOX9DeKWek6OtwcxNnj3x  spotify:track:3wOX9DeKWek6OtwcxNnj3x
# 1   4i39VKIzzOgVQS1OPoXvFG  spotify:track:4i39VKIzzOgVQS1OPoXvFG
# 2   36zJ1xpwNPWH7z42WOmrl7  spotify:track:36zJ1xpwNPWH7z42WOmrl7
# 3   0OF6WSdeVmYEGBZlxvwvLq  spotify:track:0OF6WSdeVmYEGBZlxvwvLq
# 4   3BWB9Yc0pU1DfqpcKtenJF  spotify:track:3BWB9Yc0pU1DfqpcKtenJF
# 5   6RPuORHGAq1Z4TKW84nlfh  spotify:track:6RPuORHGAq1Z4TKW84nlfh
# 6   2AHejGSGKvO4qu4f26uyEa  spotify:track:2AHejGSGKvO4qu4f26uyEa
# 7   2hN5qPiwQuQlkBQbQ0klaj  spotify:track:2hN5qPiwQuQlkBQbQ0klaj
# 8   0qpF1m96FRwUUIModl6axE  spotify:track:0qpF1m96FRwUUIModl6axE
# 9   3plbKUus8Ox5de75VAKc2h  spotify:track:3plbKUus8Ox5de75VAKc2h
# 10  4Wt0oJhNlzjyMHhCF3MN7B  spotify:track:4Wt0oJhNlzjyMHhCF3MN7B
# 11  5IEIWiTaLcLhhZduWbEB2a  spotify:track:5IEIWiTaLcLhhZduWbEB2a
# 12  1xYYHZ32U32ZYZfFVaujtx  spotify:track:1xYYHZ32U32ZYZfFVaujtx
# 13  5umCCdpja8kE1TdqGsVd74  spotify:track:5umCCdpja8kE1TdqGsVd74
# 14  6kKYRXeuP8gy5M85VCkzLk  spotify:track:6kKYRXeuP8gy5M85VCkzLk
# 15  2MwDr9z9cDBiCQkaqYPnWA  spotify:track:2MwDr9z9cDBiCQkaqYPnWA
# 16  06X1J1lPc0boVEpxG6UOCB  spotify:track:06X1J1lPc0boVEpxG6UOCB
# 17  4p0Yp2fnqydGVEgIE2p60X  spotify:track:4p0Yp2fnqydGVEgIE2p60X
# 18  32z2kqCprd70fr5FbxOkfG  spotify:track:32z2kqCprd70fr5FbxOkfG
# 19  3fBhtdB0pAFJiDTrniqMlV  spotify:track:3fBhtdB0pAFJiDTrniqMlV
# 20  3an4AA3vBuzfdyyQF4nsvF  spotify:track:3an4AA3vBuzfdyyQF4nsvF
# 21  5NdxiycRi3nP2v7RJoAJIT  spotify:track:5NdxiycRi3nP2v7RJoAJIT
# 22  3edkLXdSJzmaqrFVVU1S4p  spotify:track:3edkLXdSJzmaqrFVVU1S4p
# 23  4VR212R0dETpbPf4UgOAr9  spotify:track:4VR212R0dETpbPf4UgOAr9
# 24  5MgSCSEn260529OpGIdeyh  spotify:track:5MgSCSEn260529OpGIdeyh
# 25  1XrXFGSiogBItHsrQtRXoE  spotify:track:1XrXFGSiogBItHsrQtRXoE
# 26  05iEquGKfKdtdiWbfRkFEa  spotify:track:05iEquGKfKdtdiWbfRkFEa
# 27  2kL584Ddb8dVjAbga456kZ  spotify:track:2kL584Ddb8dVjAbga456kZ
# 28  4SdTaBGTR2pQ33vGnAMDCB  spotify:track:4SdTaBGTR2pQ33vGnAMDCB
# 29  0SbxubxBn2LUvmTKwQAdqT  spotify:track:0SbxubxBn2LUvmTKwQAdqT
# 30  5QzKkvtKG3ksglJPylHUqm  spotify:track:5QzKkvtKG3ksglJPylHUqm
# 31  25s1qqeuHILtIlg0mTplBt  spotify:track:25s1qqeuHILtIlg0mTplBt
# 32  0mA3nM1PFPYttlAYBcuIEB  spotify:track:0mA3nM1PFPYttlAYBcuIEB
# 33  1jNXjWbyY3OHoY7vY8HT68  spotify:track:1jNXjWbyY3OHoY7vY8HT68
# 34  5uOecHLyk0bHjuz9TVvuDD  spotify:track:5uOecHLyk0bHjuz9TVvuDD
# 35  3OetGGu1atx3ZoJ80s5ft2  spotify:track:3OetGGu1atx3ZoJ80s5ft2
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/3wOX9DeKWek6...
# 1   https://api.spotify.com/v1/tracks/4i39VKIzzOgV...
# 2   https://api.spotify.com/v1/tracks/36zJ1xpwNPWH...
# 3   https://api.spotify.com/v1/tracks/0OF6WSdeVmYE...
# 4   https://api.spotify.com/v1/tracks/3BWB9Yc0pU1D...
# 5   https://api.spotify.com/v1/tracks/6RPuORHGAq1Z...
# 6   https://api.spotify.com/v1/tracks/2AHejGSGKvO4...
# 7   https://api.spotify.com/v1/tracks/2hN5qPiwQuQl...
# 8   https://api.spotify.com/v1/tracks/0qpF1m96FRwU...
# 9   https://api.spotify.com/v1/tracks/3plbKUus8Ox5...
# 10  https://api.spotify.com/v1/tracks/4Wt0oJhNlzjy...
# 11  https://api.spotify.com/v1/tracks/5IEIWiTaLcLh...
# 12  https://api.spotify.com/v1/tracks/1xYYHZ32U32Z...
# 13  https://api.spotify.com/v1/tracks/5umCCdpja8kE...
# 14  https://api.spotify.com/v1/tracks/6kKYRXeuP8gy...
# 15  https://api.spotify.com/v1/tracks/2MwDr9z9cDBi...
# 16  https://api.spotify.com/v1/tracks/06X1J1lPc0bo...
# 17  https://api.spotify.com/v1/tracks/4p0Yp2fnqydG...
# 18  https://api.spotify.com/v1/tracks/32z2kqCprd70...
# 19  https://api.spotify.com/v1/tracks/3fBhtdB0pAFJ...
# 20  https://api.spotify.com/v1/tracks/3an4AA3vBuzf...
# 21  https://api.spotify.com/v1/tracks/5NdxiycRi3nP...
# 22  https://api.spotify.com/v1/tracks/3edkLXdSJzma...
# 23  https://api.spotify.com/v1/tracks/4VR212R0dETp...
# 24  https://api.spotify.com/v1/tracks/5MgSCSEn2605...
# 25  https://api.spotify.com/v1/tracks/1XrXFGSiogBI...
# 26  https://api.spotify.com/v1/tracks/05iEquGKfKdt...
# 27  https://api.spotify.com/v1/tracks/2kL584Ddb8dV...
# 28  https://api.spotify.com/v1/tracks/4SdTaBGTR2pQ...
# 29  https://api.spotify.com/v1/tracks/0SbxubxBn2LU...
# 30  https://api.spotify.com/v1/tracks/5QzKkvtKG3ks...
# 31  https://api.spotify.com/v1/tracks/25s1qqeuHILt...
# 32  https://api.spotify.com/v1/tracks/0mA3nM1PFPYt...
# 33  https://api.spotify.com/v1/tracks/1jNXjWbyY3OH...
# 34  https://api.spotify.com/v1/tracks/5uOecHLyk0bH...
# 35  https://api.spotify.com/v1/tracks/3OetGGu1atx3...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/3wOX...       357817
# 1   https://api.spotify.com/v1/audio-analysis/4i39...       331867
# 2   https://api.spotify.com/v1/audio-analysis/36zJ...       147960
# 3   https://api.spotify.com/v1/audio-analysis/0OF6...       248125
# 4   https://api.spotify.com/v1/audio-analysis/3BWB...       494693
# 5   https://api.spotify.com/v1/audio-analysis/6RPu...       296680
# 6   https://api.spotify.com/v1/audio-analysis/2AHe...       383933
# 7   https://api.spotify.com/v1/audio-analysis/2hN5...       562360
# 8   https://api.spotify.com/v1/audio-analysis/0qpF...       104960
# 9   https://api.spotify.com/v1/audio-analysis/3plb...       487600
# 10  https://api.spotify.com/v1/audio-analysis/4Wt0...       359307
# 11  https://api.spotify.com/v1/audio-analysis/5IEI...       393413
# 12  https://api.spotify.com/v1/audio-analysis/1xYY...       396107
# 13  https://api.spotify.com/v1/audio-analysis/5umC...       479275
# 14  https://api.spotify.com/v1/audio-analysis/6kKY...       428361
# 15  https://api.spotify.com/v1/audio-analysis/2MwD...       282036
# 16  https://api.spotify.com/v1/audio-analysis/06X1...       161027
# 17  https://api.spotify.com/v1/audio-analysis/4p0Y...       312000
# 18  https://api.spotify.com/v1/audio-analysis/32z2...       386533
# 19  https://api.spotify.com/v1/audio-analysis/3fBh...       383707
# 20  https://api.spotify.com/v1/audio-analysis/3an4...       267200
# 21  https://api.spotify.com/v1/audio-analysis/5Ndx...       496573
# 22  https://api.spotify.com/v1/audio-analysis/3edk...       392733
# 23  https://api.spotify.com/v1/audio-analysis/4VR2...       358812
# 24  https://api.spotify.com/v1/audio-analysis/5MgS...       410213
# 25  https://api.spotify.com/v1/audio-analysis/1XrX...       311556
# 26  https://api.spotify.com/v1/audio-analysis/05iE...       109213
# 27  https://api.spotify.com/v1/audio-analysis/2kL5...       516255
# 28  https://api.spotify.com/v1/audio-analysis/4SdT...       273804
# 29  https://api.spotify.com/v1/audio-analysis/0Sbx...       272800
# 30  https://api.spotify.com/v1/audio-analysis/5QzK...       346644
# 31  https://api.spotify.com/v1/audio-analysis/25s1...       329280
# 32  https://api.spotify.com/v1/audio-analysis/0mA3...       237173
# 33  https://api.spotify.com/v1/audio-analysis/1jNX...       340279
# 34  https://api.spotify.com/v1/audio-analysis/5uOe...       175213
# 35  https://api.spotify.com/v1/audio-analysis/3Oet...       308368
#
#     time_signature
# 0                3
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                3
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               3
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               3
# 22               4
# 23               4
# 24               4
# 25               3
# 26               4
# 27               4
# 28               4
# 29               4
# 30               3
# 31               4
# 32               4
# 33               4
# 34               3
# 35               3

# %%
song_names = []
artist_names = []
popularity = []

for i in track_list['items']:
        popularity.append(i['track']['popularity'])
        artist_names.append(i['track']['artists'][0]['name'])
        song_names.append(i['track']['name'])
    
song_names
# Out:
# ['Helicon 1',
#  'A Mutiny',
#  'Sleeping Diagonally',
#  'Anything You Synthesize - Ambient',
#  'Tuareg',
#  'Falling from the Sun',
#  'From Embrace To Embrace',
#  'Voskhod Project - Bonus',
#  'God Bless',
#  'Versus',
#  'Split Stones',
#  'Volga',
#  'Darkfield',
#  'Drones',
#  'Return, Return Again',
#  "Through the Stars We've Seen",
#  'Requiem On Frankfort Ave',
#  'Fanshawe',
#  "O'Canada",
#  "I'll Share a Life",
#  'Swallowing Teeth',
#  'Your Hand In Mine',
#  'Mota',
#  'The Whispering Caves',
#  'Cold Things Never Catch Fire',
#  'What the Heart Craves For',
#  'Truths Arise',
#  'Bells Bleed & Bloom',
#  'Like This',
#  'Bromas',
#  'Thunder Rising',
#  'Terrain',
#  'Winds with Hands',
#  'Penarth',
#  'Perro',
#  'Aria']

# %%
playlist_df['song_name'] = song_names
playlist_df['artist_name'] = artist_names
playlist_df['popularity_score'] = popularity

playlist_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.242  0.3940    2   -13.306     1       0.0393       0.07080
# 1         0.247  0.5260    2    -7.984     0       0.0320       0.20000
# 2         0.587  0.5420    0    -4.796     1       0.0459       0.89000
# 3         0.496  0.0936    1   -22.248     0       0.0359       0.43000
# 4         0.174  0.9130    2    -6.861     0       0.0487       0.00002
#
#    instrumentalness  liveness  valence  ...            type  \
# 0             0.791    0.0805   0.0458  ...  audio_features
# 1             0.878    0.1080   0.1300  ...  audio_features
# 2             0.891    0.1270   0.5430  ...  audio_features
# 3             0.940    0.0997   0.0308  ...  audio_features
# 4             0.754    0.0990   0.0719  ...  audio_features
#
#                        id                                   uri  \
# 0  3wOX9DeKWek6OtwcxNnj3x  spotify:track:3wOX9DeKWek6OtwcxNnj3x
# 1  4i39VKIzzOgVQS1OPoXvFG  spotify:track:4i39VKIzzOgVQS1OPoXvFG
# 2  36zJ1xpwNPWH7z42WOmrl7  spotify:track:36zJ1xpwNPWH7z42WOmrl7
# 3  0OF6WSdeVmYEGBZlxvwvLq  spotify:track:0OF6WSdeVmYEGBZlxvwvLq
# 4  3BWB9Yc0pU1DfqpcKtenJF  spotify:track:3BWB9Yc0pU1DfqpcKtenJF
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3wOX9DeKWek6...
# 1  https://api.spotify.com/v1/tracks/4i39VKIzzOgV...
# 2  https://api.spotify.com/v1/tracks/36zJ1xpwNPWH...
# 3  https://api.spotify.com/v1/tracks/0OF6WSdeVmYE...
# 4  https://api.spotify.com/v1/tracks/3BWB9Yc0pU1D...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3wOX...      357817
# 1  https://api.spotify.com/v1/audio-analysis/4i39...      331867
# 2  https://api.spotify.com/v1/audio-analysis/36zJ...      147960
# 3  https://api.spotify.com/v1/audio-analysis/0OF6...      248125
# 4  https://api.spotify.com/v1/audio-analysis/3BWB...      494693
#
#    time_signature                          song_name          artist_name  \
# 0               3                          Helicon 1               Mogwai
# 1               4                           A Mutiny         Red Sparowes
# 2               4                Sleeping Diagonally  The Six Parts Seven
# 3               4  Anything You Synthesize - Ambient  The American Dollar
# 4               4                             Tuareg              Toundra
#
#   popularity_score
# 0               28
# 1               19
# 2                0
# 3               52
# 4               17
#
# [5 rows x 21 columns]
