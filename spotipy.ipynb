# %% [markdown]
# ### utilizing Spotipy library
# https://spotipy.readthedocs.io/en/master/

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
#import config
from config import CLIENT_ID
from config import CLIENT_SECRET
import os
import pprint

# %% [markdown]
# ## sensitive info should be saved in your own config file
# at least for now.

# %%
# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = CLIENT_ID
os.environ['SPOTIPY_CLIENT_SECRET'] = CLIENT_SECRET
# os.environ['SPOTIPY_REDIRECT_URI'] = REDIRECT_URI

# %% [markdown]
# ## test playlist (only has 36 songs)
# https://open.spotify.com/playlist/2kDhFUoUK822iKJhKfyn4U?si=ed745160d4be44dd

# %% [markdown]
# ### add the URI
# assuming we can eventually pass in a list of playlists

# %%
playlist = 'spotify:playlist:37i9dQZF1DWWEcRhUVtL8n'

# %% [markdown]
# ### playlist_tracks
# Get full details of the tracks of a playlist.
# > playlist_tracks(playlist_id, fields=None, limit=100, offset=0, market=None, additional_types=('track', ))
#
# Parameters:<br>
# - playlist_id - the playlist ID, URI or URL
# - fields - which fields to return
# - limit - the maximum number of tracks to return
# - offset - the index of the first track to return
# - market - an ISO 3166-1 alpha-2 country code.
# - additional_types - list of item types to return.
#   - valid types are: track and episode

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
track_list = sp.playlist_tracks(playlist)

# %% [markdown]
# ### split to extract just the track info

# %%
playlist_URI = playlist.split("/")[-1].split("?")[0]

# %% [markdown]
# ### create list of tracks

# %%
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %% [markdown]
# ### view track URI's

# %%
track_uris
# Out:
# ['spotify:track:1hf0PdHw0lnVxq5lfzwjSl',
#  'spotify:track:6HU7h9RYOaPRFeh0R3UeAr',
#  'spotify:track:5bD7bhOa64aE8a0vifa5J6',
#  'spotify:track:0MnTkIEP4zZN1IUSu8MvIz',
#  'spotify:track:4XVPArAtSq0657KUF0vXRy',
#  'spotify:track:7B3z0ySL9Rr0XvZEAjWZzM',
#  'spotify:track:5RaThsdZpF9WWwoP00NjLI',
#  'spotify:track:7N1bEUVuQo8HHuikDgJ10c',
#  'spotify:track:3nOz1U41SZZ0N3fuUWr9nb',
#  'spotify:track:3MwKRb5GB9phdL9ktdvBsv',
#  'spotify:track:5o9iQVktO08gIlRAHqqxtj',
#  'spotify:track:0VF7YLIxSQKyNiFL3X6MmN',
#  'spotify:track:4JeOesjcWWlprTAvucDSJX',
#  'spotify:track:0KQRhak4Irr2CKxgQ9U6ay',
#  'spotify:track:6Ql7rNuoP90aIdgwQkPYBP',
#  'spotify:track:0brBOx8ejPXvBYnQkWquYK',
#  'spotify:track:7LNm1oWd6PniO9wRYpNY5o',
#  'spotify:track:0ohcCrxZkBfFbkuRPOZQZX',
#  'spotify:track:5meVa5klVlJalupZTvv5XX',
#  'spotify:track:0KmgJyW4GDgonqsoyx0CZ3',
#  'spotify:track:7rC3P7tpWriaC4hYWKwGQd',
#  'spotify:track:7a4YwlUER1m7rkWJjYJRAD',
#  'spotify:track:1VyA8mbSyXOdJx2lguR8Uu',
#  'spotify:track:5MG69A9XyXDbBbeOxdR3Tl',
#  'spotify:track:0vQYe6g8bNbdUKnUnXdQQV',
#  'spotify:track:23TPP1eeElFfvYVznskwCY',
#  'spotify:track:252G7yirQ4pXj6ZD4T9R2W',
#  'spotify:track:0PLhwCmQ7cC3ThRGPn3HxF',
#  'spotify:track:5BCYtpbTyUQSMRwDVPb5wk',
#  'spotify:track:1h8dms5lJ4QcXB0tyguk4c',
#  'spotify:track:7n6QMW76A5qgfn0Mb4aL7i',
#  'spotify:track:4aHrviUXxabPdIgWxdYQLt',
#  'spotify:track:2F9DCIJ7ZXHhNkiIlIIOkw',
#  'spotify:track:7GtOjSSp5Qyi3gNbNDZgja',
#  'spotify:track:7AX1eCw6qcX54PrDylynJr',
#  'spotify:track:1camd9eP6HEbhNjXww8FKN',
#  'spotify:track:0VlNBqGgNFR8Kp022pyp2f',
#  'spotify:track:1RlmAzI27AlIpvoRN3u6Iy',
#  'spotify:track:3gZyxP7keADPPc8lEJWehW',
#  'spotify:track:4dHdqpGaO9km4TEw9nNQSR',
#  'spotify:track:0ioTTk5l0Zz7Oh48qEocgj',
#  'spotify:track:2Tv3bPKLESHfl8jgAlY2Pv',
#  'spotify:track:4LK36kV9w3KBD2GYL26ZBq',
#  'spotify:track:3gzIK2dGSVvPBiohsTwEWZ',
#  'spotify:track:19YOJKCVvOL7v6B2Oe3UBc',
#  'spotify:track:6fGSHpEipD1YjtLLChnBzW',
#  'spotify:track:1q2Zb0v5ZGxKDktEz7wSPb',
#  'spotify:track:0fB64S7FNKUDQlyYXlacYi',
#  'spotify:track:5YIAMIFBXGXsyJwJmqUMZo',
#  'spotify:track:7xXUNbWepi09rzwW1Il61B',
#  'spotify:track:5d8a5B6RlYnquvR4X4OIrX',
#  'spotify:track:0ePX6rVjeql7Bt1KurTbAG',
#  'spotify:track:7uvxkcv7FWVh4wE91I8Bi2',
#  'spotify:track:6VRfsebyIwzt9otSvcuV87',
#  'spotify:track:1NfqGbaWcZLor12cITE5Fv',
#  'spotify:track:2Ryp5LkAWyJwRqoFd8N7Kk',
#  'spotify:track:0P2CBPHJsD0BgdsqHedugp',
#  'spotify:track:5eGIOMy0V0r7neaaPve2kB',
#  'spotify:track:2IKix80lBA5ppm6096p5U7',
#  'spotify:track:3Gplr4iOpewQ9ynbZujzlu',
#  'spotify:track:6S2Uha79wlOXCRlDOImZkZ',
#  'spotify:track:0ZpHuEhi1CvOJgrqOSy8mv',
#  'spotify:track:1SldN7GTd0ADTjspv96wCl',
#  'spotify:track:1USo158Kncaxfyq9q306dn',
#  'spotify:track:5nsMKSAJwcr1pA9I6PW429',
#  'spotify:track:4nLTOnpSCBwRlul92HLIyW',
#  'spotify:track:3QEX5O23KVp1yg1tj6Hycp',
#  'spotify:track:5DObWDHfwHE2mIdZGgRnzE',
#  'spotify:track:6el1gIJ39V0ycFwNLZiKm7',
#  'spotify:track:3NE8bmyye8sEOQtWknh8Vi',
#  'spotify:track:2DGdgztVbE3pFmqoF1rHzp',
#  'spotify:track:18O6oj2DtAA9lPlP9Kl9R2',
#  'spotify:track:7LhVGZrF9jgkT97CaKTlds',
#  'spotify:track:6pQcqaoZlGKF3zvglt6tvc',
#  'spotify:track:0G41EUi3xiwUR6iOtXAQCz']

# %% [markdown]
# ### convert to DataFrame
# this may not be needed at this time with this data but good practice nonetheless

# %%
track_df = pd.DataFrame(track_uris)

# %% [markdown]
# ### view the DataFrame

# %%
track_df
# Out:
#                                        0
# 0   spotify:track:1hf0PdHw0lnVxq5lfzwjSl
# 1   spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 2   spotify:track:5bD7bhOa64aE8a0vifa5J6
# 3   spotify:track:0MnTkIEP4zZN1IUSu8MvIz
# 4   spotify:track:4XVPArAtSq0657KUF0vXRy
# ..                                   ...
# 70  spotify:track:2DGdgztVbE3pFmqoF1rHzp
# 71  spotify:track:18O6oj2DtAA9lPlP9Kl9R2
# 72  spotify:track:7LhVGZrF9jgkT97CaKTlds
# 73  spotify:track:6pQcqaoZlGKF3zvglt6tvc
# 74  spotify:track:0G41EUi3xiwUR6iOtXAQCz
#
# [75 rows x 1 columns]

# %% [markdown]
# ### PrettyPrinter
# Construct a PrettyPrinter instance. This constructor understands several keyword parameters.
# > pprint.PrettyPrinter(indent=1, width=80, depth=None, stream=None, *, compact=False, sort_dicts=True, underscore_numbers=False)
#
# - stream (default sys.stdout) is a file-like object to which the output will be written by calling its write() method.
#
# Other values configure the manner in which nesting of complex data structures is displayed.
#
# - indent (default 1) specifies the amount of indentation added for each nesting level.
#
# - depth controls the number of nesting levels which may be printed; if the data structure being printed is too deep, the next contained level is replaced by .... By default, there is no constraint on the depth of the objects being formatted.
#
# - width (default 80) specifies the desired maximum number of characters per line in the output. If a structure cannot be formatted within the width constraint, a best effort will be made.
#
# - compact impacts the way that long sequences (lists, tuples, sets, etc) are formatted. If compact is false (the default) then each item of a sequence will be formatted on a separate line. If compact is true, as many items as will fit within the width will be formatted on each output line.
#
# - If sort_dicts is true (the default), dictionaries will be formatted with their keys sorted, otherwise they will display in insertion order.
#
# - If underscore_numbers is true, integers will be formatted with the _ character for a thousands separator, otherwise underscores are not displayed (the default).

# %%
pp = pprint.PrettyPrinter(compact=True)

# %%
pp.pprint(track_list)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWWEcRhUVtL8n/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2022-08-12T18:24:50Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25pd339V2rRJo84USlcSRP'},
#                                              'href': 'https://api.spotify.com/v1/artists/25pd339V2rRJo84USlcSRP',
#                                              'id': '25pd339V2rRJo84USlcSRP',
#                                              'name': 'JAWNY',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:25pd339V2rRJo84USlcSRP'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BZ', 'CA', 'CD',
#                                                       'CG', 'CH', 'CI', 'CL',
#                                                       'CM', 'CO', 'CR', 'CV',
#                                                       'CW', 'CY', 'CZ', 'DE',
#                                                       'DJ', 'DK', 'DM', 'DO',
#                                                       'DZ', 'EC', 'EE', 'EG',
#                                                       'ES', 'FI', 'FJ', 'FM',
#                                                       'FR', 'GA', 'GB', 'GD',
#                                                       'GE', 'GH', 'GM', 'GN',
#                                                       'GQ', 'GR', 'GT', 'GW',
#                                                       'GY', 'HK', 'HN', 'HR',
#                                                       'HT', 'HU', 'ID', 'IE',
#                                                       'IL', 'IN', 'IQ', 'IS',
#                                                       'IT', 'JM', 'JO', 'JP',
#                                                       'KE', 'KG', 'KH', 'KI',
#                                                       'KM', 'KN', 'KR', 'KW',
#                                                       'KZ', 'LA', 'LB', 'LC',
#                                                       'LI', 'LK', 'LR', 'LS',
#                                                       'LT', 'LU', 'LV', 'LY',
#                                                       'MA', 'MC', 'MD', 'ME',
#                                                       'MG', 'MH', 'MK', 'ML',
#                                                       'MN', 'MO', 'MR', 'MT',
#                                                       'MU', 'MV', 'MW', 'MX',
#                                                       'MY', 'MZ', 'NA', 'NE',
#                                                       'NG', 'NI', 'NL', 'NO',
#                                                       'NP', 'NR', 'NZ', 'OM',
#                                                       'PA', 'PE', 'PG', 'PH',
#                                                       'PK', 'PL', 'PS', 'PT',
#                                                       'PW', 'PY', 'QA', 'RO',
#                                                       'RS', 'RW', 'SA', 'SB',
#                                                       'SC', 'SE', 'SG', 'SI',
#                                                       'SK', 'SL', 'SM', 'SN',
#                                                       'SR', 'ST', 'SV', 'SZ',
#                                                       'TD', 'TG', 'TH', 'TJ',
#                                                       'TL', 'TN', 'TO', 'TR',
#                                                       'TT', 'TV', 'TW', 'TZ',
#                                                       'UA', 'UG', 'US', 'UY',
#                                                       'UZ', 'VC', 'VE', 'VN',
#                                                       'VU', 'WS', 'XK', 'ZA',
#                                                       'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/62JUc5rzLwVpGKwpawkTjL'},
#                                 'href': 'https://api.spotify.com/v1/albums/62JUc5rzLwVpGKwpawkTjL',
#                                 'id': '62JUc5rzLwVpGKwpawkTjL',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2736728316f461683601ae5e4eb',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e026728316f461683601ae5e4eb',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048516728316f461683601ae5e4eb',
#                                             'width': 64}],
#                                 'name': 'strawberry chainsaw',
#                                 'release_date': '2022-08-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:62JUc5rzLwVpGKwpawkTjL'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25pd339V2rRJo84USlcSRP'},
#                                    'href': 'https://api.spotify.com/v1/artists/25pd339V2rRJo84USlcSRP',
#                                    'id': '25pd339V2rRJo84USlcSRP',
#                                    'name': 'JAWNY',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:25pd339V2rRJo84USlcSRP'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BZ', 'CA', 'CD', 'CG', 'CH',
#                                             'CI', 'CL', 'CM', 'CO', 'CR', 'CV',
#                                             'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK',
#                                             'DM', 'DO', 'DZ', 'EC', 'EE', 'EG',
#                                             'ES', 'FI', 'FJ', 'FM', 'FR', 'GA',
#                                             'GB', 'GD', 'GE', 'GH', 'GM', 'GN',
#                                             'GQ', 'GR', 'GT', 'GW', 'GY', 'HK',
#                                             'HN', 'HR', 'HT', 'HU', 'ID', 'IE',
#                                             'IL', 'IN', 'IQ', 'IS', 'IT', 'JM',
#                                             'JO', 'JP', 'KE', 'KG', 'KH', 'KI',
#                                             'KM', 'KN', 'KR', 'KW', 'KZ', 'LA',
#                                             'LB', 'LC', 'LI', 'LK', 'LR', 'LS',
#                                             'LT', 'LU', 'LV', 'LY', 'MA', 'MC',
#                                             'MD', 'ME', 'MG', 'MH', 'MK', 'ML',
#                                             'MN', 'MO', 'MR', 'MT', 'MU', 'MV',
#                                             'MW', 'MX', 'MY', 'MZ', 'NA', 'NE',
#                                             'NG', 'NI', 'NL', 'NO', 'NP', 'NR',
#                                             'NZ', 'OM', 'PA', 'PE', 'PG', 'PH',
#                                             'PK', 'PL', 'PS', 'PT', 'PW', 'PY',
#                                             'QA', 'RO', 'RS', 'RW', 'SA', 'SB',
#                                             'SC', 'SE', 'SG', 'SI', 'SK', 'SL',
#                                             'SM', 'SN', 'SR', 'ST', 'SV', 'SZ',
#                                             'TD', 'TG', 'TH', 'TJ', 'TL', 'TN',
#                                             'TO', 'TR', 'TT', 'TV', 'TW', 'TZ',
#                                             'UA', 'UG', 'US', 'UY', 'UZ', 'VC',
#                                             'VE', 'VN', 'VU', 'WS', 'XK', 'ZA',
#                                             'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 156008,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUG12205511'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1hf0PdHw0lnVxq5lfzwjSl'},
#                       'href': 'https://api.spotify.com/v1/tracks/1hf0PdHw0lnVxq5lfzwjSl',
#                       'id': '1hf0PdHw0lnVxq5lfzwjSl',
#                       'is_local': False,
#                       'name': 'strawberry chainsaw',
#                       'popularity': 65,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:1hf0PdHw0lnVxq5lfzwjSl'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-08-12T18:24:50Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#                                              'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#                                              'id': '1McMsnEElThX1knmY4oliG',
#                                              'name': 'Olivia Rodrigo',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#                                 'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#                                 'id': '6s84u2TUpR3wdUv4NgKA2j',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#                                             'width': 64}],
#                                 'name': 'SOUR',
#                                 'release_date': '2021-05-21',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#                                    'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#                                    'id': '1McMsnEElThX1knmY4oliG',
#                                    'name': 'Olivia Rodrigo',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 215506,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USUG12101240'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6HU7h9RYOaPRFeh0R3UeAr'},
#                       'href': 'https://api.spotify.com/v1/tracks/6HU7h9RYOaPRFeh0R3UeAr',
#                       'id': '6HU7h9RYOaPRFeh0R3UeAr',
#                       'is_local': False,
#                       'name': 'deja vu',
#                       'popularity': 88,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:6HU7h9RYOaPRFeh0R3UeAr'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-08-12T18:24:50Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HthCchcL0kVLHTr113Vk1'},
#                                              'href': 'https://api.spotify.com/v1/artists/0HthCchcL0kVLHTr113Vk1',
#                                              'id': '0HthCchcL0kVLHTr113Vk1',
#                                              'name': 'mxmtoon',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0HthCchcL0kVLHTr113Vk1'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BY', 'BZ', 'CA',
#                                                       'CD', 'CG', 'CH', 'CI',
#                                                       'CL', 'CM', 'CO', 'CR',
#                                                       'CV', 'CW', 'CY', 'CZ',
#                                                       'DE', 'DJ', 'DK', 'DM',
#                                                       'DO', 'DZ', 'EC', 'EE',
#                                                       'EG', 'ES', 'FI', 'FJ',
#                                                       'FM', 'FR', 'GA', 'GB',
#                                                       'GD', 'GE', 'GH', 'GM',
#                                                       'GN', 'GQ', 'GR', 'GT',
#                                                       'GW', 'GY', 'HK', 'HN',
#                                                       'HR', 'HT', 'HU', 'ID',
#                                                       'IE', 'IL', 'IN', 'IQ',
#                                                       'IS', 'IT', 'JM', 'JO',
#                                                       'JP', 'KE', 'KG', 'KH',
#                                                       'KI', 'KM', 'KN', 'KR',
#                                                       'KW', 'KZ', 'LA', 'LB',
#                                                       'LC', 'LI', 'LK', 'LR',
#                                                       'LS', 'LT', 'LU', 'LV',
#                                                       'LY', 'MA', 'MC', 'MD',
#                                                       'ME', 'MG', 'MH', 'MK',
#                                                       'ML', 'MN', 'MO', 'MR',
#                                                       'MT', 'MU', 'MV', 'MW',
#                                                       'MX', 'MY', 'MZ', 'NA',
#                                                       'NE', 'NG', 'NI', 'NL',
#                                                       'NO', 'NP', 'NR', 'NZ',
#                                                       'OM', 'PA', 'PE', 'PG',
#                                                       'PH', 'PK', 'PL', 'PS',
#                                                       'PT', 'PW', 'PY', 'QA',
#                                                       'RO', 'RS', 'RW', 'SA',
#                                                       'SB', 'SC', 'SE', 'SG',
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5AVdHQYItgjzDu5qRVmONy'},
#                                 'href': 'https://api.spotify.com/v1/albums/5AVdHQYItgjzDu5qRVmONy',
#                                 'id': '5AVdHQYItgjzDu5qRVmONy',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27360e8cf62e33400b6fc3c05b3',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0260e8cf62e33400b6fc3c05b3',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485160e8cf62e33400b6fc3c05b3',
#                                             'width': 64}],
#                                 'name': 'kaleidoscope',
#                                 'release_date': '2022-08-04',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5AVdHQYItgjzDu5qRVmONy'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HthCchcL0kVLHTr113Vk1'},
#                                    'href': 'https://api.spotify.com/v1/artists/0HthCchcL0kVLHTr113Vk1',
#                                    'id': '0HthCchcL0kVLHTr113Vk1',
#                                    'name': 'mxmtoon',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0HthCchcL0kVLHTr113Vk1'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 185346,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBKPL2207078'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5bD7bhOa64aE8a0vifa5J6'},
#                       'href': 'https://api.spotify.com/v1/tracks/5bD7bhOa64aE8a0vifa5J6',
#                       'id': '5bD7bhOa64aE8a0vifa5J6',
#                       'is_local': False,
#                       'name': 'kaleidoscope',
#                       'popularity': 58,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/0a722a3240a82dadfc6dfdb0fd6b39d834a68c09?cid=1c31402b45784dd489ea18b5c466c5f9',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:5bD7bhOa64aE8a0vifa5J6'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-08-12T18:24:50Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/581C5Qwl87TskfBEzuoisu'},
#                                              'href': 'https://api.spotify.com/v1/artists/581C5Qwl87TskfBEzuoisu',
#                                              'id': '581C5Qwl87TskfBEzuoisu',
#                                              'name': 'Cafuné',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:581C5Qwl87TskfBEzuoisu'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BZ', 'CA', 'CD',
#                                                       'CG', 'CH', 'CI', 'CL',
#                                                       'CM', 'CO', 'CR', 'CV',
#                                                       'CW', 'CY', 'CZ', 'DE',
#                                                       'DJ', 'DK', 'DM', 'DO',
#                                                       'DZ', 'EC', 'EE', 'EG',
#                                                       'ES', 'FI', 'FJ', 'FM',
#                                                       'FR', 'GA', 'GB', 'GD',
#                                                       'GE', 'GH', 'GM', 'GN',
#                                                       'GQ', 'GR', 'GT', 'GW',
#                                                       'GY', 'HK', 'HN', 'HR',
#                                                       'HT', 'HU', 'ID', 'IE',
#                                                       'IL', 'IN', 'IQ', 'IS',
#                                                       'IT', 'JM', 'JO', 'JP',
#                                                       'KE', 'KG', 'KH', 'KI',
#                                                       'KM', 'KN', 'KR', 'KW',
#                                                       'KZ', 'LA', 'LB', 'LC',
#                                                       'LI', 'LK', 'LR', 'LS',
#                                                       'LT', 'LU', 'LV', 'LY',
#                                                       'MA', 'MC', 'MD', 'ME',
#                                                       'MG', 'MH', 'MK', 'ML',
#                                                       'MN', 'MO', 'MR', 'MT',
#                                                       'MU', 'MV', 'MW', 'MX',
#                                                       'MY', 'MZ', 'NA', 'NE',
#                                                       'NG', 'NI', 'NL', 'NO',
#                                                       'NP', 'NR', 'NZ', 'OM',
#                                                       'PA', 'PE', 'PG', 'PH',
#                                                       'PK', 'PL', 'PS', 'PT',
#                                                       'PW', 'PY', 'QA', 'RO',
#                                                       'RS', 'RW', 'SA', 'SB',
#                                                       'SC', 'SE', 'SG', 'SI',
#                                                       'SK', 'SL', 'SM', 'SN',
#                                                       'SR', 'ST', 'SV', 'SZ',
#                                                       'TD', 'TG', 'TH', 'TJ',
#                                                       'TL', 'TN', 'TO', 'TR',
#                                                       'TT', 'TV', 'TW', 'TZ',
#                                                       'UA', 'UG', 'US', 'UY',
#                                                       'UZ', 'VC', 'VE', 'VN',
#                                                       'VU', 'WS', 'XK', 'ZA',
#                                                       'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3Bt2OtHQDRDXC10Flgm9Rv'},
#                                 'href': 'https://api.spotify.com/v1/albums/3Bt2OtHQDRDXC10Flgm9Rv',
#                                 'id': '3Bt2OtHQDRDXC10Flgm9Rv',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27376a3f63eed99d8f4b99f931f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0276a3f63eed99d8f4b99f931f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485176a3f63eed99d8f4b99f931f',
#                                             'width': 64}],
#                                 'name': 'Tek It (I Watch the Moon)',
#                                 'release_date': '2019',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 3,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3Bt2OtHQDRDXC10Flgm9Rv'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/581C5Qwl87TskfBEzuoisu'},
#                                    'href': 'https://api.spotify.com/v1/artists/581C5Qwl87TskfBEzuoisu',
#                                    'id': '581C5Qwl87TskfBEzuoisu',
#                                    'name': 'Cafuné',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:581C5Qwl87TskfBEzuoisu'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BZ', 'CA', 'CD', 'CG', 'CH',
#                                             'CI', 'CL', 'CM', 'CO', 'CR', 'CV',
#                                             'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK',
#                                             'DM', 'DO', 'DZ', 'EC', 'EE', 'EG',
#                                             'ES', 'FI', 'FJ', 'FM', 'FR', 'GA',
#                                             'GB', 'GD', 'GE', 'GH', 'GM', 'GN',
#                                             'GQ', 'GR', 'GT', 'GW', 'GY', 'HK',
#                                             'HN', 'HR', 'HT', 'HU', 'ID', 'IE',
#                                             'IL', 'IN', 'IQ', 'IS', 'IT', 'JM',
#                                             'JO', 'JP', 'KE', 'KG', 'KH', 'KI',
#                                             'KM', 'KN', 'KR', 'KW', 'KZ', 'LA',
#                                             'LB', 'LC', 'LI', 'LK', 'LR', 'LS',
#                                             'LT', 'LU', 'LV', 'LY', 'MA', 'MC',
#                                             'MD', 'ME', 'MG', 'MH', 'MK', 'ML',
#                                             'MN', 'MO', 'MR', 'MT', 'MU', 'MV',
#                                             'MW', 'MX', 'MY', 'MZ', 'NA', 'NE',
#                                             'NG', 'NI', 'NL', 'NO', 'NP', 'NR',
#                                             'NZ', 'OM', 'PA', 'PE', 'PG', 'PH',
#                                             'PK', 'PL', 'PS', 'PT', 'PW', 'PY',
#                                             'QA', 'RO', 'RS', 'RW', 'SA', 'SB',
#                                             'SC', 'SE', 'SG', 'SI', 'SK', 'SL',
#                                             'SM', 'SN', 'SR', 'ST', 'SV', 'SZ',
#                                             'TD', 'TG', 'TH', 'TJ', 'TL', 'TN',
#                                             'TO', 'TR', 'TT', 'TV', 'TW', 'TZ',
#                                             'UA', 'UG', 'US', 'UY', 'UZ', 'VC',
#                                             'VE', 'VN', 'VU', 'WS', 'XK', 'ZA',
#                                             'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 166859,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USEE12200097'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0MnTkIEP4zZN1IUSu8MvIz'},
#                       'href': 'https://api.spotify.com/v1/tracks/0MnTkIEP4zZN1IUSu8MvIz',
#                       'id': '0MnTkIEP4zZN1IUSu8MvIz',
#                       'is_local': False,
#                       'name': 'Tek It - Sped Up',
#                       'popularity': 82,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/69d7a1befd8b3fa3d84544e67035c587881dd4cc?cid=1c31402b45784dd489ea18b5c466c5f9',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0MnTkIEP4zZN1IUSu8MvIz'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-08-19T04:00:00Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3P4vW5tzQvmuoNaFQqzy9q'},
#                                              'href': 'https://api.spotify.com/v1/artists/3P4vW5tzQvmuoNaFQqzy9q',
#                                              'id': '3P4vW5tzQvmuoNaFQqzy9q',
#                                              'name': 'chloe moriondo',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3P4vW5tzQvmuoNaFQqzy9q'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BZ', 'CA', 'CD',
#                                                       'CG', 'CH', 'CI', 'CL',
#                                                       'CM', 'CO', 'CR', 'CV',
#                                                       'CW', 'CY', 'CZ', 'DE',
#                                                       'DJ', 'DK', 'DM', 'DO',
#                                                       'DZ', 'EC', 'EE', 'EG',
#                                                       'ES', 'FI', 'FJ', 'FM',
#                                                       'FR', 'GA', 'GB', 'GD',
#                                                       'GE', 'GH', 'GM', 'GN',
#                                                       'GQ', 'GR', 'GT', 'GW',
#                                                       'GY', 'HK', 'HN', 'HR',
#                                                       'HT', 'HU', 'ID', 'IE',
#                                                       'IL', 'IN', 'IQ', 'IS',
#                                                       'IT', 'JM', 'JO', 'JP',
#                                                       'KE', 'KG', 'KH', 'KI',
#                                                       'KM', 'KN', 'KR', 'KW',
#                                                       'KZ', 'LA', 'LB', 'LC',
#                                                       'LI', 'LK', 'LR', 'LS',
#                                                       'LT', 'LU', 'LV', 'LY',
#                                                       'MA', 'MC', 'MD', 'ME',
#                                                       'MG', 'MH', 'MK', 'ML',
#                                                       'MN', 'MO', 'MR', 'MT',
#                                                       'MU', 'MV', 'MW', 'MX',
#                                                       'MY', 'MZ', 'NA', 'NE',
#                                                       'NG', 'NI', 'NL', 'NO',
#                                                       'NP', 'NR', 'NZ', 'OM',
#                                                       'PA', 'PE', 'PG', 'PH',
#                                                       'PK', 'PL', 'PS', 'PT',
#                                                       'PW', 'PY', 'QA', 'RO',
#                                                       'RS', 'RW', 'SA', 'SB',
#                                                       'SC', 'SE', 'SG', 'SI',
#                                                       'SK', 'SL', 'SM', 'SN',
#                                                       'SR', 'ST', 'SV', 'SZ',
#                                                       'TD', 'TG', 'TH', 'TJ',
#                                                       'TL', 'TN', 'TO', 'TR',
#                                                       'TT', 'TV', 'TW', 'TZ',
#                                                       'UA', 'UG', 'US', 'UY',
#                                                       'UZ', 'VC', 'VE', 'VN',
#                                                       'VU', 'WS', 'XK', 'ZA',
#                                                       'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/63awPWi564xa0E4Y61w2dz'},
#                                 'href': 'https://api.spotify.com/v1/albums/63awPWi564xa0E4Y61w2dz',
#                                 'id': '63awPWi564xa0E4Y61w2dz',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273160c4693ff84d7e7f9e6925e',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02160c4693ff84d7e7f9e6925e',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851160c4693ff84d7e7f9e6925e',
#                                             'width': 64}],
#                                 'name': 'Fruity',
#                                 'release_date': '2022-08-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:63awPWi564xa0E4Y61w2dz'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3P4vW5tzQvmuoNaFQqzy9q'},
#                                    'href': 'https://api.spotify.com/v1/artists/3P4vW5tzQvmuoNaFQqzy9q',
#                                    'id': '3P4vW5tzQvmuoNaFQqzy9q',
#                                    'name': 'chloe moriondo',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3P4vW5tzQvmuoNaFQqzy9q'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BZ', 'CA', 'CD', 'CG', 'CH',
#                                             'CI', 'CL', 'CM', 'CO', 'CR', 'CV',
#                                             'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK',
#                                             'DM', 'DO', 'DZ', 'EC', 'EE', 'EG',
#                                             'ES', 'FI', 'FJ', 'FM', 'FR', 'GA',
#                                             'GB', 'GD', 'GE', 'GH', 'GM', 'GN',
#                                             'GQ', 'GR', 'GT', 'GW', 'GY', 'HK',
#                                             'HN', 'HR', 'HT', 'HU', 'ID', 'IE',
#                                             'IL', 'IN', 'IQ', 'IS', 'IT', 'JM',
#                                             'JO', 'JP', 'KE', 'KG', 'KH', 'KI',
#                                             'KM', 'KN', 'KR', 'KW', 'KZ', 'LA',
#                                             'LB', 'LC', 'LI', 'LK', 'LR', 'LS',
#                                             'LT', 'LU', 'LV', 'LY', 'MA', 'MC',
#                                             'MD', 'ME', 'MG', 'MH', 'MK', 'ML',
#                                             'MN', 'MO', 'MR', 'MT', 'MU', 'MV',
#                                             'MW', 'MX', 'MY', 'MZ', 'NA', 'NE',
#                                             'NG', 'NI', 'NL', 'NO', 'NP', 'NR',
#                                             'NZ', 'OM', 'PA', 'PE', 'PG', 'PH',
#                                             'PK', 'PL', 'PS', 'PT', 'PW', 'PY',
#                                             'QA', 'RO', 'RS', 'RW', 'SA', 'SB',
#                                             'SC', 'SE', 'SG', 'SI', 'SK', 'SL',
#                                             'SM', 'SN', 'SR', 'ST', 'SV', 'SZ',
# ...
#                                                       'SI', 'SK', 'SL', 'SM',
#                                                       'SN', 'SR', 'ST', 'SV',
#                                                       'SZ', 'TD', 'TG', 'TH',
#                                                       'TJ', 'TL', 'TN', 'TO',
#                                                       'TR', 'TT', 'TV', 'TW',
#                                                       'TZ', 'UA', 'UG', 'US',
#                                                       'UY', 'UZ', 'VC', 'VE',
#                                                       'VN', 'VU', 'WS', 'XK',
#                                                       'ZA', 'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3qr8WlrGBQMrzpRL6ERL4B'},
#                                 'href': 'https://api.spotify.com/v1/albums/3qr8WlrGBQMrzpRL6ERL4B',
#                                 'id': '3qr8WlrGBQMrzpRL6ERL4B',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273bfbfb0955132f5fc8051d30d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02bfbfb0955132f5fc8051d30d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851bfbfb0955132f5fc8051d30d',
#                                             'width': 64}],
#                                 'name': 'Peaceful In My Mind',
#                                 'release_date': '2021-11-10',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3qr8WlrGBQMrzpRL6ERL4B'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anAI9P9iSzc9qzLv6AtHZ'},
#                                    'href': 'https://api.spotify.com/v1/artists/1anAI9P9iSzc9qzLv6AtHZ',
#                                    'id': '1anAI9P9iSzc9qzLv6AtHZ',
#                                    'name': 'Sure Sure',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1anAI9P9iSzc9qzLv6AtHZ'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BY', 'BZ', 'CA', 'CD', 'CG',
#                                             'CH', 'CI', 'CL', 'CM', 'CO', 'CR',
#                                             'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ',
#                                             'DK', 'DM', 'DO', 'DZ', 'EC', 'EE',
#                                             'EG', 'ES', 'FI', 'FJ', 'FM', 'FR',
#                                             'GA', 'GB', 'GD', 'GE', 'GH', 'GM',
#                                             'GN', 'GQ', 'GR', 'GT', 'GW', 'GY',
#                                             'HK', 'HN', 'HR', 'HT', 'HU', 'ID',
#                                             'IE', 'IL', 'IN', 'IQ', 'IS', 'IT',
#                                             'JM', 'JO', 'JP', 'KE', 'KG', 'KH',
#                                             'KI', 'KM', 'KN', 'KR', 'KW', 'KZ',
#                                             'LA', 'LB', 'LC', 'LI', 'LK', 'LR',
#                                             'LS', 'LT', 'LU', 'LV', 'LY', 'MA',
#                                             'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#                                             'ML', 'MN', 'MO', 'MR', 'MT', 'MU',
#                                             'MV', 'MW', 'MX', 'MY', 'MZ', 'NA',
#                                             'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
#                                             'NR', 'NZ', 'OM', 'PA', 'PE', 'PG',
#                                             'PH', 'PK', 'PL', 'PS', 'PT', 'PW',
#                                             'PY', 'QA', 'RO', 'RS', 'RW', 'SA',
#                                             'SB', 'SC', 'SE', 'SG', 'SI', 'SK',
#                                             'SL', 'SM', 'SN', 'SR', 'ST', 'SV',
#                                             'SZ', 'TD', 'TG', 'TH', 'TJ', 'TL',
#                                             'TN', 'TO', 'TR', 'TT', 'TV', 'TW',
#                                             'TZ', 'UA', 'UG', 'US', 'UY', 'UZ',
#                                             'VC', 'VE', 'VN', 'VU', 'WS', 'XK',
#                                             'ZA', 'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 169717,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'QM24S2106639'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6pQcqaoZlGKF3zvglt6tvc'},
#                       'href': 'https://api.spotify.com/v1/tracks/6pQcqaoZlGKF3zvglt6tvc',
#                       'id': '6pQcqaoZlGKF3zvglt6tvc',
#                       'is_local': False,
#                       'name': 'Peaceful In My Mind',
#                       'popularity': 57,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/fe9cdd5a86938c4d05656fbb45603d42556097c5?cid=1c31402b45784dd489ea18b5c466c5f9',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6pQcqaoZlGKF3zvglt6tvc'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-08-12T18:24:50Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO'},
#                                              'href': 'https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO',
#                                              'id': '5FxD8fkQZ6KcsSYupDVoSO',
#                                              'name': 'Omar Apollo',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5FxD8fkQZ6KcsSYupDVoSO'}],
#                                 'available_markets': ['AD', 'AE', 'AG', 'AL',
#                                                       'AM', 'AO', 'AR', 'AT',
#                                                       'AU', 'AZ', 'BA', 'BB',
#                                                       'BD', 'BE', 'BF', 'BG',
#                                                       'BH', 'BI', 'BJ', 'BN',
#                                                       'BO', 'BR', 'BS', 'BT',
#                                                       'BW', 'BZ', 'CA', 'CD',
#                                                       'CG', 'CH', 'CI', 'CL',
#                                                       'CM', 'CO', 'CR', 'CV',
#                                                       'CW', 'CY', 'CZ', 'DE',
#                                                       'DJ', 'DK', 'DM', 'DO',
#                                                       'DZ', 'EC', 'EE', 'EG',
#                                                       'ES', 'FI', 'FJ', 'FM',
#                                                       'FR', 'GA', 'GB', 'GD',
#                                                       'GE', 'GH', 'GM', 'GN',
#                                                       'GQ', 'GR', 'GT', 'GW',
#                                                       'GY', 'HK', 'HN', 'HR',
#                                                       'HT', 'HU', 'ID', 'IE',
#                                                       'IL', 'IN', 'IQ', 'IS',
#                                                       'IT', 'JM', 'JO', 'JP',
#                                                       'KE', 'KG', 'KH', 'KI',
#                                                       'KM', 'KN', 'KR', 'KW',
#                                                       'KZ', 'LA', 'LB', 'LC',
#                                                       'LI', 'LK', 'LR', 'LS',
#                                                       'LT', 'LU', 'LV', 'LY',
#                                                       'MA', 'MC', 'MD', 'ME',
#                                                       'MG', 'MH', 'MK', 'ML',
#                                                       'MN', 'MO', 'MR', 'MT',
#                                                       'MU', 'MV', 'MW', 'MX',
#                                                       'MY', 'MZ', 'NA', 'NE',
#                                                       'NG', 'NI', 'NL', 'NO',
#                                                       'NP', 'NR', 'NZ', 'OM',
#                                                       'PA', 'PE', 'PG', 'PH',
#                                                       'PK', 'PL', 'PS', 'PT',
#                                                       'PW', 'PY', 'QA', 'RO',
#                                                       'RS', 'RW', 'SA', 'SB',
#                                                       'SC', 'SE', 'SG', 'SI',
#                                                       'SK', 'SL', 'SM', 'SN',
#                                                       'SR', 'ST', 'SV', 'SZ',
#                                                       'TD', 'TG', 'TH', 'TJ',
#                                                       'TL', 'TN', 'TO', 'TR',
#                                                       'TT', 'TV', 'TW', 'TZ',
#                                                       'UA', 'UG', 'US', 'UY',
#                                                       'UZ', 'VC', 'VE', 'VN',
#                                                       'VU', 'WS', 'XK', 'ZA',
#                                                       'ZM', 'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5z7TD11Qh81Gbf52hd5zAv'},
#                                 'href': 'https://api.spotify.com/v1/albums/5z7TD11Qh81Gbf52hd5zAv',
#                                 'id': '5z7TD11Qh81Gbf52hd5zAv',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27390cf5d1ccfca2beb86149a19',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0290cf5d1ccfca2beb86149a19',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485190cf5d1ccfca2beb86149a19',
#                                             'width': 64}],
#                                 'name': 'Ivory',
#                                 'release_date': '2022-04-08',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5z7TD11Qh81Gbf52hd5zAv'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO'},
#                                    'href': 'https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO',
#                                    'id': '5FxD8fkQZ6KcsSYupDVoSO',
#                                    'name': 'Omar Apollo',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5FxD8fkQZ6KcsSYupDVoSO'}],
#                       'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO',
#                                             'AR', 'AT', 'AU', 'AZ', 'BA', 'BB',
#                                             'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#                                             'BJ', 'BN', 'BO', 'BR', 'BS', 'BT',
#                                             'BW', 'BZ', 'CA', 'CD', 'CG', 'CH',
#                                             'CI', 'CL', 'CM', 'CO', 'CR', 'CV',
#                                             'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK',
#                                             'DM', 'DO', 'DZ', 'EC', 'EE', 'EG',
#                                             'ES', 'FI', 'FJ', 'FM', 'FR', 'GA',
#                                             'GB', 'GD', 'GE', 'GH', 'GM', 'GN',
#                                             'GQ', 'GR', 'GT', 'GW', 'GY', 'HK',
#                                             'HN', 'HR', 'HT', 'HU', 'ID', 'IE',
#                                             'IL', 'IN', 'IQ', 'IS', 'IT', 'JM',
#                                             'JO', 'JP', 'KE', 'KG', 'KH', 'KI',
#                                             'KM', 'KN', 'KR', 'KW', 'KZ', 'LA',
#                                             'LB', 'LC', 'LI', 'LK', 'LR', 'LS',
#                                             'LT', 'LU', 'LV', 'LY', 'MA', 'MC',
#                                             'MD', 'ME', 'MG', 'MH', 'MK', 'ML',
#                                             'MN', 'MO', 'MR', 'MT', 'MU', 'MV',
#                                             'MW', 'MX', 'MY', 'MZ', 'NA', 'NE',
#                                             'NG', 'NI', 'NL', 'NO', 'NP', 'NR',
#                                             'NZ', 'OM', 'PA', 'PE', 'PG', 'PH',
#                                             'PK', 'PL', 'PS', 'PT', 'PW', 'PY',
#                                             'QA', 'RO', 'RS', 'RW', 'SA', 'SB',
#                                             'SC', 'SE', 'SG', 'SI', 'SK', 'SL',
#                                             'SM', 'SN', 'SR', 'ST', 'SV', 'SZ',
#                                             'TD', 'TG', 'TH', 'TJ', 'TL', 'TN',
#                                             'TO', 'TR', 'TT', 'TV', 'TW', 'TZ',
#                                             'UA', 'UG', 'US', 'UY', 'UZ', 'VC',
#                                             'VE', 'VN', 'VU', 'WS', 'XK', 'ZA',
#                                             'ZM', 'ZW'],
#                       'disc_number': 1,
#                       'duration_ms': 197453,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USWB12200272'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0G41EUi3xiwUR6iOtXAQCz'},
#                       'href': 'https://api.spotify.com/v1/tracks/0G41EUi3xiwUR6iOtXAQCz',
#                       'id': '0G41EUi3xiwUR6iOtXAQCz',
#                       'is_local': False,
#                       'name': 'Petrified',
#                       'popularity': 56,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/a08f4b89ff53711d5c3e04cf436320519fc18d1e?cid=1c31402b45784dd489ea18b5c466c5f9',
#                       'track': True,
#                       'track_number': 9,
#                       'type': 'track',
#                       'uri': 'spotify:track:0G41EUi3xiwUR6iOtXAQCz'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 75}

# %% [markdown]
# ### audio_features
# Get audio features for one or multiple tracks based upon their Spotify IDs Parameters
# > audio_features(tracks=[])
#
# - tracks - a list of track URIs, URLs or IDs, maximum: 100 ids

# %%
playlist_info = sp.audio_features(track_uris)

# %%
playlist_info
# Out:
# [{'danceability': 0.615,
#   'energy': 0.879,
#   'key': 5,
#   'loudness': -3.977,
#   'mode': 1,
#   'speechiness': 0.0451,
#   'acousticness': 0.234,
#   'instrumentalness': 2.35e-05,
#   'liveness': 0.422,
#   'valence': 0.627,
#   'tempo': 100.028,
#   'type': 'audio_features',
#   'id': '1hf0PdHw0lnVxq5lfzwjSl',
#   'uri': 'spotify:track:1hf0PdHw0lnVxq5lfzwjSl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1hf0PdHw0lnVxq5lfzwjSl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1hf0PdHw0lnVxq5lfzwjSl',
#   'duration_ms': 156008,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.612,
#   'key': 2,
#   'loudness': -7.222,
#   'mode': 1,
#   'speechiness': 0.112,
#   'acousticness': 0.584,
#   'instrumentalness': 5.7e-06,
#   'liveness': 0.37,
#   'valence': 0.178,
#   'tempo': 180.917,
#   'type': 'audio_features',
#   'id': '6HU7h9RYOaPRFeh0R3UeAr',
#   'uri': 'spotify:track:6HU7h9RYOaPRFeh0R3UeAr',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HU7h9RYOaPRFeh0R3UeAr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HU7h9RYOaPRFeh0R3UeAr',
#   'duration_ms': 215507,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.741,
#   'key': 10,
#   'loudness': -5.53,
#   'mode': 1,
#   'speechiness': 0.0328,
#   'acousticness': 0.182,
#   'instrumentalness': 0.000474,
#   'liveness': 0.0662,
#   'valence': 0.763,
#   'tempo': 99.99,
#   'type': 'audio_features',
#   'id': '5bD7bhOa64aE8a0vifa5J6',
#   'uri': 'spotify:track:5bD7bhOa64aE8a0vifa5J6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5bD7bhOa64aE8a0vifa5J6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bD7bhOa64aE8a0vifa5J6',
#   'duration_ms': 185347,
#   'time_signature': 4},
#  {'danceability': 0.348,
#   'energy': 0.95,
#   'key': 10,
#   'loudness': -5.049,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 9.93e-05,
#   'instrumentalness': 9.68e-06,
#   'liveness': 0.0868,
#   'valence': 0.377,
#   'tempo': 168.964,
#   'type': 'audio_features',
#   'id': '0MnTkIEP4zZN1IUSu8MvIz',
#   'uri': 'spotify:track:0MnTkIEP4zZN1IUSu8MvIz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MnTkIEP4zZN1IUSu8MvIz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MnTkIEP4zZN1IUSu8MvIz',
#   'duration_ms': 166859,
#   'time_signature': 4},
#  {'danceability': 0.666,
#   'energy': 0.652,
#   'key': 7,
#   'loudness': -5.956,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.00635,
#   'instrumentalness': 2.13e-05,
#   'liveness': 0.221,
#   'valence': 0.666,
#   'tempo': 128.028,
#   'type': 'audio_features',
#   'id': '4XVPArAtSq0657KUF0vXRy',
#   'uri': 'spotify:track:4XVPArAtSq0657KUF0vXRy',
#   'track_href': 'https://api.spotify.com/v1/tracks/4XVPArAtSq0657KUF0vXRy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4XVPArAtSq0657KUF0vXRy',
#   'duration_ms': 193133,
#   'time_signature': 4},
#  {'danceability': 0.744,
#   'energy': 0.619,
#   'key': 0,
#   'loudness': -9.805,
#   'mode': 1,
#   'speechiness': 0.039,
#   'acousticness': 0.598,
#   'instrumentalness': 0.00372,
#   'liveness': 0.231,
#   'valence': 0.641,
#   'tempo': 112.997,
#   'type': 'audio_features',
#   'id': '7B3z0ySL9Rr0XvZEAjWZzM',
#   'uri': 'spotify:track:7B3z0ySL9Rr0XvZEAjWZzM',
#   'track_href': 'https://api.spotify.com/v1/tracks/7B3z0ySL9Rr0XvZEAjWZzM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7B3z0ySL9Rr0XvZEAjWZzM',
#   'duration_ms': 188387,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.818,
#   'key': 2,
#   'loudness': -3.061,
#   'mode': 1,
#   'speechiness': 0.0332,
#   'acousticness': 0.019,
#   'instrumentalness': 2.42e-05,
#   'liveness': 0.0807,
#   'valence': 0.965,
#   'tempo': 140.019,
#   'type': 'audio_features',
#   'id': '5RaThsdZpF9WWwoP00NjLI',
#   'uri': 'spotify:track:5RaThsdZpF9WWwoP00NjLI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5RaThsdZpF9WWwoP00NjLI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RaThsdZpF9WWwoP00NjLI',
#   'duration_ms': 183440,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.489,
#   'key': 0,
#   'loudness': -9.997,
#   'mode': 1,
#   'speechiness': 0.241,
#   'acousticness': 0.076,
#   'instrumentalness': 0.00152,
#   'liveness': 0.123,
#   'valence': 0.504,
#   'tempo': 96.039,
#   'type': 'audio_features',
#   'id': '7N1bEUVuQo8HHuikDgJ10c',
#   'uri': 'spotify:track:7N1bEUVuQo8HHuikDgJ10c',
#   'track_href': 'https://api.spotify.com/v1/tracks/7N1bEUVuQo8HHuikDgJ10c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7N1bEUVuQo8HHuikDgJ10c',
#   'duration_ms': 114375,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.471,
#   'key': 10,
#   'loudness': -9.247,
#   'mode': 1,
#   'speechiness': 0.157,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.455,
#   'tempo': 170.084,
#   'type': 'audio_features',
#   'id': '3nOz1U41SZZ0N3fuUWr9nb',
#   'uri': 'spotify:track:3nOz1U41SZZ0N3fuUWr9nb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3nOz1U41SZZ0N3fuUWr9nb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nOz1U41SZZ0N3fuUWr9nb',
#   'duration_ms': 232813,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.596,
#   'key': 9,
#   'loudness': -7.64,
#   'mode': 0,
#   'speechiness': 0.0428,
#   'acousticness': 0.254,
#   'instrumentalness': 2.06e-05,
#   'liveness': 0.151,
#   'valence': 0.797,
#   'tempo': 81.001,
#   'type': 'audio_features',
#   'id': '3MwKRb5GB9phdL9ktdvBsv',
#   'uri': 'spotify:track:3MwKRb5GB9phdL9ktdvBsv',
#   'track_href': 'https://api.spotify.com/v1/tracks/3MwKRb5GB9phdL9ktdvBsv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MwKRb5GB9phdL9ktdvBsv',
#   'duration_ms': 192593,
#   'time_signature': 4},
#  {'danceability': 0.86,
#   'energy': 0.422,
#   'key': 1,
#   'loudness': -9.785,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.541,
#   'instrumentalness': 0.00449,
#   'liveness': 0.139,
#   'valence': 0.523,
#   'tempo': 99.958,
#   'type': 'audio_features',
#   'id': '5o9iQVktO08gIlRAHqqxtj',
#   'uri': 'spotify:track:5o9iQVktO08gIlRAHqqxtj',
#   'track_href': 'https://api.spotify.com/v1/tracks/5o9iQVktO08gIlRAHqqxtj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5o9iQVktO08gIlRAHqqxtj',
#   'duration_ms': 106800,
#   'time_signature': 4},
#  {'danceability': 0.512,
#   'energy': 0.483,
#   'key': 0,
#   'loudness': -7.798,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.00304,
#   'instrumentalness': 0.0011,
#   'liveness': 0.12,
#   'valence': 0.367,
#   'tempo': 160.009,
#   'type': 'audio_features',
#   'id': '0VF7YLIxSQKyNiFL3X6MmN',
#   'uri': 'spotify:track:0VF7YLIxSQKyNiFL3X6MmN',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VF7YLIxSQKyNiFL3X6MmN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VF7YLIxSQKyNiFL3X6MmN',
#   'duration_ms': 217027,
#   'time_signature': 4},
#  {'danceability': 0.53,
#   'energy': 0.593,
#   'key': 5,
#   'loudness': -7.286,
#   'mode': 1,
#   'speechiness': 0.0545,
#   'acousticness': 0.385,
#   'instrumentalness': 0,
#   'liveness': 0.314,
#   'valence': 0.538,
#   'tempo': 125.723,
#   'type': 'audio_features',
#   'id': '4JeOesjcWWlprTAvucDSJX',
#   'uri': 'spotify:track:4JeOesjcWWlprTAvucDSJX',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JeOesjcWWlprTAvucDSJX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JeOesjcWWlprTAvucDSJX',
#   'duration_ms': 158537,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.416,
#   'key': 7,
#   'loudness': -9.504,
#   'mode': 1,
#   'speechiness': 0.433,
#   'acousticness': 0.912,
#   'instrumentalness': 0,
#   'liveness': 0.0934,
#   'valence': 0.433,
#   'tempo': 175.191,
#   'type': 'audio_features',
#   'id': '0KQRhak4Irr2CKxgQ9U6ay',
#   'uri': 'spotify:track:0KQRhak4Irr2CKxgQ9U6ay',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KQRhak4Irr2CKxgQ9U6ay',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KQRhak4Irr2CKxgQ9U6ay',
#   'duration_ms': 143960,
#   'time_signature': 3},
#  {'danceability': 0.728,
#   'energy': 0.82,
#   'key': 11,
#   'loudness': -6.198,
#   'mode': 0,
#   'speechiness': 0.031,
#   'acousticness': 0.00898,
#   'instrumentalness': 0.000216,
#   'liveness': 0.176,
#   'valence': 0.652,
#   'tempo': 124.001,
#   'type': 'audio_features',
#   'id': '6Ql7rNuoP90aIdgwQkPYBP',
#   'uri': 'spotify:track:6Ql7rNuoP90aIdgwQkPYBP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Ql7rNuoP90aIdgwQkPYBP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Ql7rNuoP90aIdgwQkPYBP',
#   'duration_ms': 164577,
#   'time_signature': 4},
#  {'danceability': 0.875,
#   'energy': 0.649,
#   'key': 6,
#   'loudness': -5.754,
#   'mode': 1,
#   'speechiness': 0.0433,
#   'acousticness': 0.429,
#   'instrumentalness': 0.00237,
#   'liveness': 0.0704,
#   'valence': 0.833,
#   'tempo': 140.031,
#   'type': 'audio_features',
#   'id': '0brBOx8ejPXvBYnQkWquYK',
#   'uri': 'spotify:track:0brBOx8ejPXvBYnQkWquYK',
#   'track_href': 'https://api.spotify.com/v1/tracks/0brBOx8ejPXvBYnQkWquYK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0brBOx8ejPXvBYnQkWquYK',
#   'duration_ms': 194693,
#   'time_signature': 4},
#  {'danceability': 0.54,
#   'energy': 0.11,
#   'key': 8,
#   'loudness': -19.885,
#   'mode': 1,
#   'speechiness': 0.0328,
#   'acousticness': 0.498,
#   'instrumentalness': 0.000614,
#   'liveness': 0.0781,
#   'valence': 0.172,
#   'tempo': 76.068,
#   'type': 'audio_features',
#   'id': '7LNm1oWd6PniO9wRYpNY5o',
#   'uri': 'spotify:track:7LNm1oWd6PniO9wRYpNY5o',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LNm1oWd6PniO9wRYpNY5o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LNm1oWd6PniO9wRYpNY5o',
#   'duration_ms': 290132,
#   'time_signature': 4},
#  {'danceability': 0.619,
#   'energy': 0.736,
#   'key': 11,
#   'loudness': -7.651,
#   'mode': 1,
#   'speechiness': 0.0425,
#   'acousticness': 0.0328,
#   'instrumentalness': 0,
#   'liveness': 0.0864,
#   'valence': 0.299,
#   'tempo': 93.993,
#   'type': 'audio_features',
#   'id': '0ohcCrxZkBfFbkuRPOZQZX',
#   'uri': 'spotify:track:0ohcCrxZkBfFbkuRPOZQZX',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ohcCrxZkBfFbkuRPOZQZX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ohcCrxZkBfFbkuRPOZQZX',
#   'duration_ms': 208600,
#   'time_signature': 4},
#  {'danceability': 0.759,
#   'energy': 0.665,
#   'key': 2,
#   'loudness': -6.338,
#   'mode': 1,
#   'speechiness': 0.0861,
#   'acousticness': 0.494,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.391,
#   'tempo': 125.056,
#   'type': 'audio_features',
#   'id': '5meVa5klVlJalupZTvv5XX',
#   'uri': 'spotify:track:5meVa5klVlJalupZTvv5XX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5meVa5klVlJalupZTvv5XX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5meVa5klVlJalupZTvv5XX',
#   'duration_ms': 185173,
#   'time_signature': 4},
#  {'danceability': 0.471,
#   'energy': 0.335,
#   'key': 4,
#   'loudness': -8.767,
#   'mode': 0,
#   'speechiness': 0.0273,
#   'acousticness': 0.593,
#   'instrumentalness': 2.11e-05,
#   'liveness': 0.297,
#   'valence': 0.111,
#   'tempo': 145.252,
#   'type': 'audio_features',
#   'id': '0KmgJyW4GDgonqsoyx0CZ3',
#   'uri': 'spotify:track:0KmgJyW4GDgonqsoyx0CZ3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KmgJyW4GDgonqsoyx0CZ3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KmgJyW4GDgonqsoyx0CZ3',
#   'duration_ms': 243907,
#   'time_signature': 3},
#  {'danceability': 0.586,
#   'energy': 0.744,
#   'key': 4,
#   'loudness': -10.142,
#   'mode': 1,
#   'speechiness': 0.0508,
#   'acousticness': 0.00614,
#   'instrumentalness': 0.000172,
#   'liveness': 0.372,
#   'valence': 0.523,
#   'tempo': 117.006,
#   'type': 'audio_features',
#   'id': '7rC3P7tpWriaC4hYWKwGQd',
#   'uri': 'spotify:track:7rC3P7tpWriaC4hYWKwGQd',
#   'track_href': 'https://api.spotify.com/v1/tracks/7rC3P7tpWriaC4hYWKwGQd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rC3P7tpWriaC4hYWKwGQd',
#   'duration_ms': 162560,
#   'time_signature': 4},
#  {'danceability': 0.674,
#   'energy': 0.595,
#   'key': 4,
#   'loudness': -5.18,
#   'mode': 1,
#   'speechiness': 0.0365,
#   'acousticness': 0.358,
#   'instrumentalness': 0,
#   'liveness': 0.146,
#   'valence': 0.207,
#   'tempo': 81.045,
#   'type': 'audio_features',
#   'id': '7a4YwlUER1m7rkWJjYJRAD',
#   'uri': 'spotify:track:7a4YwlUER1m7rkWJjYJRAD',
#   'track_href': 'https://api.spotify.com/v1/tracks/7a4YwlUER1m7rkWJjYJRAD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7a4YwlUER1m7rkWJjYJRAD',
#   'duration_ms': 198010,
#   'time_signature': 4},
#  {'danceability': 0.318,
#   'energy': 0.476,
#   'key': 0,
#   'loudness': -7.108,
#   'mode': 1,
#   'speechiness': 0.0441,
#   'acousticness': 0.454,
#   'instrumentalness': 1.57e-05,
#   'liveness': 0.503,
#   'valence': 0.0807,
#   'tempo': 160.737,
#   'type': 'audio_features',
#   'id': '1VyA8mbSyXOdJx2lguR8Uu',
#   'uri': 'spotify:track:1VyA8mbSyXOdJx2lguR8Uu',
#   'track_href': 'https://api.spotify.com/v1/tracks/1VyA8mbSyXOdJx2lguR8Uu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1VyA8mbSyXOdJx2lguR8Uu',
#   'duration_ms': 166137,
#   'time_signature': 4},
#  {'danceability': 0.796,
#   'energy': 0.727,
#   'key': 1,
#   'loudness': -4.726,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.793,
#   'instrumentalness': 2.49e-05,
#   'liveness': 0.0858,
#   'valence': 0.818,
#   'tempo': 104.98,
#   'type': 'audio_features',
#   'id': '5MG69A9XyXDbBbeOxdR3Tl',
#   'uri': 'spotify:track:5MG69A9XyXDbBbeOxdR3Tl',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MG69A9XyXDbBbeOxdR3Tl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MG69A9XyXDbBbeOxdR3Tl',
#   'duration_ms': 123950,
#   'time_signature': 4},
#  {'danceability': 0.534,
#   'energy': 0.87,
#   'key': 9,
#   'loudness': -4.428,
#   'mode': 0,
#   'speechiness': 0.075,
#   'acousticness': 0.00127,
#   'instrumentalness': 0,
#   'liveness': 0.355,
#   'valence': 0.328,
#   'tempo': 121.841,
#   'type': 'audio_features',
#   'id': '0vQYe6g8bNbdUKnUnXdQQV',
#   'uri': 'spotify:track:0vQYe6g8bNbdUKnUnXdQQV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0vQYe6g8bNbdUKnUnXdQQV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0vQYe6g8bNbdUKnUnXdQQV',
#   'duration_ms': 177511,
#   'time_signature': 4},
#  {'danceability': 0.801,
#   'energy': 0.589,
#   'key': 7,
#   'loudness': -5.157,
#   'mode': 1,
#   'speechiness': 0.0485,
#   'acousticness': 0.0863,
#   'instrumentalness': 0,
#   'liveness': 0.162,
#   'valence': 0.58,
#   'tempo': 116.934,
#   'type': 'audio_features',
#   'id': '23TPP1eeElFfvYVznskwCY',
#   'uri': 'spotify:track:23TPP1eeElFfvYVznskwCY',
#   'track_href': 'https://api.spotify.com/v1/tracks/23TPP1eeElFfvYVznskwCY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23TPP1eeElFfvYVznskwCY',
#   'duration_ms': 180147,
#   'time_signature': 4},
#  {'danceability': 0.742,
#   'energy': 0.521,
#   'key': 0,
#   'loudness': -6.844,
#   'mode': 1,
#   'speechiness': 0.0441,
#   'acousticness': 0.0252,
#   'instrumentalness': 0.023,
#   'liveness': 0.581,
#   'valence': 0.646,
#   'tempo': 125.032,
#   'type': 'audio_features',
#   'id': '252G7yirQ4pXj6ZD4T9R2W',
#   'uri': 'spotify:track:252G7yirQ4pXj6ZD4T9R2W',
#   'track_href': 'https://api.spotify.com/v1/tracks/252G7yirQ4pXj6ZD4T9R2W',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/252G7yirQ4pXj6ZD4T9R2W',
#   'duration_ms': 172112,
#   'time_signature': 4},
#  {'danceability': 0.765,
#   'energy': 0.582,
#   'key': 0,
#   'loudness': -4.528,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.245,
#   'instrumentalness': 8.21e-05,
#   'liveness': 0.154,
#   'valence': 0.36,
#   'tempo': 132.992,
#   'type': 'audio_features',
#   'id': '0PLhwCmQ7cC3ThRGPn3HxF',
#   'uri': 'spotify:track:0PLhwCmQ7cC3ThRGPn3HxF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0PLhwCmQ7cC3ThRGPn3HxF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PLhwCmQ7cC3ThRGPn3HxF',
#   'duration_ms': 171280,
#   'time_signature': 4},
#  {'danceability': 0.581,
#   'energy': 0.832,
#   'key': 6,
#   'loudness': -5.48,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'acousticness': 0.0753,
#   'instrumentalness': 0,
#   'liveness': 0.0773,
#   'valence': 0.678,
#   'tempo': 99.908,
#   'type': 'audio_features',
#   'id': '5BCYtpbTyUQSMRwDVPb5wk',
#   'uri': 'spotify:track:5BCYtpbTyUQSMRwDVPb5wk',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BCYtpbTyUQSMRwDVPb5wk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BCYtpbTyUQSMRwDVPb5wk',
#   'duration_ms': 218053,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.841,
#   'key': 8,
#   'loudness': -5.374,
#   'mode': 1,
#   'speechiness': 0.0359,
#   'acousticness': 0.00853,
#   'instrumentalness': 0.00504,
#   'liveness': 0.245,
#   'valence': 0.556,
#   'tempo': 173.05,
#   'type': 'audio_features',
#   'id': '1h8dms5lJ4QcXB0tyguk4c',
#   'uri': 'spotify:track:1h8dms5lJ4QcXB0tyguk4c',
#   'track_href': 'https://api.spotify.com/v1/tracks/1h8dms5lJ4QcXB0tyguk4c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1h8dms5lJ4QcXB0tyguk4c',
#   'duration_ms': 187093,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.664,
#   'key': 0,
#   'loudness': -7.713,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.305,
#   'instrumentalness': 2.29e-05,
#   'liveness': 0.143,
#   'valence': 0.727,
#   'tempo': 111.933,
#   'type': 'audio_features',
#   'id': '7n6QMW76A5qgfn0Mb4aL7i',
#   'uri': 'spotify:track:7n6QMW76A5qgfn0Mb4aL7i',
#   'track_href': 'https://api.spotify.com/v1/tracks/7n6QMW76A5qgfn0Mb4aL7i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7n6QMW76A5qgfn0Mb4aL7i',
#   'duration_ms': 213855,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.526,
#   'key': 8,
#   'loudness': -7.241,
#   'mode': 1,
#   'speechiness': 0.0986,
#   'acousticness': 0.229,
#   'instrumentalness': 4.56e-05,
#   'liveness': 0.309,
#   'valence': 0.786,
#   'tempo': 110.02,
#   'type': 'audio_features',
#   'id': '4aHrviUXxabPdIgWxdYQLt',
#   'uri': 'spotify:track:4aHrviUXxabPdIgWxdYQLt',
#   'track_href': 'https://api.spotify.com/v1/tracks/4aHrviUXxabPdIgWxdYQLt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4aHrviUXxabPdIgWxdYQLt',
#   'duration_ms': 176481,
#   'time_signature': 4},
#  {'danceability': 0.913,
#   'energy': 0.459,
#   'key': 5,
#   'loudness': -7.528,
#   'mode': 1,
#   'speechiness': 0.0446,
#   'acousticness': 0.469,
#   'instrumentalness': 0.000889,
#   'liveness': 0.0891,
#   'valence': 0.848,
#   'tempo': 114.996,
#   'type': 'audio_features',
#   'id': '2F9DCIJ7ZXHhNkiIlIIOkw',
#   'uri': 'spotify:track:2F9DCIJ7ZXHhNkiIlIIOkw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2F9DCIJ7ZXHhNkiIlIIOkw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2F9DCIJ7ZXHhNkiIlIIOkw',
#   'duration_ms': 215385,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.71,
#   'key': 0,
#   'loudness': -6.657,
#   'mode': 1,
#   'speechiness': 0.0424,
#   'acousticness': 0.0118,
#   'instrumentalness': 0.00111,
#   'liveness': 0.149,
#   'valence': 0.262,
#   'tempo': 83.026,
#   'type': 'audio_features',
#   'id': '7GtOjSSp5Qyi3gNbNDZgja',
#   'uri': 'spotify:track:7GtOjSSp5Qyi3gNbNDZgja',
#   'track_href': 'https://api.spotify.com/v1/tracks/7GtOjSSp5Qyi3gNbNDZgja',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GtOjSSp5Qyi3gNbNDZgja',
#   'duration_ms': 227374,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.527,
#   'key': 10,
#   'loudness': -7.472,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.771,
#   'instrumentalness': 1.3e-06,
#   'liveness': 0.126,
#   'valence': 0.222,
#   'tempo': 127.999,
#   'type': 'audio_features',
#   'id': '7AX1eCw6qcX54PrDylynJr',
#   'uri': 'spotify:track:7AX1eCw6qcX54PrDylynJr',
#   'track_href': 'https://api.spotify.com/v1/tracks/7AX1eCw6qcX54PrDylynJr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7AX1eCw6qcX54PrDylynJr',
#   'duration_ms': 249494,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.273,
#   'key': 7,
#   'loudness': -11.458,
#   'mode': 1,
#   'speechiness': 0.0285,
#   'acousticness': 0.324,
#   'instrumentalness': 3.79e-05,
#   'liveness': 0.244,
#   'valence': 0.719,
#   'tempo': 90.059,
#   'type': 'audio_features',
#   'id': '1camd9eP6HEbhNjXww8FKN',
#   'uri': 'spotify:track:1camd9eP6HEbhNjXww8FKN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1camd9eP6HEbhNjXww8FKN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1camd9eP6HEbhNjXww8FKN',
#   'duration_ms': 165255,
#   'time_signature': 4},
#  {'danceability': 0.706,
#   'energy': 0.688,
#   'key': 8,
#   'loudness': -6.505,
#   'mode': 1,
#   'speechiness': 0.0544,
#   'acousticness': 0.0442,
#   'instrumentalness': 0.0039,
#   'liveness': 0.0943,
#   'valence': 0.851,
#   'tempo': 170.026,
#   'type': 'audio_features',
#   'id': '0VlNBqGgNFR8Kp022pyp2f',
#   'uri': 'spotify:track:0VlNBqGgNFR8Kp022pyp2f',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VlNBqGgNFR8Kp022pyp2f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VlNBqGgNFR8Kp022pyp2f',
#   'duration_ms': 166588,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.864,
#   'key': 11,
#   'loudness': -3.919,
#   'mode': 1,
#   'speechiness': 0.0491,
#   'acousticness': 0.0314,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.892,
#   'tempo': 160.009,
#   'type': 'audio_features',
#   'id': '1RlmAzI27AlIpvoRN3u6Iy',
#   'uri': 'spotify:track:1RlmAzI27AlIpvoRN3u6Iy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1RlmAzI27AlIpvoRN3u6Iy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RlmAzI27AlIpvoRN3u6Iy',
#   'duration_ms': 199512,
#   'time_signature': 4},
#  {'danceability': 0.568,
#   'energy': 0.904,
#   'key': 6,
#   'loudness': -4.772,
#   'mode': 0,
#   'speechiness': 0.226,
#   'acousticness': 0.00167,
#   'instrumentalness': 2.55e-06,
#   'liveness': 0.11,
#   'valence': 0.487,
#   'tempo': 169.935,
#   'type': 'audio_features',
#   'id': '3gZyxP7keADPPc8lEJWehW',
#   'uri': 'spotify:track:3gZyxP7keADPPc8lEJWehW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gZyxP7keADPPc8lEJWehW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gZyxP7keADPPc8lEJWehW',
#   'duration_ms': 258320,
#   'time_signature': 4},
#  {'danceability': 0.589,
#   'energy': 0.605,
#   'key': 8,
#   'loudness': -7.237,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'acousticness': 0.0658,
#   'instrumentalness': 0,
#   'liveness': 0.332,
#   'valence': 0.503,
#   'tempo': 95.084,
#   'type': 'audio_features',
#   'id': '4dHdqpGaO9km4TEw9nNQSR',
#   'uri': 'spotify:track:4dHdqpGaO9km4TEw9nNQSR',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dHdqpGaO9km4TEw9nNQSR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dHdqpGaO9km4TEw9nNQSR',
#   'duration_ms': 251281,
#   'time_signature': 3},
#  {'danceability': 0.708,
#   'energy': 0.477,
#   'key': 8,
#   'loudness': -7.297,
#   'mode': 1,
#   'speechiness': 0.0565,
#   'acousticness': 0.292,
#   'instrumentalness': 1.75e-06,
#   'liveness': 0.255,
#   'valence': 0.733,
#   'tempo': 149.929,
#   'type': 'audio_features',
#   'id': '0ioTTk5l0Zz7Oh48qEocgj',
#   'uri': 'spotify:track:0ioTTk5l0Zz7Oh48qEocgj',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ioTTk5l0Zz7Oh48qEocgj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ioTTk5l0Zz7Oh48qEocgj',
#   'duration_ms': 183000,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.796,
#   'key': 1,
#   'loudness': -5.402,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.000926,
#   'instrumentalness': 5.18e-05,
#   'liveness': 0.196,
#   'valence': 0.933,
#   'tempo': 119.97,
#   'type': 'audio_features',
#   'id': '2Tv3bPKLESHfl8jgAlY2Pv',
#   'uri': 'spotify:track:2Tv3bPKLESHfl8jgAlY2Pv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Tv3bPKLESHfl8jgAlY2Pv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tv3bPKLESHfl8jgAlY2Pv',
#   'duration_ms': 165068,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.443,
#   'key': 4,
#   'loudness': -6.968,
#   'mode': 1,
#   'speechiness': 0.0382,
#   'acousticness': 0.0225,
#   'instrumentalness': 6.76e-06,
#   'liveness': 0.099,
#   'valence': 0.37,
#   'tempo': 119.984,
#   'type': 'audio_features',
#   'id': '4LK36kV9w3KBD2GYL26ZBq',
#   'uri': 'spotify:track:4LK36kV9w3KBD2GYL26ZBq',
#   'track_href': 'https://api.spotify.com/v1/tracks/4LK36kV9w3KBD2GYL26ZBq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LK36kV9w3KBD2GYL26ZBq',
#   'duration_ms': 179573,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.569,
#   'key': 0,
#   'loudness': -7.236,
#   'mode': 0,
#   'speechiness': 0.0487,
#   'acousticness': 0.0581,
#   'instrumentalness': 0.000169,
#   'liveness': 0.108,
#   'valence': 0.616,
#   'tempo': 142.967,
#   'type': 'audio_features',
#   'id': '3gzIK2dGSVvPBiohsTwEWZ',
#   'uri': 'spotify:track:3gzIK2dGSVvPBiohsTwEWZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gzIK2dGSVvPBiohsTwEWZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gzIK2dGSVvPBiohsTwEWZ',
#   'duration_ms': 226781,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.565,
#   'key': 3,
#   'loudness': -6.922,
#   'mode': 1,
#   'speechiness': 0.122,
#   'acousticness': 0.537,
#   'instrumentalness': 0,
#   'liveness': 0.214,
#   'valence': 0.514,
#   'tempo': 131.083,
#   'type': 'audio_features',
#   'id': '19YOJKCVvOL7v6B2Oe3UBc',
#   'uri': 'spotify:track:19YOJKCVvOL7v6B2Oe3UBc',
#   'track_href': 'https://api.spotify.com/v1/tracks/19YOJKCVvOL7v6B2Oe3UBc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19YOJKCVvOL7v6B2Oe3UBc',
#   'duration_ms': 142830,
#   'time_signature': 3},
#  {'danceability': 0.7,
#   'energy': 0.494,
#   'key': 4,
#   'loudness': -4.908,
#   'mode': 1,
#   'speechiness': 0.0463,
#   'acousticness': 0.742,
#   'instrumentalness': 0,
#   'liveness': 0.304,
#   'valence': 0.229,
#   'tempo': 132.943,
#   'type': 'audio_features',
#   'id': '6fGSHpEipD1YjtLLChnBzW',
#   'uri': 'spotify:track:6fGSHpEipD1YjtLLChnBzW',
#   'track_href': 'https://api.spotify.com/v1/tracks/6fGSHpEipD1YjtLLChnBzW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6fGSHpEipD1YjtLLChnBzW',
#   'duration_ms': 176947,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.788,
#   'key': 2,
#   'loudness': -4.714,
#   'mode': 1,
#   'speechiness': 0.259,
#   'acousticness': 0.0123,
#   'instrumentalness': 1.84e-05,
#   'liveness': 0.368,
#   'valence': 0.72,
#   'tempo': 148.992,
#   'type': 'audio_features',
#   'id': '1q2Zb0v5ZGxKDktEz7wSPb',
#   'uri': 'spotify:track:1q2Zb0v5ZGxKDktEz7wSPb',
#   'track_href': 'https://api.spotify.com/v1/tracks/1q2Zb0v5ZGxKDktEz7wSPb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1q2Zb0v5ZGxKDktEz7wSPb',
#   'duration_ms': 182426,
#   'time_signature': 4},
#  {'danceability': 0.895,
#   'energy': 0.407,
#   'key': 1,
#   'loudness': -8.331,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.37,
#   'instrumentalness': 0,
#   'liveness': 0.0553,
#   'valence': 0.964,
#   'tempo': 127.071,
#   'type': 'audio_features',
#   'id': '0fB64S7FNKUDQlyYXlacYi',
#   'uri': 'spotify:track:0fB64S7FNKUDQlyYXlacYi',
#   'track_href': 'https://api.spotify.com/v1/tracks/0fB64S7FNKUDQlyYXlacYi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0fB64S7FNKUDQlyYXlacYi',
#   'duration_ms': 97293,
#   'time_signature': 3},
#  {'danceability': 0.514,
#   'energy': 0.671,
#   'key': 2,
#   'loudness': -7.048,
#   'mode': 1,
#   'speechiness': 0.0287,
#   'acousticness': 0.048,
#   'instrumentalness': 0.000218,
#   'liveness': 0.194,
#   'valence': 0.356,
#   'tempo': 179.934,
#   'type': 'audio_features',
#   'id': '5YIAMIFBXGXsyJwJmqUMZo',
#   'uri': 'spotify:track:5YIAMIFBXGXsyJwJmqUMZo',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YIAMIFBXGXsyJwJmqUMZo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YIAMIFBXGXsyJwJmqUMZo',
#   'duration_ms': 214724,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.646,
#   'key': 9,
#   'loudness': -5.788,
#   'mode': 1,
#   'speechiness': 0.0469,
#   'acousticness': 0.655,
#   'instrumentalness': 0,
#   'liveness': 0.188,
#   'valence': 0.336,
#   'tempo': 130.003,
#   'type': 'audio_features',
#   'id': '7xXUNbWepi09rzwW1Il61B',
#   'uri': 'spotify:track:7xXUNbWepi09rzwW1Il61B',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xXUNbWepi09rzwW1Il61B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xXUNbWepi09rzwW1Il61B',
#   'duration_ms': 188308,
#   'time_signature': 4},
#  {'danceability': 0.842,
#   'energy': 0.681,
#   'key': 1,
#   'loudness': -5.73,
#   'mode': 0,
#   'speechiness': 0.0361,
#   'acousticness': 0.232,
#   'instrumentalness': 2.32e-05,
#   'liveness': 0.125,
#   'valence': 0.872,
#   'tempo': 109.97,
#   'type': 'audio_features',
#   'id': '5d8a5B6RlYnquvR4X4OIrX',
#   'uri': 'spotify:track:5d8a5B6RlYnquvR4X4OIrX',
#   'track_href': 'https://api.spotify.com/v1/tracks/5d8a5B6RlYnquvR4X4OIrX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5d8a5B6RlYnquvR4X4OIrX',
#   'duration_ms': 203062,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.889,
#   'key': 3,
#   'loudness': -2.564,
#   'mode': 0,
#   'speechiness': 0.0416,
#   'acousticness': 0.0682,
#   'instrumentalness': 4.77e-06,
#   'liveness': 0.124,
#   'valence': 0.743,
#   'tempo': 139.965,
#   'type': 'audio_features',
#   'id': '0ePX6rVjeql7Bt1KurTbAG',
#   'uri': 'spotify:track:0ePX6rVjeql7Bt1KurTbAG',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ePX6rVjeql7Bt1KurTbAG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ePX6rVjeql7Bt1KurTbAG',
#   'duration_ms': 177397,
#   'time_signature': 4},
#  {'danceability': 0.824,
#   'energy': 0.618,
#   'key': 5,
#   'loudness': -5.435,
#   'mode': 0,
#   'speechiness': 0.0656,
#   'acousticness': 0.0132,
#   'instrumentalness': 0,
#   'liveness': 0.0872,
#   'valence': 0.676,
#   'tempo': 120.028,
#   'type': 'audio_features',
#   'id': '7uvxkcv7FWVh4wE91I8Bi2',
#   'uri': 'spotify:track:7uvxkcv7FWVh4wE91I8Bi2',
#   'track_href': 'https://api.spotify.com/v1/tracks/7uvxkcv7FWVh4wE91I8Bi2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uvxkcv7FWVh4wE91I8Bi2',
#   'duration_ms': 243236,
#   'time_signature': 4},
#  {'danceability': 0.518,
#   'energy': 0.792,
#   'key': 9,
#   'loudness': -3.915,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.00477,
#   'instrumentalness': 1.85e-05,
#   'liveness': 0.296,
#   'valence': 0.202,
#   'tempo': 122.042,
#   'type': 'audio_features',
#   'id': '6VRfsebyIwzt9otSvcuV87',
#   'uri': 'spotify:track:6VRfsebyIwzt9otSvcuV87',
#   'track_href': 'https://api.spotify.com/v1/tracks/6VRfsebyIwzt9otSvcuV87',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VRfsebyIwzt9otSvcuV87',
#   'duration_ms': 215814,
#   'time_signature': 4},
#  {'danceability': 0.415,
#   'energy': 0.585,
#   'key': 9,
#   'loudness': -8.958,
#   'mode': 1,
#   'speechiness': 0.0761,
#   'acousticness': 0.0384,
#   'instrumentalness': 3.5e-05,
#   'liveness': 0.328,
#   'valence': 0.554,
#   'tempo': 160.292,
#   'type': 'audio_features',
#   'id': '1NfqGbaWcZLor12cITE5Fv',
#   'uri': 'spotify:track:1NfqGbaWcZLor12cITE5Fv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1NfqGbaWcZLor12cITE5Fv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NfqGbaWcZLor12cITE5Fv',
#   'duration_ms': 164349,
#   'time_signature': 3},
#  {'danceability': 0.661,
#   'energy': 0.633,
#   'key': 5,
#   'loudness': -8.819,
#   'mode': 0,
#   'speechiness': 0.052,
#   'acousticness': 0.0227,
#   'instrumentalness': 9.86e-05,
#   'liveness': 0.104,
#   'valence': 0.782,
#   'tempo': 104.934,
#   'type': 'audio_features',
#   'id': '2Ryp5LkAWyJwRqoFd8N7Kk',
#   'uri': 'spotify:track:2Ryp5LkAWyJwRqoFd8N7Kk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Ryp5LkAWyJwRqoFd8N7Kk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Ryp5LkAWyJwRqoFd8N7Kk',
#   'duration_ms': 148571,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.708,
#   'key': 2,
#   'loudness': -5.22,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.155,
#   'instrumentalness': 0.000221,
#   'liveness': 0.0663,
#   'valence': 0.964,
#   'tempo': 96.001,
#   'type': 'audio_features',
#   'id': '0P2CBPHJsD0BgdsqHedugp',
#   'uri': 'spotify:track:0P2CBPHJsD0BgdsqHedugp',
#   'track_href': 'https://api.spotify.com/v1/tracks/0P2CBPHJsD0BgdsqHedugp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0P2CBPHJsD0BgdsqHedugp',
#   'duration_ms': 139387,
#   'time_signature': 4},
#  {'danceability': 0.577,
#   'energy': 0.555,
#   'key': 8,
#   'loudness': -8.228,
#   'mode': 1,
#   'speechiness': 0.0352,
#   'acousticness': 0.583,
#   'instrumentalness': 6.59e-05,
#   'liveness': 0.105,
#   'valence': 0.437,
#   'tempo': 132.336,
#   'type': 'audio_features',
#   'id': '5eGIOMy0V0r7neaaPve2kB',
#   'uri': 'spotify:track:5eGIOMy0V0r7neaaPve2kB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eGIOMy0V0r7neaaPve2kB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eGIOMy0V0r7neaaPve2kB',
#   'duration_ms': 134957,
#   'time_signature': 4},
#  {'danceability': 0.63,
#   'energy': 0.468,
#   'key': 4,
#   'loudness': -7.887,
#   'mode': 1,
#   'speechiness': 0.0485,
#   'acousticness': 0.365,
#   'instrumentalness': 0.00163,
#   'liveness': 0.0994,
#   'valence': 0.648,
#   'tempo': 172.118,
#   'type': 'audio_features',
#   'id': '2IKix80lBA5ppm6096p5U7',
#   'uri': 'spotify:track:2IKix80lBA5ppm6096p5U7',
#   'track_href': 'https://api.spotify.com/v1/tracks/2IKix80lBA5ppm6096p5U7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IKix80lBA5ppm6096p5U7',
#   'duration_ms': 170488,
#   'time_signature': 4},
#  {'danceability': 0.707,
#   'energy': 0.735,
#   'key': 1,
#   'loudness': -5.237,
#   'mode': 1,
#   'speechiness': 0.0362,
#   'acousticness': 0.00896,
#   'instrumentalness': 4.78e-05,
#   'liveness': 0.0433,
#   'valence': 0.762,
#   'tempo': 129.965,
#   'type': 'audio_features',
#   'id': '3Gplr4iOpewQ9ynbZujzlu',
#   'uri': 'spotify:track:3Gplr4iOpewQ9ynbZujzlu',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Gplr4iOpewQ9ynbZujzlu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Gplr4iOpewQ9ynbZujzlu',
#   'duration_ms': 158240,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.666,
#   'key': 2,
#   'loudness': -8.319,
#   'mode': 1,
#   'speechiness': 0.0505,
#   'acousticness': 0.33,
#   'instrumentalness': 0.00638,
#   'liveness': 0.0961,
#   'valence': 0.148,
#   'tempo': 171.957,
#   'type': 'audio_features',
#   'id': '6S2Uha79wlOXCRlDOImZkZ',
#   'uri': 'spotify:track:6S2Uha79wlOXCRlDOImZkZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6S2Uha79wlOXCRlDOImZkZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6S2Uha79wlOXCRlDOImZkZ',
#   'duration_ms': 251269,
#   'time_signature': 4},
#  {'danceability': 0.795,
#   'energy': 0.584,
#   'key': 8,
#   'loudness': -5.758,
#   'mode': 0,
#   'speechiness': 0.0396,
#   'acousticness': 0.172,
#   'instrumentalness': 2.99e-05,
#   'liveness': 0.103,
#   'valence': 0.785,
#   'tempo': 127.05,
#   'type': 'audio_features',
#   'id': '0ZpHuEhi1CvOJgrqOSy8mv',
#   'uri': 'spotify:track:0ZpHuEhi1CvOJgrqOSy8mv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ZpHuEhi1CvOJgrqOSy8mv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ZpHuEhi1CvOJgrqOSy8mv',
#   'duration_ms': 146274,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.895,
#   'key': 3,
#   'loudness': -5.224,
#   'mode': 0,
#   'speechiness': 0.0396,
#   'acousticness': 0.099,
#   'instrumentalness': 0.0117,
#   'liveness': 0.0911,
#   'valence': 0.356,
#   'tempo': 116.953,
#   'type': 'audio_features',
#   'id': '1SldN7GTd0ADTjspv96wCl',
#   'uri': 'spotify:track:1SldN7GTd0ADTjspv96wCl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SldN7GTd0ADTjspv96wCl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SldN7GTd0ADTjspv96wCl',
#   'duration_ms': 207813,
#   'time_signature': 4},
#  {'danceability': 0.444,
#   'energy': 0.301,
#   'key': 0,
#   'loudness': -8.88,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.886,
#   'instrumentalness': 0,
#   'liveness': 0.183,
#   'valence': 0.35,
#   'tempo': 95.278,
#   'type': 'audio_features',
#   'id': '1USo158Kncaxfyq9q306dn',
#   'uri': 'spotify:track:1USo158Kncaxfyq9q306dn',
#   'track_href': 'https://api.spotify.com/v1/tracks/1USo158Kncaxfyq9q306dn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1USo158Kncaxfyq9q306dn',
#   'duration_ms': 156342,
#   'time_signature': 3},
#  {'danceability': 0.839,
#   'energy': 0.525,
#   'key': 2,
#   'loudness': -4.873,
#   'mode': 1,
#   'speechiness': 0.131,
#   'acousticness': 0.0303,
#   'instrumentalness': 0,
#   'liveness': 0.302,
#   'valence': 0.831,
#   'tempo': 135.996,
#   'type': 'audio_features',
#   'id': '5nsMKSAJwcr1pA9I6PW429',
#   'uri': 'spotify:track:5nsMKSAJwcr1pA9I6PW429',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nsMKSAJwcr1pA9I6PW429',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nsMKSAJwcr1pA9I6PW429',
#   'duration_ms': 133897,
#   'time_signature': 4},
#  {'danceability': 0.682,
#   'energy': 0.609,
#   'key': 7,
#   'loudness': -6.372,
#   'mode': 0,
#   'speechiness': 0.139,
#   'acousticness': 0.000928,
#   'instrumentalness': 0.000201,
#   'liveness': 0.142,
#   'valence': 0.723,
#   'tempo': 111.991,
#   'type': 'audio_features',
#   'id': '4nLTOnpSCBwRlul92HLIyW',
#   'uri': 'spotify:track:4nLTOnpSCBwRlul92HLIyW',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nLTOnpSCBwRlul92HLIyW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nLTOnpSCBwRlul92HLIyW',
#   'duration_ms': 184315,
#   'time_signature': 4},
#  {'danceability': 0.507,
#   'energy': 0.252,
#   'key': 10,
#   'loudness': -12.625,
#   'mode': 0,
#   'speechiness': 0.0616,
#   'acousticness': 0.869,
#   'instrumentalness': 0.000293,
#   'liveness': 0.0819,
#   'valence': 0.307,
#   'tempo': 137.314,
#   'type': 'audio_features',
#   'id': '3QEX5O23KVp1yg1tj6Hycp',
#   'uri': 'spotify:track:3QEX5O23KVp1yg1tj6Hycp',
#   'track_href': 'https://api.spotify.com/v1/tracks/3QEX5O23KVp1yg1tj6Hycp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QEX5O23KVp1yg1tj6Hycp',
#   'duration_ms': 156798,
#   'time_signature': 3},
#  {'danceability': 0.696,
#   'energy': 0.9,
#   'key': 7,
#   'loudness': -3.818,
#   'mode': 0,
#   'speechiness': 0.0438,
#   'acousticness': 0.00603,
#   'instrumentalness': 0.00198,
#   'liveness': 0.111,
#   'valence': 0.722,
#   'tempo': 119.985,
#   'type': 'audio_features',
#   'id': '5DObWDHfwHE2mIdZGgRnzE',
#   'uri': 'spotify:track:5DObWDHfwHE2mIdZGgRnzE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5DObWDHfwHE2mIdZGgRnzE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5DObWDHfwHE2mIdZGgRnzE',
#   'duration_ms': 231671,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.606,
#   'key': 6,
#   'loudness': -6.466,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.11,
#   'instrumentalness': 0,
#   'liveness': 0.295,
#   'valence': 0.564,
#   'tempo': 116.053,
#   'type': 'audio_features',
#   'id': '6el1gIJ39V0ycFwNLZiKm7',
#   'uri': 'spotify:track:6el1gIJ39V0ycFwNLZiKm7',
#   'track_href': 'https://api.spotify.com/v1/tracks/6el1gIJ39V0ycFwNLZiKm7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6el1gIJ39V0ycFwNLZiKm7',
#   'duration_ms': 194630,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.86,
#   'key': 5,
#   'loudness': -3.159,
#   'mode': 1,
#   'speechiness': 0.0429,
#   'acousticness': 0.0769,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.803,
#   'tempo': 105.017,
#   'type': 'audio_features',
#   'id': '3NE8bmyye8sEOQtWknh8Vi',
#   'uri': 'spotify:track:3NE8bmyye8sEOQtWknh8Vi',
#   'track_href': 'https://api.spotify.com/v1/tracks/3NE8bmyye8sEOQtWknh8Vi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3NE8bmyye8sEOQtWknh8Vi',
#   'duration_ms': 218000,
#   'time_signature': 4},
#  {'danceability': 0.617,
#   'energy': 0.71,
#   'key': 0,
#   'loudness': -10.114,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.185,
#   'instrumentalness': 0.378,
#   'liveness': 0.117,
#   'valence': 0.692,
#   'tempo': 97.019,
#   'type': 'audio_features',
#   'id': '2DGdgztVbE3pFmqoF1rHzp',
#   'uri': 'spotify:track:2DGdgztVbE3pFmqoF1rHzp',
#   'track_href': 'https://api.spotify.com/v1/tracks/2DGdgztVbE3pFmqoF1rHzp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DGdgztVbE3pFmqoF1rHzp',
#   'duration_ms': 206857,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.825,
#   'key': 9,
#   'loudness': -7.086,
#   'mode': 1,
#   'speechiness': 0.0474,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.000122,
#   'liveness': 0.0748,
#   'valence': 0.197,
#   'tempo': 103.985,
#   'type': 'audio_features',
#   'id': '18O6oj2DtAA9lPlP9Kl9R2',
#   'uri': 'spotify:track:18O6oj2DtAA9lPlP9Kl9R2',
#   'track_href': 'https://api.spotify.com/v1/tracks/18O6oj2DtAA9lPlP9Kl9R2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18O6oj2DtAA9lPlP9Kl9R2',
#   'duration_ms': 183812,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.687,
#   'key': 5,
#   'loudness': -7.24,
#   'mode': 1,
#   'speechiness': 0.0393,
#   'acousticness': 0.0952,
#   'instrumentalness': 0,
#   'liveness': 0.0861,
#   'valence': 0.283,
#   'tempo': 134.974,
#   'type': 'audio_features',
#   'id': '7LhVGZrF9jgkT97CaKTlds',
#   'uri': 'spotify:track:7LhVGZrF9jgkT97CaKTlds',
#   'track_href': 'https://api.spotify.com/v1/tracks/7LhVGZrF9jgkT97CaKTlds',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LhVGZrF9jgkT97CaKTlds',
#   'duration_ms': 198140,
#   'time_signature': 4},
#  {'danceability': 0.848,
#   'energy': 0.576,
#   'key': 4,
#   'loudness': -7.634,
#   'mode': 1,
#   'speechiness': 0.0466,
#   'acousticness': 0.294,
#   'instrumentalness': 0.000587,
#   'liveness': 0.209,
#   'valence': 0.485,
#   'tempo': 119.024,
#   'type': 'audio_features',
#   'id': '6pQcqaoZlGKF3zvglt6tvc',
#   'uri': 'spotify:track:6pQcqaoZlGKF3zvglt6tvc',
#   'track_href': 'https://api.spotify.com/v1/tracks/6pQcqaoZlGKF3zvglt6tvc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pQcqaoZlGKF3zvglt6tvc',
#   'duration_ms': 169718,
#   'time_signature': 4},
#  {'danceability': 0.343,
#   'energy': 0.331,
#   'key': 2,
#   'loudness': -9.528,
#   'mode': 1,
#   'speechiness': 0.035,
#   'acousticness': 0.313,
#   'instrumentalness': 1.7e-05,
#   'liveness': 0.512,
#   'valence': 0.343,
#   'tempo': 203.852,
#   'type': 'audio_features',
#   'id': '0G41EUi3xiwUR6iOtXAQCz',
#   'uri': 'spotify:track:0G41EUi3xiwUR6iOtXAQCz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0G41EUi3xiwUR6iOtXAQCz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0G41EUi3xiwUR6iOtXAQCz',
#   'duration_ms': 197453,
#   'time_signature': 4}]

# %% [markdown]
# ### confirm how many tracks in list

# %%
len(playlist_info)
# Out:
# 75

# %% [markdown]
# ### convert to DataFrame

# %%
playlist_df = pd.DataFrame(playlist_info)

# %%
playlist_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.615   0.879    5    -3.977     1       0.0451      0.234000
# 1          0.442   0.612    2    -7.222     1       0.1120      0.584000
# 2          0.723   0.741   10    -5.530     1       0.0328      0.182000
# 3          0.348   0.950   10    -5.049     0       0.1240      0.000099
# 4          0.666   0.652    7    -5.956     1       0.0304      0.006350
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.617   0.710    0   -10.114     1       0.0326      0.185000
# 71         0.561   0.825    9    -7.086     1       0.0474      0.014900
# 72         0.585   0.687    5    -7.240     1       0.0393      0.095200
# 73         0.848   0.576    4    -7.634     1       0.0466      0.294000
# 74         0.343   0.331    2    -9.528     1       0.0350      0.313000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000023    0.4220    0.627  100.028  audio_features
# 1           0.000006    0.3700    0.178  180.917  audio_features
# 2           0.000474    0.0662    0.763   99.990  audio_features
# 3           0.000010    0.0868    0.377  168.964  audio_features
# 4           0.000021    0.2210    0.666  128.028  audio_features
# ..               ...       ...      ...      ...             ...
# 70          0.378000    0.1170    0.692   97.019  audio_features
# 71          0.000122    0.0748    0.197  103.985  audio_features
# 72          0.000000    0.0861    0.283  134.974  audio_features
# 73          0.000587    0.2090    0.485  119.024  audio_features
# 74          0.000017    0.5120    0.343  203.852  audio_features
#
#                         id                                   uri  \
# 0   1hf0PdHw0lnVxq5lfzwjSl  spotify:track:1hf0PdHw0lnVxq5lfzwjSl
# 1   6HU7h9RYOaPRFeh0R3UeAr  spotify:track:6HU7h9RYOaPRFeh0R3UeAr
# 2   5bD7bhOa64aE8a0vifa5J6  spotify:track:5bD7bhOa64aE8a0vifa5J6
# 3   0MnTkIEP4zZN1IUSu8MvIz  spotify:track:0MnTkIEP4zZN1IUSu8MvIz
# 4   4XVPArAtSq0657KUF0vXRy  spotify:track:4XVPArAtSq0657KUF0vXRy
# ..                     ...                                   ...
# 70  2DGdgztVbE3pFmqoF1rHzp  spotify:track:2DGdgztVbE3pFmqoF1rHzp
# 71  18O6oj2DtAA9lPlP9Kl9R2  spotify:track:18O6oj2DtAA9lPlP9Kl9R2
# 72  7LhVGZrF9jgkT97CaKTlds  spotify:track:7LhVGZrF9jgkT97CaKTlds
# 73  6pQcqaoZlGKF3zvglt6tvc  spotify:track:6pQcqaoZlGKF3zvglt6tvc
# 74  0G41EUi3xiwUR6iOtXAQCz  spotify:track:0G41EUi3xiwUR6iOtXAQCz
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/1hf0PdHw0lnV...
# 1   https://api.spotify.com/v1/tracks/6HU7h9RYOaPR...
# 2   https://api.spotify.com/v1/tracks/5bD7bhOa64aE...
# 3   https://api.spotify.com/v1/tracks/0MnTkIEP4zZN...
# 4   https://api.spotify.com/v1/tracks/4XVPArAtSq06...
# ..                                                ...
# 70  https://api.spotify.com/v1/tracks/2DGdgztVbE3p...
# 71  https://api.spotify.com/v1/tracks/18O6oj2DtAA9...
# 72  https://api.spotify.com/v1/tracks/7LhVGZrF9jgk...
# 73  https://api.spotify.com/v1/tracks/6pQcqaoZlGKF...
# 74  https://api.spotify.com/v1/tracks/0G41EUi3xiwU...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/1hf0...       156008
# 1   https://api.spotify.com/v1/audio-analysis/6HU7...       215507
# 2   https://api.spotify.com/v1/audio-analysis/5bD7...       185347
# 3   https://api.spotify.com/v1/audio-analysis/0MnT...       166859
# 4   https://api.spotify.com/v1/audio-analysis/4XVP...       193133
# ..                                                ...          ...
# 70  https://api.spotify.com/v1/audio-analysis/2DGd...       206857
# 71  https://api.spotify.com/v1/audio-analysis/18O6...       183812
# 72  https://api.spotify.com/v1/audio-analysis/7LhV...       198140
# 73  https://api.spotify.com/v1/audio-analysis/6pQc...       169718
# 74  https://api.spotify.com/v1/audio-analysis/0G41...       197453
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 70               4
# 71               4
# 72               4
# 73               4
# 74               4
#
# [75 rows x 18 columns]

# %%
playlist_df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     75.000000  75.000000  75.000000  75.000000  75.000000    75.000000
# mean       0.643987   0.625333   4.840000  -6.928293   0.786667     0.065475
# std        0.133021   0.173998   3.483707   2.516666   0.412420     0.064032
# min        0.318000   0.110000   0.000000 -19.885000   0.000000     0.027300
# 25%        0.564500   0.523000   2.000000  -7.842500   1.000000     0.035100
# 50%        0.646000   0.618000   5.000000  -6.922000   1.000000     0.043800
# 75%        0.728500   0.738500   8.000000  -5.230500   1.000000     0.055500
# max        0.913000   0.950000  11.000000  -2.564000   1.000000     0.433000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     75.000000         75.000000  75.000000  75.000000   75.000000
# mean       0.239856          0.006012   0.183253   0.551543  127.692480
# std        0.258838          0.043647   0.118545   0.237492   27.848756
# min        0.000099          0.000000   0.043300   0.080700   76.068000
# 25%        0.022600          0.000000   0.095200   0.356000  107.493500
# 50%        0.122000          0.000023   0.139000   0.556000  125.032000
# 75%        0.377500          0.000257   0.244500   0.738000  141.499000
# max        0.912000          0.378000   0.581000   0.965000  203.852000
#
#          duration_ms  time_signature
# count      75.000000       75.000000
# mean   186289.413333        3.893333
# std     36562.821851        0.310768
# min     97293.000000        3.000000
# 25%    164822.500000        4.000000
# 50%    183812.000000        4.000000
# 75%    211227.500000        4.000000
# max    290132.000000        4.000000

# %%
#Exporting track_list as json
#with open("tracks.json", "w") as outfile:
    #json.dump(track_list, outfile)

# %%
import json

song_names = []
artist1_names = []
songs = json.dumps(track_list)

#for i in track_list[items]:
        #popularity = track_list[items][i]['track']['popularity']
    
#print(popularity)

# %%
#Step into popularity score
track_list['items'][1]['track']['popularity']
# Out:
# 88

# %%
#Step into Artist
track_list['items'][1]['track']['artists'][0]['name']
# Out:
# 'Olivia Rodrigo'

# %%
#Step into Song Name
track_list['items'][1]['track']['name']
# Out:
# 'deja vu'

# %%
track_list['items']
# Out:
# [{'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25pd339V2rRJo84USlcSRP'},
#       'href': 'https://api.spotify.com/v1/artists/25pd339V2rRJo84USlcSRP',
#       'id': '25pd339V2rRJo84USlcSRP',
#       'name': 'JAWNY',
#       'type': 'artist',
#       'uri': 'spotify:artist:25pd339V2rRJo84USlcSRP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/62JUc5rzLwVpGKwpawkTjL'},
#     'href': 'https://api.spotify.com/v1/albums/62JUc5rzLwVpGKwpawkTjL',
#     'id': '62JUc5rzLwVpGKwpawkTjL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736728316f461683601ae5e4eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026728316f461683601ae5e4eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516728316f461683601ae5e4eb',
#       'width': 64}],
#     'name': 'strawberry chainsaw',
#     'release_date': '2022-08-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:62JUc5rzLwVpGKwpawkTjL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25pd339V2rRJo84USlcSRP'},
#      'href': 'https://api.spotify.com/v1/artists/25pd339V2rRJo84USlcSRP',
#      'id': '25pd339V2rRJo84USlcSRP',
#      'name': 'JAWNY',
#      'type': 'artist',
#      'uri': 'spotify:artist:25pd339V2rRJo84USlcSRP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 156008,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12205511'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1hf0PdHw0lnVxq5lfzwjSl'},
#    'href': 'https://api.spotify.com/v1/tracks/1hf0PdHw0lnVxq5lfzwjSl',
#    'id': '1hf0PdHw0lnVxq5lfzwjSl',
#    'is_local': False,
#    'name': 'strawberry chainsaw',
#    'popularity': 65,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1hf0PdHw0lnVxq5lfzwjSl'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#       'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#       'id': '1McMsnEElThX1knmY4oliG',
#       'name': 'Olivia Rodrigo',
#       'type': 'artist',
#       'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#     'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#     'id': '6s84u2TUpR3wdUv4NgKA2j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#       'width': 64}],
#     'name': 'SOUR',
#     'release_date': '2021-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 215506,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12101240'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6HU7h9RYOaPRFeh0R3UeAr'},
#    'href': 'https://api.spotify.com/v1/tracks/6HU7h9RYOaPRFeh0R3UeAr',
#    'id': '6HU7h9RYOaPRFeh0R3UeAr',
#    'is_local': False,
#    'name': 'deja vu',
#    'popularity': 88,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6HU7h9RYOaPRFeh0R3UeAr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HthCchcL0kVLHTr113Vk1'},
#       'href': 'https://api.spotify.com/v1/artists/0HthCchcL0kVLHTr113Vk1',
#       'id': '0HthCchcL0kVLHTr113Vk1',
#       'name': 'mxmtoon',
#       'type': 'artist',
#       'uri': 'spotify:artist:0HthCchcL0kVLHTr113Vk1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5AVdHQYItgjzDu5qRVmONy'},
#     'href': 'https://api.spotify.com/v1/albums/5AVdHQYItgjzDu5qRVmONy',
#     'id': '5AVdHQYItgjzDu5qRVmONy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27360e8cf62e33400b6fc3c05b3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0260e8cf62e33400b6fc3c05b3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485160e8cf62e33400b6fc3c05b3',
#       'width': 64}],
#     'name': 'kaleidoscope',
#     'release_date': '2022-08-04',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5AVdHQYItgjzDu5qRVmONy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0HthCchcL0kVLHTr113Vk1'},
#      'href': 'https://api.spotify.com/v1/artists/0HthCchcL0kVLHTr113Vk1',
#      'id': '0HthCchcL0kVLHTr113Vk1',
#      'name': 'mxmtoon',
#      'type': 'artist',
#      'uri': 'spotify:artist:0HthCchcL0kVLHTr113Vk1'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 185346,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL2207078'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5bD7bhOa64aE8a0vifa5J6'},
#    'href': 'https://api.spotify.com/v1/tracks/5bD7bhOa64aE8a0vifa5J6',
#    'id': '5bD7bhOa64aE8a0vifa5J6',
#    'is_local': False,
#    'name': 'kaleidoscope',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0a722a3240a82dadfc6dfdb0fd6b39d834a68c09?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5bD7bhOa64aE8a0vifa5J6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/581C5Qwl87TskfBEzuoisu'},
#       'href': 'https://api.spotify.com/v1/artists/581C5Qwl87TskfBEzuoisu',
#       'id': '581C5Qwl87TskfBEzuoisu',
#       'name': 'Cafuné',
#       'type': 'artist',
#       'uri': 'spotify:artist:581C5Qwl87TskfBEzuoisu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Bt2OtHQDRDXC10Flgm9Rv'},
#     'href': 'https://api.spotify.com/v1/albums/3Bt2OtHQDRDXC10Flgm9Rv',
#     'id': '3Bt2OtHQDRDXC10Flgm9Rv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27376a3f63eed99d8f4b99f931f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0276a3f63eed99d8f4b99f931f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485176a3f63eed99d8f4b99f931f',
#       'width': 64}],
#     'name': 'Tek It (I Watch the Moon)',
#     'release_date': '2019',
#     'release_date_precision': 'year',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:3Bt2OtHQDRDXC10Flgm9Rv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/581C5Qwl87TskfBEzuoisu'},
#      'href': 'https://api.spotify.com/v1/artists/581C5Qwl87TskfBEzuoisu',
#      'id': '581C5Qwl87TskfBEzuoisu',
#      'name': 'Cafuné',
#      'type': 'artist',
#      'uri': 'spotify:artist:581C5Qwl87TskfBEzuoisu'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 166859,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEE12200097'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0MnTkIEP4zZN1IUSu8MvIz'},
#    'href': 'https://api.spotify.com/v1/tracks/0MnTkIEP4zZN1IUSu8MvIz',
#    'id': '0MnTkIEP4zZN1IUSu8MvIz',
#    'is_local': False,
#    'name': 'Tek It - Sped Up',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/69d7a1befd8b3fa3d84544e67035c587881dd4cc?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0MnTkIEP4zZN1IUSu8MvIz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-19T04:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3P4vW5tzQvmuoNaFQqzy9q'},
#       'href': 'https://api.spotify.com/v1/artists/3P4vW5tzQvmuoNaFQqzy9q',
#       'id': '3P4vW5tzQvmuoNaFQqzy9q',
#       'name': 'chloe moriondo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3P4vW5tzQvmuoNaFQqzy9q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/63awPWi564xa0E4Y61w2dz'},
#     'href': 'https://api.spotify.com/v1/albums/63awPWi564xa0E4Y61w2dz',
#     'id': '63awPWi564xa0E4Y61w2dz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273160c4693ff84d7e7f9e6925e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02160c4693ff84d7e7f9e6925e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851160c4693ff84d7e7f9e6925e',
#       'width': 64}],
#     'name': 'Fruity',
#     'release_date': '2022-08-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:63awPWi564xa0E4Y61w2dz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3P4vW5tzQvmuoNaFQqzy9q'},
#      'href': 'https://api.spotify.com/v1/artists/3P4vW5tzQvmuoNaFQqzy9q',
#      'id': '3P4vW5tzQvmuoNaFQqzy9q',
#      'name': 'chloe moriondo',
#      'type': 'artist',
#      'uri': 'spotify:artist:3P4vW5tzQvmuoNaFQqzy9q'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 193133,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USAT22205499'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4XVPArAtSq0657KUF0vXRy'},
#    'href': 'https://api.spotify.com/v1/tracks/4XVPArAtSq0657KUF0vXRy',
#    'id': '4XVPArAtSq0657KUF0vXRy',
#    'is_local': False,
#    'name': 'Fruity',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9b27d2ba42792ec3b85d049237caf267a2ae7748?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4XVPArAtSq0657KUF0vXRy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l0CmX0FuQjFxr8SK7Vqag'},
#       'href': 'https://api.spotify.com/v1/artists/3l0CmX0FuQjFxr8SK7Vqag',
#       'id': '3l0CmX0FuQjFxr8SK7Vqag',
#       'name': 'Clairo',
#       'type': 'artist',
#       'uri': 'spotify:artist:3l0CmX0FuQjFxr8SK7Vqag'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kkVGtCqE2NiAKosri9Rnd'},
#     'href': 'https://api.spotify.com/v1/albums/4kkVGtCqE2NiAKosri9Rnd',
#     'id': '4kkVGtCqE2NiAKosri9Rnd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27333ccb60f9b2785ef691b2fbc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0233ccb60f9b2785ef691b2fbc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485133ccb60f9b2785ef691b2fbc',
#       'width': 64}],
#     'name': 'Immunity',
#     'release_date': '2019-08-02',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4kkVGtCqE2NiAKosri9Rnd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3l0CmX0FuQjFxr8SK7Vqag'},
#      'href': 'https://api.spotify.com/v1/artists/3l0CmX0FuQjFxr8SK7Vqag',
#      'id': '3l0CmX0FuQjFxr8SK7Vqag',
#      'name': 'Clairo',
#      'type': 'artist',
#      'uri': 'spotify:artist:3l0CmX0FuQjFxr8SK7Vqag'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 188386,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US4HB1900086'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7B3z0ySL9Rr0XvZEAjWZzM'},
#    'href': 'https://api.spotify.com/v1/tracks/7B3z0ySL9Rr0XvZEAjWZzM',
#    'id': '7B3z0ySL9Rr0XvZEAjWZzM',
#    'is_local': False,
#    'name': 'Sofia',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:7B3z0ySL9Rr0XvZEAjWZzM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#       'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#       'id': '6eJa3zG1QZLRB3xgRuyxbm',
#       'name': 'Dayglow',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1WuvMjvT8P5oOpe51cQdO1'},
#     'href': 'https://api.spotify.com/v1/albums/1WuvMjvT8P5oOpe51cQdO1',
#     'id': '1WuvMjvT8P5oOpe51cQdO1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739a017c3eb15190378a7d9c2c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029a017c3eb15190378a7d9c2c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519a017c3eb15190378a7d9c2c',
#       'width': 64}],
#     'name': 'Then It All Goes Away',
#     'release_date': '2022-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1WuvMjvT8P5oOpe51cQdO1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#      'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#      'id': '6eJa3zG1QZLRB3xgRuyxbm',
#      'name': 'Dayglow',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 183440,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL2201994'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5RaThsdZpF9WWwoP00NjLI'},
#    'href': 'https://api.spotify.com/v1/tracks/5RaThsdZpF9WWwoP00NjLI',
#    'id': '5RaThsdZpF9WWwoP00NjLI',
#    'is_local': False,
#    'name': 'Then It All Goes Away',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b450c2480576d60586d1b411a8c999a86bc2b20d?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5RaThsdZpF9WWwoP00NjLI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jN7f9X0EmFnsbRS6nl6as'},
#       'href': 'https://api.spotify.com/v1/artists/3jN7f9X0EmFnsbRS6nl6as',
#       'id': '3jN7f9X0EmFnsbRS6nl6as',
#       'name': 'iamnotshane',
#       'type': 'artist',
#       'uri': 'spotify:artist:3jN7f9X0EmFnsbRS6nl6as'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0sCKHcwHvwtLYuaBNfE6BL'},
#     'href': 'https://api.spotify.com/v1/albums/0sCKHcwHvwtLYuaBNfE6BL',
#     'id': '0sCKHcwHvwtLYuaBNfE6BL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ab95b62fbc1e7e04b41edc0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ab95b62fbc1e7e04b41edc0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ab95b62fbc1e7e04b41edc0',
#       'width': 64}],
#     'name': 'Maybe My Soulmate Died',
#     'release_date': '2022-06-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:0sCKHcwHvwtLYuaBNfE6BL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jN7f9X0EmFnsbRS6nl6as'},
#      'href': 'https://api.spotify.com/v1/artists/3jN7f9X0EmFnsbRS6nl6as',
#      'id': '3jN7f9X0EmFnsbRS6nl6as',
#      'name': 'iamnotshane',
#      'type': 'artist',
#      'uri': 'spotify:artist:3jN7f9X0EmFnsbRS6nl6as'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
# ...
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c7d259f5b66e67e3c61f7010',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c7d259f5b66e67e3c61f7010',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c7d259f5b66e67e3c61f7010',
#       'width': 64}],
#     'name': 'closer to closure',
#     'release_date': '2022-05-26',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:6CfZkq2gT8JmDKJGgHOIf1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69761NObDw2KwmmFgZmxzC'},
#      'href': 'https://api.spotify.com/v1/artists/69761NObDw2KwmmFgZmxzC',
#      'id': '69761NObDw2KwmmFgZmxzC',
#      'name': 'Lexi Jayde',
#      'type': 'artist',
#      'uri': 'spotify:artist:69761NObDw2KwmmFgZmxzC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 198139,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZAKB2166144'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7LhVGZrF9jgkT97CaKTlds'},
#    'href': 'https://api.spotify.com/v1/tracks/7LhVGZrF9jgkT97CaKTlds',
#    'id': '7LhVGZrF9jgkT97CaKTlds',
#    'is_local': False,
#    'name': 'gentle',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/addb448fe549f0e39d22811e46985d6313797d53?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:7LhVGZrF9jgkT97CaKTlds'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anAI9P9iSzc9qzLv6AtHZ'},
#       'href': 'https://api.spotify.com/v1/artists/1anAI9P9iSzc9qzLv6AtHZ',
#       'id': '1anAI9P9iSzc9qzLv6AtHZ',
#       'name': 'Sure Sure',
#       'type': 'artist',
#       'uri': 'spotify:artist:1anAI9P9iSzc9qzLv6AtHZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3qr8WlrGBQMrzpRL6ERL4B'},
#     'href': 'https://api.spotify.com/v1/albums/3qr8WlrGBQMrzpRL6ERL4B',
#     'id': '3qr8WlrGBQMrzpRL6ERL4B',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bfbfb0955132f5fc8051d30d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bfbfb0955132f5fc8051d30d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bfbfb0955132f5fc8051d30d',
#       'width': 64}],
#     'name': 'Peaceful In My Mind',
#     'release_date': '2021-11-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3qr8WlrGBQMrzpRL6ERL4B'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anAI9P9iSzc9qzLv6AtHZ'},
#      'href': 'https://api.spotify.com/v1/artists/1anAI9P9iSzc9qzLv6AtHZ',
#      'id': '1anAI9P9iSzc9qzLv6AtHZ',
#      'name': 'Sure Sure',
#      'type': 'artist',
#      'uri': 'spotify:artist:1anAI9P9iSzc9qzLv6AtHZ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 169717,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM24S2106639'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6pQcqaoZlGKF3zvglt6tvc'},
#    'href': 'https://api.spotify.com/v1/tracks/6pQcqaoZlGKF3zvglt6tvc',
#    'id': '6pQcqaoZlGKF3zvglt6tvc',
#    'is_local': False,
#    'name': 'Peaceful In My Mind',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fe9cdd5a86938c4d05656fbb45603d42556097c5?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6pQcqaoZlGKF3zvglt6tvc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-08-12T18:24:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO'},
#       'href': 'https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO',
#       'id': '5FxD8fkQZ6KcsSYupDVoSO',
#       'name': 'Omar Apollo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5FxD8fkQZ6KcsSYupDVoSO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5z7TD11Qh81Gbf52hd5zAv'},
#     'href': 'https://api.spotify.com/v1/albums/5z7TD11Qh81Gbf52hd5zAv',
#     'id': '5z7TD11Qh81Gbf52hd5zAv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390cf5d1ccfca2beb86149a19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290cf5d1ccfca2beb86149a19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190cf5d1ccfca2beb86149a19',
#       'width': 64}],
#     'name': 'Ivory',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5z7TD11Qh81Gbf52hd5zAv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO'},
#      'href': 'https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO',
#      'id': '5FxD8fkQZ6KcsSYupDVoSO',
#      'name': 'Omar Apollo',
#      'type': 'artist',
#      'uri': 'spotify:artist:5FxD8fkQZ6KcsSYupDVoSO'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 197453,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB12200272'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0G41EUi3xiwUR6iOtXAQCz'},
#    'href': 'https://api.spotify.com/v1/tracks/0G41EUi3xiwUR6iOtXAQCz',
#    'id': '0G41EUi3xiwUR6iOtXAQCz',
#    'is_local': False,
#    'name': 'Petrified',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a08f4b89ff53711d5c3e04cf436320519fc18d1e?cid=1c31402b45784dd489ea18b5c466c5f9',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:0G41EUi3xiwUR6iOtXAQCz'},
#   'video_thumbnail': {'url': None}}]
