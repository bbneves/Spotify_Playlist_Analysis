# %%
import pandas as pd
import datetime 
import psycopg2
import numpy as np
import matplotlib.pyplot as plt

from config import db_password

# %%
playlist_df = pd.read_csv(f'./Resources/all_data.csv', index_col=0)

# %%
playlist_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.798   0.697    0    -7.139     1       0.0891        0.0202
# 1         0.798   0.697    0    -7.139     1       0.0891        0.0202
# 2         0.798   0.697    0    -7.139     1       0.0891        0.0202
# 3         0.798   0.697    0    -7.139     1       0.0891        0.0202
# 4         0.798   0.697    0    -7.139     1       0.0891        0.0202
#
#    instrumentalness  liveness  valence  ...     playlist_name   followers  \
# 0               0.0     0.259    0.745  ...         K-Pop ON!   4,113,578
# 1               0.0     0.259    0.745  ...              SALT     295,173
# 2               0.0     0.259    0.745  ...        Pop Rising   2,642,529
# 3               0.0     0.259    0.745  ...      Hot Hits USA     762,848
# 4               0.0     0.259    0.745  ...  Today’s Top Hits  31,728,611
#
#   songs genre_1 genre_2                             playlist_uri  \
# ...

# %%
playlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12419 entries, 0 to 12418
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      12419 non-null  float64
#  1   energy            12419 non-null  float64
#  2   key               12419 non-null  int64
#  3   loudness          12419 non-null  float64
#  4   mode              12419 non-null  int64
#  5   speechiness       12419 non-null  float64
#  6   acousticness      12419 non-null  float64
#  7   instrumentalness  12419 non-null  float64
#  8   liveness          12419 non-null  float64
#  9   valence           12419 non-null  float64
#  10  tempo             12419 non-null  float64
#  11  type              12419 non-null  object
#  12  id                12419 non-null  object
#  13  uri               12419 non-null  object
#  14  track_href        12419 non-null  object
#  15  analysis_url      12419 non-null  object
# ...

# %%
playlist_df = playlist_df.drop_duplicates()

# %%
playlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8105 entries, 0 to 12418
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      8105 non-null   float64
#  1   energy            8105 non-null   float64
#  2   key               8105 non-null   int64
#  3   loudness          8105 non-null   float64
#  4   mode              8105 non-null   int64
#  5   speechiness       8105 non-null   float64
#  6   acousticness      8105 non-null   float64
#  7   instrumentalness  8105 non-null   float64
#  8   liveness          8105 non-null   float64
#  9   valence           8105 non-null   float64
#  10  tempo             8105 non-null   float64
#  11  type              8105 non-null   object
#  12  id                8105 non-null   object
#  13  uri               8105 non-null   object
#  14  track_href        8105 non-null   object
#  15  analysis_url      8105 non-null   object
# ...

# %% [markdown]
# ### genres

# %%
genres = pd.concat([playlist_df.genre_1, playlist_df.genre_1])

# %%
genres.value_counts()
# Out:
# Pop                  2354
# Rock                 1870
# Indie                1728
# Electronic           1308
# Latin                1108
# Jazz                 1050
# Instrumental          996
# Blues                 886
# Country               770
# Rap                   768
# R&B                   758
# Singer-Songwriter     738
# Metal                 668
# Christian             398
# Classical             310
# K-Pop                 300
# Alternative           200
# Name: genre_1, dtype: int64
