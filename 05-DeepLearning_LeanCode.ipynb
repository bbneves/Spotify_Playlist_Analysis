# %% [markdown]
# # Deep Learning
#
# ## We'll be using sklearning and tensorflow.
#
# ### Goals with DL:
#  The strategy is to apply DL in order to predict a song's popularity. The threshold to make a song popular is a popularity score above 60. Then a 1 equals popular and a 0 not-popular.
#
# ### Preprocessing:
#
#  Before starting to apply any DL methodologies, we first had to prepare our dataset.
#  Removing columns with unique for the songs' information would not bring any purpose to predicting the its popularity. Therefore, information such as Song name, Playlist name, URI, and more, were removed.
#
#  Bucketing and OneHot Encode will not be used in this datas set as we seek to bring the popupar position only with the features of the songs.

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.callbacks import ModelCheckpoint

import os
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Getting the CSV file with all the information merged together
full_ml_df = pd.read_csv('./Resources/all_data.csv', index_col=False)
unique_ml_df = full_ml_df.copy()

# Every song has a unique Track_URI. So, using drop_duplicates ensures all song tracks are unique.
unique_ml_df = full_ml_df.drop_duplicates(subset=['track_uri'])

# Dropping columns which is specific for each song (like name and uri)
full_ml_df = full_ml_df.drop(columns=['Unnamed: 0', 'followers', 'songs',
                            'playlist_uri','track_uri','artist_name',
                            'song_name', 'analysis_url', 'id','uri',
                            'time_signature', 'playlist_name','track_href',
                            'type', 'mode', 'genre_2', 'genre_1' ])
# Now for the unique songs df.
unique_ml_df = unique_ml_df.drop(columns=['Unnamed: 0', 'followers', 'songs',
                            'playlist_uri','track_uri','artist_name',
                            'song_name', 'analysis_url', 'id','uri',
                            'time_signature', 'playlist_name','track_href',
                            'type', 'mode', 'genre_2', 'genre_1' ])

# %% [markdown]
# ## Attempt: Full dataset
#
# The dataset was created by selecting 100 playlists with a variety of genres. Because, really popular music may be on more the one playlist, it would be useful to have duplicates included to create a tendency of what a popular song should have as scores.

# %%
# Splitting the preprocessed data into features and targets

X = full_ml_df.drop(columns=['popular', 'popularity'])
y = full_ml_df['popular'].values

# Training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y) # Test size is 25%

# %%
# Scaling the dataset
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Activation function:
#
# The reasoning behind Tanh, Relu, and sigmoid are:
#  - Tanh: The dataset holds some negative values, so for the first layer there is a great value in having them as negative.
#  - Relu: Because it starts from zero, it is a good mid-section to connect the negative inputs.
#  - Sigmoid: Good activation function for the last layer.

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Adopting a ratio to generate neurons according to the number of features (columns) given.

number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = number_input_features//0.75
hidden_nodes_layer2 = number_input_features//1.20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='tanh'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Compiling the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Check the strucutre of the model
nn.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_50 (Dense)             (None, 14)                168
# _________________________________________________________________
# dense_51 (Dense)             (None, 9)                 135
# _________________________________________________________________
# dense_52 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Saving DP Info
#
# Saving the process of the training and the model.

# %%
# Creating a checkpoint save for this specify setup

os.makedirs("checkpoint_dl_fulldata/", exist_ok=True)
checkpoint_path = "checkpoint_dl_fulldata/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch',
    period=12)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ### Training the model.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=120,callbacks=[cp_callback])
# Out:
# Epoch 1/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.6461 - accuracy: 0.6296
# Epoch 2/120
# 292/292 [==============================] - 0s 385us/step - loss: 0.5675 - accuracy: 0.7013
# Epoch 3/120
# 292/292 [==============================] - 0s 385us/step - loss: 0.5603 - accuracy: 0.7132
# Epoch 4/120
# 292/292 [==============================] - 0s 386us/step - loss: 0.5469 - accuracy: 0.7279
# Epoch 5/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.5478 - accuracy: 0.7369
# Epoch 6/120
# 292/292 [==============================] - 0s 423us/step - loss: 0.5398 - accuracy: 0.7332
# Epoch 7/120
# 292/292 [==============================] - 0s 430us/step - loss: 0.5466 - accuracy: 0.7318
# Epoch 8/120
# 292/292 [==============================] - 0s 448us/step - loss: 0.5380 - accuracy: 0.7406
# Epoch 9/120
# 292/292 [==============================] - 0s 427us/step - loss: 0.5260 - accuracy: 0.7430
# Epoch 10/120
# 292/292 [==============================] - 0s 405us/step - loss: 0.5392 - accuracy: 0.7330
# Epoch 11/120
# 292/292 [==============================] - 0s 397us/step - loss: 0.5269 - accuracy: 0.7422
# Epoch 12/120
# 292/292 [==============================] - 0s 393us/step - loss: 0.5245 - accuracy: 0.7441
#
# Epoch 00012: saving model to checkpoint_dl_fulldata/weights.12.hdf5
# Epoch 13/120
# 292/292 [==============================] - 0s 398us/step - loss: 0.5264 - accuracy: 0.7412
# Epoch 14/120
# 292/292 [==============================] - 0s 413us/step - loss: 0.5283 - accuracy: 0.7396
# Epoch 15/120
# 292/292 [==============================] - 0s 442us/step - loss: 0.5202 - accuracy: 0.7472
# Epoch 16/120
# 292/292 [==============================] - 0s 415us/step - loss: 0.5280 - accuracy: 0.7406
# Epoch 17/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.5280 - accuracy: 0.7410
# Epoch 18/120
# 292/292 [==============================] - 0s 426us/step - loss: 0.5164 - accuracy: 0.7395
# Epoch 19/120
# 292/292 [==============================] - 0s 397us/step - loss: 0.5274 - accuracy: 0.7383
# Epoch 20/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.5219 - accuracy: 0.7402
# Epoch 21/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.5196 - accuracy: 0.7439
# Epoch 22/120
# 292/292 [==============================] - 0s 428us/step - loss: 0.5227 - accuracy: 0.7417
# Epoch 23/120
# 292/292 [==============================] - 0s 415us/step - loss: 0.5123 - accuracy: 0.7499
# Epoch 24/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.5146 - accuracy: 0.7516
#
# Epoch 00024: saving model to checkpoint_dl_fulldata/weights.24.hdf5
# Epoch 25/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.5127 - accuracy: 0.7477
# Epoch 26/120
# 292/292 [==============================] - 0s 419us/step - loss: 0.5062 - accuracy: 0.7520
# Epoch 27/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.5169 - accuracy: 0.7469
# Epoch 28/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.5121 - accuracy: 0.7498
# Epoch 29/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4970 - accuracy: 0.7652
# Epoch 30/120
# 292/292 [==============================] - 0s 399us/step - loss: 0.5144 - accuracy: 0.7509
# Epoch 31/120
# 292/292 [==============================] - 0s 416us/step - loss: 0.5177 - accuracy: 0.7466
# Epoch 32/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.5079 - accuracy: 0.7595
# Epoch 33/120
# 292/292 [==============================] - 0s 408us/step - loss: 0.5038 - accuracy: 0.7634
# Epoch 34/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.5104 - accuracy: 0.7598
# Epoch 35/120
# 292/292 [==============================] - 0s 424us/step - loss: 0.5003 - accuracy: 0.7666
# Epoch 36/120
# 292/292 [==============================] - 0s 413us/step - loss: 0.4993 - accuracy: 0.7722
#
# Epoch 00036: saving model to checkpoint_dl_fulldata/weights.36.hdf5
# Epoch 37/120
# 292/292 [==============================] - 0s 424us/step - loss: 0.5062 - accuracy: 0.7630
# Epoch 38/120
# 292/292 [==============================] - 0s 415us/step - loss: 0.5059 - accuracy: 0.7663
# Epoch 39/120
# 292/292 [==============================] - 0s 399us/step - loss: 0.4982 - accuracy: 0.7687
# Epoch 40/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.5067 - accuracy: 0.7602
# Epoch 41/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.5054 - accuracy: 0.7623
# Epoch 42/120
# 292/292 [==============================] - 0s 420us/step - loss: 0.5003 - accuracy: 0.7637
# Epoch 43/120
# 292/292 [==============================] - 0s 406us/step - loss: 0.5045 - accuracy: 0.7610
# Epoch 44/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.4992 - accuracy: 0.7671
# Epoch 45/120
# 292/292 [==============================] - 0s 407us/step - loss: 0.4862 - accuracy: 0.7748
# Epoch 46/120
# 292/292 [==============================] - 0s 412us/step - loss: 0.5035 - accuracy: 0.7612
# Epoch 47/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.5027 - accuracy: 0.7634
# Epoch 48/120
# 292/292 [==============================] - 0s 405us/step - loss: 0.4965 - accuracy: 0.7700
#
# Epoch 00048: saving model to checkpoint_dl_fulldata/weights.48.hdf5
# Epoch 49/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4927 - accuracy: 0.7636
# Epoch 50/120
# 292/292 [==============================] - 0s 398us/step - loss: 0.4970 - accuracy: 0.7586
# Epoch 51/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.4982 - accuracy: 0.7647
# Epoch 52/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4930 - accuracy: 0.7687
# Epoch 53/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.4939 - accuracy: 0.7672
# Epoch 54/120
# 292/292 [==============================] - 0s 407us/step - loss: 0.4988 - accuracy: 0.7618
# Epoch 55/120
# 292/292 [==============================] - 0s 407us/step - loss: 0.5056 - accuracy: 0.7562
# Epoch 56/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4870 - accuracy: 0.7721
# Epoch 57/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4912 - accuracy: 0.7649
# Epoch 58/120
# 292/292 [==============================] - 0s 409us/step - loss: 0.4903 - accuracy: 0.7691
# Epoch 59/120
# 292/292 [==============================] - 0s 405us/step - loss: 0.4960 - accuracy: 0.7621
# Epoch 60/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4912 - accuracy: 0.7678
#
# Epoch 00060: saving model to checkpoint_dl_fulldata/weights.60.hdf5
# Epoch 61/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4831 - accuracy: 0.7646
# Epoch 62/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.5009 - accuracy: 0.7565
# Epoch 63/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4776 - accuracy: 0.7770
# Epoch 64/120
# 292/292 [==============================] - 0s 411us/step - loss: 0.4850 - accuracy: 0.7700
# Epoch 65/120
# 292/292 [==============================] - 0s 406us/step - loss: 0.4893 - accuracy: 0.7606
# Epoch 66/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4850 - accuracy: 0.7643
# Epoch 67/120
# 292/292 [==============================] - 0s 405us/step - loss: 0.4810 - accuracy: 0.7740
# Epoch 68/120
# 292/292 [==============================] - 0s 406us/step - loss: 0.4852 - accuracy: 0.7654
# Epoch 69/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.4958 - accuracy: 0.7605
# Epoch 70/120
# 292/292 [==============================] - 0s 408us/step - loss: 0.4857 - accuracy: 0.7653
# Epoch 71/120
# 292/292 [==============================] - 0s 406us/step - loss: 0.4723 - accuracy: 0.7809
# Epoch 72/120
# 292/292 [==============================] - 0s 418us/step - loss: 0.4832 - accuracy: 0.7652
#
# Epoch 00072: saving model to checkpoint_dl_fulldata/weights.72.hdf5
# Epoch 73/120
# 292/292 [==============================] - 0s 428us/step - loss: 0.4836 - accuracy: 0.7718
# Epoch 74/120
# 292/292 [==============================] - 0s 422us/step - loss: 0.4793 - accuracy: 0.7665
# Epoch 75/120
# 292/292 [==============================] - 0s 414us/step - loss: 0.4912 - accuracy: 0.7653
# Epoch 76/120
# 292/292 [==============================] - 0s 557us/step - loss: 0.4756 - accuracy: 0.7748
# Epoch 77/120
# 292/292 [==============================] - 0s 409us/step - loss: 0.4780 - accuracy: 0.7719
# Epoch 78/120
# 292/292 [==============================] - 0s 392us/step - loss: 0.4760 - accuracy: 0.7698
# Epoch 79/120
# 292/292 [==============================] - 0s 427us/step - loss: 0.4845 - accuracy: 0.7630
# Epoch 80/120
# 292/292 [==============================] - 0s 425us/step - loss: 0.4812 - accuracy: 0.7706
# Epoch 81/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4827 - accuracy: 0.7684
# Epoch 82/120
# 292/292 [==============================] - 0s 393us/step - loss: 0.4755 - accuracy: 0.7713
# Epoch 83/120
# 292/292 [==============================] - 0s 409us/step - loss: 0.4697 - accuracy: 0.7748
# Epoch 84/120
# 292/292 [==============================] - 0s 436us/step - loss: 0.4814 - accuracy: 0.7656
#
# Epoch 00084: saving model to checkpoint_dl_fulldata/weights.84.hdf5
# Epoch 85/120
# 292/292 [==============================] - 0s 416us/step - loss: 0.4745 - accuracy: 0.7738
# Epoch 86/120
# 292/292 [==============================] - 0s 400us/step - loss: 0.4832 - accuracy: 0.7692
# Epoch 87/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4780 - accuracy: 0.7663
# Epoch 88/120
# 292/292 [==============================] - 0s 403us/step - loss: 0.4920 - accuracy: 0.7659
# Epoch 89/120
# 292/292 [==============================] - 0s 399us/step - loss: 0.4841 - accuracy: 0.7645
# Epoch 90/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.4800 - accuracy: 0.7715
# Epoch 91/120
# 292/292 [==============================] - 0s 400us/step - loss: 0.4722 - accuracy: 0.7786
# Epoch 92/120
# 292/292 [==============================] - 0s 422us/step - loss: 0.4775 - accuracy: 0.7715
# Epoch 93/120
# 292/292 [==============================] - 0s 427us/step - loss: 0.4781 - accuracy: 0.7711
# Epoch 94/120
# 292/292 [==============================] - 0s 402us/step - loss: 0.4721 - accuracy: 0.7796
# Epoch 95/120
# 292/292 [==============================] - 0s 398us/step - loss: 0.4749 - accuracy: 0.7796
# Epoch 96/120
# 292/292 [==============================] - 0s 395us/step - loss: 0.4684 - accuracy: 0.7796
#
# Epoch 00096: saving model to checkpoint_dl_fulldata/weights.96.hdf5
# Epoch 97/120
# 292/292 [==============================] - 0s 394us/step - loss: 0.4685 - accuracy: 0.7834
# Epoch 98/120
# 292/292 [==============================] - 0s 397us/step - loss: 0.4745 - accuracy: 0.7725
# Epoch 99/120
# 292/292 [==============================] - 0s 396us/step - loss: 0.4811 - accuracy: 0.7734
# Epoch 100/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4679 - accuracy: 0.7776
# Epoch 101/120
# 292/292 [==============================] - 0s 407us/step - loss: 0.4763 - accuracy: 0.7738
# Epoch 102/120
# 292/292 [==============================] - 0s 422us/step - loss: 0.4823 - accuracy: 0.7704
# Epoch 103/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4776 - accuracy: 0.7740
# Epoch 104/120
# 292/292 [==============================] - 0s 416us/step - loss: 0.4707 - accuracy: 0.7732
# Epoch 105/120
# 292/292 [==============================] - 0s 413us/step - loss: 0.4729 - accuracy: 0.7735
# Epoch 106/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4771 - accuracy: 0.7735
# Epoch 107/120
# 292/292 [==============================] - 0s 430us/step - loss: 0.4659 - accuracy: 0.7833
# Epoch 108/120
# 292/292 [==============================] - 0s 420us/step - loss: 0.4740 - accuracy: 0.7693
#
# Epoch 00108: saving model to checkpoint_dl_fulldata/weights.108.hdf5
# Epoch 109/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4693 - accuracy: 0.7751
# Epoch 110/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4712 - accuracy: 0.7758
# Epoch 111/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4801 - accuracy: 0.7623
# Epoch 112/120
# 292/292 [==============================] - 0s 405us/step - loss: 0.4679 - accuracy: 0.7784
# Epoch 113/120
# 292/292 [==============================] - 0s 398us/step - loss: 0.4632 - accuracy: 0.7845
# Epoch 114/120
# 292/292 [==============================] - 0s 399us/step - loss: 0.4670 - accuracy: 0.7761
# Epoch 115/120
# 292/292 [==============================] - 0s 395us/step - loss: 0.4699 - accuracy: 0.7790
# Epoch 116/120
# 292/292 [==============================] - 0s 404us/step - loss: 0.4698 - accuracy: 0.7759
# Epoch 117/120
# 292/292 [==============================] - 0s 408us/step - loss: 0.4727 - accuracy: 0.7708
# Epoch 118/120
# 292/292 [==============================] - 0s 401us/step - loss: 0.4774 - accuracy: 0.7748
# Epoch 119/120
# 292/292 [==============================] - 0s 400us/step - loss: 0.4653 - accuracy: 0.7841
# Epoch 120/120
# 292/292 [==============================] - 0s 413us/step - loss: 0.4676 - accuracy: 0.7763
#
# Epoch 00120: saving model to checkpoint_dl_fulldata/weights.120.hdf5

# %%
# Evaluating the model with our test data

model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 98/98 - 0s - loss: 0.5066 - accuracy: 0.7630
# Loss: 0.5066050291061401, Accuracy: 0.7629629373550415

# %%
# Export our model to HDF5 file
nn.save("fulldata_dl.h5")

# %% [markdown]
# ## Attempt: Unique songs dataset
#
# Observing the effects of not havind repeated songs, and how it will respond to the popularity score > 60.

# %%
# Splitting the preprocessed data into features and targets

Xu = unique_ml_df.drop(columns=['popular', 'popularity'])
yu = unique_ml_df['popular'].values

# Training and testing set
Xu_train, Xu_test, yu_train, yu_test = train_test_split(Xu, yu) # Test size is 25%

# %%
# Scaling the dataset
scaler = StandardScaler()
Xu_scaler = scaler.fit(Xu_train)

Xu_train_scaled = Xu_scaler.transform(Xu_train)
Xu_test_scaled = Xu_scaler.transform(Xu_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Adopting a ratio to generate neurons according to the number of features (columns) given.

number_input_features = len(Xu_train_scaled[0])
hidden_nodes_layer1 = number_input_features//0.75
hidden_nodes_layer2 = number_input_features//1.20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='tanh'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Compiling the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Check the strucutre of the model
nn.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 14)                168
# _________________________________________________________________
# dense_57 (Dense)             (None, 9)                 135
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Creating a checkpoint save for this specify setup

os.makedirs("checkpoint_dl_uniquedata/", exist_ok=True)
checkpoint_path = "checkpoint_dl_uniquedata/weights.{epoch:02d}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq='epoch',
    period=12)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train the model
fit_model = nn.fit(Xu_train_scaled,yu_train,epochs=120,callbacks=[cp_callback])
# Out:
# Epoch 1/120
# 159/159 [==============================] - 0s 434us/step - loss: 0.7232 - accuracy: 0.4791
# Epoch 2/120
# 159/159 [==============================] - 0s 456us/step - loss: 0.6512 - accuracy: 0.6258
# Epoch 3/120
# 159/159 [==============================] - 0s 433us/step - loss: 0.6186 - accuracy: 0.6480
# Epoch 4/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.6030 - accuracy: 0.6616
# Epoch 5/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5876 - accuracy: 0.6678
# Epoch 6/120
# 159/159 [==============================] - 0s 395us/step - loss: 0.5837 - accuracy: 0.6833
# Epoch 7/120
# 159/159 [==============================] - 0s 391us/step - loss: 0.5871 - accuracy: 0.6816
# Epoch 8/120
# 159/159 [==============================] - 0s 402us/step - loss: 0.5713 - accuracy: 0.6965
# Epoch 9/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5713 - accuracy: 0.6972
# Epoch 10/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5720 - accuracy: 0.6966
# Epoch 11/120
# 159/159 [==============================] - 0s 417us/step - loss: 0.5720 - accuracy: 0.6951
# Epoch 12/120
# 159/159 [==============================] - 0s 417us/step - loss: 0.5609 - accuracy: 0.6976
#
# Epoch 00012: saving model to checkpoint_dl_uniquedata/weights.12.hdf5
# Epoch 13/120
# 159/159 [==============================] - 0s 452us/step - loss: 0.5721 - accuracy: 0.6967
# Epoch 14/120
# 159/159 [==============================] - 0s 401us/step - loss: 0.5673 - accuracy: 0.6976
# Epoch 15/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5665 - accuracy: 0.7055
# Epoch 16/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5735 - accuracy: 0.6929
# Epoch 17/120
# 159/159 [==============================] - 0s 425us/step - loss: 0.5725 - accuracy: 0.7007
# Epoch 18/120
# 159/159 [==============================] - 0s 414us/step - loss: 0.5684 - accuracy: 0.7045
# Epoch 19/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5703 - accuracy: 0.7013
# Epoch 20/120
# 159/159 [==============================] - 0s 404us/step - loss: 0.5597 - accuracy: 0.7124
# Epoch 21/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5588 - accuracy: 0.7025
# Epoch 22/120
# 159/159 [==============================] - 0s 412us/step - loss: 0.5548 - accuracy: 0.7072
# Epoch 23/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5656 - accuracy: 0.7029
# Epoch 24/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5621 - accuracy: 0.7090
#
# Epoch 00024: saving model to checkpoint_dl_uniquedata/weights.24.hdf5
# Epoch 25/120
# 159/159 [==============================] - 0s 414us/step - loss: 0.5611 - accuracy: 0.7095
# Epoch 26/120
# 159/159 [==============================] - 0s 402us/step - loss: 0.5646 - accuracy: 0.7081
# Epoch 27/120
# 159/159 [==============================] - 0s 395us/step - loss: 0.5634 - accuracy: 0.7133
# Epoch 28/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5519 - accuracy: 0.7145
# Epoch 29/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5505 - accuracy: 0.7151
# Epoch 30/120
# 159/159 [==============================] - 0s 407us/step - loss: 0.5640 - accuracy: 0.7033
# Epoch 31/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5512 - accuracy: 0.7152
# Epoch 32/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5649 - accuracy: 0.7039
# Epoch 33/120
# 159/159 [==============================] - 0s 398us/step - loss: 0.5612 - accuracy: 0.7103
# Epoch 34/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5620 - accuracy: 0.7093
# Epoch 35/120
# 159/159 [==============================] - 0s 398us/step - loss: 0.5628 - accuracy: 0.7092
# Epoch 36/120
# 159/159 [==============================] - 0s 403us/step - loss: 0.5608 - accuracy: 0.7096
#
# Epoch 00036: saving model to checkpoint_dl_uniquedata/weights.36.hdf5
# Epoch 37/120
# 159/159 [==============================] - 0s 413us/step - loss: 0.5558 - accuracy: 0.7071
# Epoch 38/120
# 159/159 [==============================] - 0s 402us/step - loss: 0.5654 - accuracy: 0.7011
# Epoch 39/120
# 159/159 [==============================] - 0s 407us/step - loss: 0.5417 - accuracy: 0.7249
# Epoch 40/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5593 - accuracy: 0.7040
# Epoch 41/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5610 - accuracy: 0.7050
# Epoch 42/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5553 - accuracy: 0.7161
# Epoch 43/120
# 159/159 [==============================] - 0s 418us/step - loss: 0.5472 - accuracy: 0.7156
# Epoch 44/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5659 - accuracy: 0.7173
# Epoch 45/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5729 - accuracy: 0.6995
# Epoch 46/120
# 159/159 [==============================] - 0s 397us/step - loss: 0.5472 - accuracy: 0.7158
# Epoch 47/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5543 - accuracy: 0.7122
# Epoch 48/120
# 159/159 [==============================] - 0s 404us/step - loss: 0.5551 - accuracy: 0.7055
#
# Epoch 00048: saving model to checkpoint_dl_uniquedata/weights.48.hdf5
# Epoch 49/120
# 159/159 [==============================] - 0s 405us/step - loss: 0.5517 - accuracy: 0.7123
# Epoch 50/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5512 - accuracy: 0.7118
# Epoch 51/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5562 - accuracy: 0.7097
# Epoch 52/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5552 - accuracy: 0.7093
# Epoch 53/120
# 159/159 [==============================] - 0s 417us/step - loss: 0.5448 - accuracy: 0.7189
# Epoch 54/120
# 159/159 [==============================] - 0s 412us/step - loss: 0.5470 - accuracy: 0.7222
# Epoch 55/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5503 - accuracy: 0.7126
# Epoch 56/120
# 159/159 [==============================] - 0s 402us/step - loss: 0.5548 - accuracy: 0.7033
# Epoch 57/120
# 159/159 [==============================] - 0s 429us/step - loss: 0.5547 - accuracy: 0.7116
# Epoch 58/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5515 - accuracy: 0.7091
# Epoch 59/120
# 159/159 [==============================] - 0s 416us/step - loss: 0.5540 - accuracy: 0.7094
# Epoch 60/120
# 159/159 [==============================] - 0s 406us/step - loss: 0.5472 - accuracy: 0.7152
#
# Epoch 00060: saving model to checkpoint_dl_uniquedata/weights.60.hdf5
# Epoch 61/120
# 159/159 [==============================] - 0s 412us/step - loss: 0.5517 - accuracy: 0.7079
# Epoch 62/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5451 - accuracy: 0.7134
# Epoch 63/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5434 - accuracy: 0.7144
# Epoch 64/120
# 159/159 [==============================] - 0s 414us/step - loss: 0.5564 - accuracy: 0.7105
# Epoch 65/120
# 159/159 [==============================] - 0s 425us/step - loss: 0.5446 - accuracy: 0.7143
# Epoch 66/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5472 - accuracy: 0.7045
# Epoch 67/120
# 159/159 [==============================] - 0s 406us/step - loss: 0.5532 - accuracy: 0.7104
# Epoch 68/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5599 - accuracy: 0.7112
# Epoch 69/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5422 - accuracy: 0.7211
# Epoch 70/120
# 159/159 [==============================] - 0s 404us/step - loss: 0.5444 - accuracy: 0.7173
# Epoch 71/120
# 159/159 [==============================] - 0s 407us/step - loss: 0.5391 - accuracy: 0.7191
# Epoch 72/120
# 159/159 [==============================] - 0s 404us/step - loss: 0.5511 - accuracy: 0.7131
#
# Epoch 00072: saving model to checkpoint_dl_uniquedata/weights.72.hdf5
# Epoch 73/120
# 159/159 [==============================] - 0s 422us/step - loss: 0.5472 - accuracy: 0.7101
# Epoch 74/120
# 159/159 [==============================] - 0s 437us/step - loss: 0.5497 - accuracy: 0.7137
# Epoch 75/120
# 159/159 [==============================] - 0s 419us/step - loss: 0.5381 - accuracy: 0.7237
# Epoch 76/120
# 159/159 [==============================] - 0s 419us/step - loss: 0.5413 - accuracy: 0.7211
# Epoch 77/120
# 159/159 [==============================] - 0s 420us/step - loss: 0.5339 - accuracy: 0.7239
# Epoch 78/120
# 159/159 [==============================] - 0s 418us/step - loss: 0.5374 - accuracy: 0.7252
# Epoch 79/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5471 - accuracy: 0.7140
# Epoch 80/120
# 159/159 [==============================] - 0s 420us/step - loss: 0.5469 - accuracy: 0.7177
# Epoch 81/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5447 - accuracy: 0.7220
# Epoch 82/120
# 159/159 [==============================] - 0s 405us/step - loss: 0.5506 - accuracy: 0.7060
# Epoch 83/120
# 159/159 [==============================] - 0s 398us/step - loss: 0.5437 - accuracy: 0.7169
# Epoch 84/120
# 159/159 [==============================] - 0s 391us/step - loss: 0.5470 - accuracy: 0.7146
#
# Epoch 00084: saving model to checkpoint_dl_uniquedata/weights.84.hdf5
# Epoch 85/120
# 159/159 [==============================] - 0s 388us/step - loss: 0.5450 - accuracy: 0.7171
# Epoch 86/120
# 159/159 [==============================] - 0s 403us/step - loss: 0.5481 - accuracy: 0.7249
# Epoch 87/120
# 159/159 [==============================] - 0s 398us/step - loss: 0.5534 - accuracy: 0.7139
# Epoch 88/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5411 - accuracy: 0.7172
# Epoch 89/120
# 159/159 [==============================] - 0s 401us/step - loss: 0.5366 - accuracy: 0.7227
# Epoch 90/120
# 159/159 [==============================] - 0s 395us/step - loss: 0.5499 - accuracy: 0.7116
# Epoch 91/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5491 - accuracy: 0.7176
# Epoch 92/120
# 159/159 [==============================] - 0s 394us/step - loss: 0.5387 - accuracy: 0.7271
# Epoch 93/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5429 - accuracy: 0.7165
# Epoch 94/120
# 159/159 [==============================] - 0s 393us/step - loss: 0.5459 - accuracy: 0.7177
# Epoch 95/120
# 159/159 [==============================] - 0s 406us/step - loss: 0.5447 - accuracy: 0.7183
# Epoch 96/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5534 - accuracy: 0.7142
#
# Epoch 00096: saving model to checkpoint_dl_uniquedata/weights.96.hdf5
# Epoch 97/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5423 - accuracy: 0.7154
# Epoch 98/120
# 159/159 [==============================] - 0s 412us/step - loss: 0.5484 - accuracy: 0.7150
# Epoch 99/120
# 159/159 [==============================] - 0s 408us/step - loss: 0.5384 - accuracy: 0.7290
# Epoch 100/120
# 159/159 [==============================] - 0s 410us/step - loss: 0.5432 - accuracy: 0.7217
# Epoch 101/120
# 159/159 [==============================] - 0s 407us/step - loss: 0.5399 - accuracy: 0.7230
# Epoch 102/120
# 159/159 [==============================] - 0s 416us/step - loss: 0.5487 - accuracy: 0.7160
# Epoch 103/120
# 159/159 [==============================] - 0s 413us/step - loss: 0.5397 - accuracy: 0.7202
# Epoch 104/120
# 159/159 [==============================] - 0s 419us/step - loss: 0.5433 - accuracy: 0.7145
# Epoch 105/120
# 159/159 [==============================] - 0s 436us/step - loss: 0.5403 - accuracy: 0.7183
# Epoch 106/120
# 159/159 [==============================] - 0s 441us/step - loss: 0.5527 - accuracy: 0.7126
# Epoch 107/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5362 - accuracy: 0.7246
# Epoch 108/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5435 - accuracy: 0.7210
#
# Epoch 00108: saving model to checkpoint_dl_uniquedata/weights.108.hdf5
# Epoch 109/120
# 159/159 [==============================] - 0s 400us/step - loss: 0.5406 - accuracy: 0.7251
# Epoch 110/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5388 - accuracy: 0.7220
# Epoch 111/120
# 159/159 [==============================] - 0s 405us/step - loss: 0.5358 - accuracy: 0.7355
# Epoch 112/120
# 159/159 [==============================] - 0s 398us/step - loss: 0.5454 - accuracy: 0.7177
# Epoch 113/120
# 159/159 [==============================] - 0s 397us/step - loss: 0.5310 - accuracy: 0.7275
# Epoch 114/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5459 - accuracy: 0.7162
# Epoch 115/120
# 159/159 [==============================] - 0s 396us/step - loss: 0.5388 - accuracy: 0.7184
# Epoch 116/120
# 159/159 [==============================] - 0s 393us/step - loss: 0.5375 - accuracy: 0.7246
# Epoch 117/120
# 159/159 [==============================] - 0s 397us/step - loss: 0.5379 - accuracy: 0.7284
# Epoch 118/120
# 159/159 [==============================] - 0s 409us/step - loss: 0.5472 - accuracy: 0.7086
# Epoch 119/120
# 159/159 [==============================] - 0s 399us/step - loss: 0.5462 - accuracy: 0.7205
# Epoch 120/120
# 159/159 [==============================] - 0s 411us/step - loss: 0.5370 - accuracy: 0.7232
#
# Epoch 00120: saving model to checkpoint_dl_uniquedata/weights.120.hdf5

# %%
# Evaluating the model with our test data

model_loss, model_accuracy = nn.evaluate(Xu_test_scaled,yu_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 53/53 - 0s - loss: 0.5884 - accuracy: 0.6880
# Loss: 0.5883817672729492, Accuracy: 0.6879810690879822

# %%
# Export our model to HDF5 file
nn.save("uniquedata_dl.h5")
