# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
#import config
from config import CLIENT_ID
from config import CLIENT_SECRET
import os
import pprint

# %%
playlist_df = pd.read_csv(f'./Resources/first20_playlists.csv')
playlist_df
# Out:
#       Unnamed: 0          Playlist   Followers  Songs Genre 1 Genre 2  \
# 0              0  Today’s Top Hits  31,728,611     50     Pop     R&B
# 1              0  Today’s Top Hits  31,728,611     50     Pop     R&B
# 2              0  Today’s Top Hits  31,728,611     50     Pop     R&B
# 3              0  Today’s Top Hits  31,728,611     50     Pop     R&B
# 4              0  Today’s Top Hits  31,728,611     50     Pop     R&B
# ...          ...               ...         ...    ...     ...     ...
# 1523          19            Pollen   1,329,707    112     Pop   Indie
# 1524          19            Pollen   1,329,707    112     Pop   Indie
# 1525          19            Pollen   1,329,707    112     Pop   Indie
# 1526          19            Pollen   1,329,707    112     Pop   Indie
# 1527          19            Pollen   1,329,707    112     Pop   Indie
#
#                                           URI  \
# 0     spotify:playlist:37i9dQZF1DXcBWIGoYBM5M
# ...

# %%
duplicateRows = playlist_df[playlist_df.duplicated(['Song Name'])]
duplicateRows
# Out:
#       Unnamed: 0              Playlist  Followers  Songs Genre 1 Genre 2  \
# 51             1  Feel Good Indie Rock  1,664,372    120    Rock   Indie
# 152            2  Indie Rock Road Trip    895,126    100    Rock   Indie
# 153            2  Indie Rock Road Trip    895,126    100    Rock   Indie
# 157            2  Indie Rock Road Trip    895,126    100    Rock   Indie
# 162            2  Indie Rock Road Trip    895,126    100    Rock   Indie
# ...          ...                   ...        ...    ...     ...     ...
# 1422          18             Indie Pop  1,707,366     75     Pop   Indie
# 1447          19                Pollen  1,329,707    112     Pop   Indie
# 1502          19                Pollen  1,329,707    112     Pop   Indie
# 1503          19                Pollen  1,329,707    112     Pop   Indie
# 1518          19                Pollen  1,329,707    112     Pop   Indie
#
#                                           URI  \
# ...
